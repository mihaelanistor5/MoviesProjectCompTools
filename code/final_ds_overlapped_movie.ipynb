# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import matplotlib
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler

# %%
import os
reviewed_movie = os.listdir('/content/drive/MyDrive/DTU/Computational Tools for Data Science/project/dataset/2_reviews_per_movie_raw')
# print("The number of reviewed movies:{}".format(len(reviewed_movie)))
reviewed_movie.sort()
reviewed_movie
# Out:
# ['10 Cloverfield Lane 2016.csv',
#  '10 Things I Hate About You 1999.csv',
#  '12 Angry Men 1957.csv',
#  '12 Monkeys 1995.csv',
#  '12 Strong 2018.csv',
#  '12 Years a Slave 2013.csv',
#  '127 Hours 2010.csv',
#  '13 Hours 2016.csv',
#  '1408 2007.csv',
#  '1917 2019.csv',
#  '1941 1979.csv',
#  '2001_ A Space Odyssey 1968.csv',
#  '2012 2009.csv',
#  '21 2008.csv',
#  '21 Jump Street 2012.csv',
#  '22 Jump Street 2014.csv',
#  '28 Days Later... 2002.csv',
#  '28 Weeks Later 2007.csv',
#  '3 Idiots 2009.csv',
#  '30 Days of Night 2007.csv',
#  '300 2006.csv',
#  '3_10 to Yuma 2007.csv',
#  '42 2013.csv',
#  '50 First Dates 2004.csv',
#  '500 Days of Summer 2009.csv',
#  '50_50 2011.csv',
#  '54 1998.csv',
#  '8 Mile 2002.csv',
#  'A Beautiful Mind 2001.csv',
#  'A Bridge Too Far 1977.csv',
#  "A Bug's Life 1998.csv",
#  'A Clockwork Orange 1971.csv',
#  "A Hard Day's Night 1964.csv",
#  'A Night at the Roxbury 1998.csv',
#  'A Nightmare on Elm Street 1984.csv',
#  'A Quiet Place 2018.csv',
#  'A Star Is Born 2018.csv',
#  'A Walk to Remember 2002.csv',
#  'About Time 2013.csv',
#  'Abraham Lincoln_ Vampire Hunter 2012.csv',
#  'Across the Universe 2007.csv',
#  'Airlift 2016.csv',
#  'Akira 1988.csv',
#  'Aladdin 1992.csv',
#  'Aladdin 2019.csv',
#  'Alexander 2004.csv',
#  'Ali 2001.csv',
#  'Alice in Wonderland 2010.csv',
#  'Alien 1979.csv',
#  'Alien 3 1992.csv',
#  'Alien vs. Predator 2004.csv',
#  'Alien_ Covenant 2017.csv',
#  'Alien_ Resurrection 1997.csv',
#  'Aliens 1986.csv',
#  'All Quiet on the Western Front 1930.csv',
#  "All the President's Men 1976.csv",
#  'Amadeus 1984.csv',
#  'American Beauty 1999.csv',
#  'American Gangster 2007.csv',
#  'American History X 1998.csv',
#  'American Hustle 2013.csv',
#  'American Made 2017.csv',
#  'American Pie 1999.csv',
#  'American Psycho 2000.csv',
#  'American Sniper 2014.csv',
#  'Amélie 2001.csv',
#  'Amistad 1997.csv',
#  'Anchorman_ The Legend of Ron Burgundy 2004.csv',
#  'Angels & Demons 2009.csv',
#  'Annie Hall 1977.csv',
#  'Annihilation 2018.csv',
#  'Ant-Man 2015.csv',
#  'Antz 1998.csv',
#  'Any Given Sunday 1999.csv',
#  'Apocalypse Now 1979.csv',
#  'Apollo 13 1995.csv',
#  'Aquaman 2018.csv',
#  'Argo 2012.csv',
#  'Armageddon 1998.csv',
#  'Army of Darkness 1992.csv',
#  'Arrival 2016.csv',
#  'As Good as It Gets 1997.csv',
#  'Atonement 2007.csv',
#  'Au Revoir les Enfants 1987.csv',
#  'August Rush 2007.csv',
#  'Avatar 2009.csv',
#  'Avengers_ Age of Ultron 2015.csv',
#  'Avengers_ Endgame 2019.csv',
#  'Avengers_ Infinity War 2018.csv',
#  'BASEketball 1998.csv',
#  'Baby Driver 2017.csv',
#  'Back to the Future 1985.csv',
#  'Back to the Future Part II 1989.csv',
#  'Back to the Future Part III 1990.csv',
#  'Bad Teacher 2011.csv',
#  'Balls of Fury 2007.csv',
#  'Barry Lyndon 1975.csv',
#  'Batman Begins 2005.csv',
#  'Batman Returns 1992.csv',
#  'Batman v Superman_ Dawn of Justice 2016.csv',
#  'Battleship Potemkin 1925.csv',
#  'Beasts of No Nation 2015.csv',
#  'Beauty and the Beast 1991.csv',
#  'Beauty and the Beast 2017.csv',
#  'Beetlejuice 1988.csv',
#  'Before Sunrise 1995.csv',
#  'Before Sunset 2004.csv',
#  'Begin Again 2013.csv',
#  'Behind The Candelabra 2013.csv',
#  'Being John Malkovich 1999.csv',
#  'Ben-Hur 1959.csv',
#  'Beowulf 2007.csv',
#  'Bhaag Milkha Bhaag 2013.csv',
#  'Big Fish 2003.csv',
#  'Big Hero 6 2014.csv',
#  "Bill & Ted's Excellent Adventure 1989.csv",
#  'Billy Elliot 2000.csv',
#  'Bird Box 2018.csv',
#  'Birdman or (The Unexpected Virtue of Ignorance) 2014.csv',
#  'BlacKkKlansman 2018.csv',
#  'Black Book 2006.csv',
#  'Black Hawk Down 2001.csv',
#  'Black Mass 2015.csv',
#  'Black Panther 2018.csv',
#  'Black Snake Moan 2006.csv',
#  'Black Swan 2010.csv',
#  'Blade 1998.csv',
#  'Blade II 2002.csv',
#  'Blade Runner 1982.csv',
#  'Blade Runner 2049 2017.csv',
#  'Blades of Glory 2007.csv',
#  'Blood Diamond 2006.csv',
#  'Bloody Sunday 2002.csv',
#  'Blow 2001.csv',
#  'Blue Crush 2002.csv',
#  'Bohemian Rhapsody 2018.csv',
#  'Bolt 2008.csv',
#  'Borat_ Cultural Learnings of America for Make Benefit Glorious Nation of Kazakhstan 2006.csv',
#  'Born on the Fourth of July 1989.csv',
#  "Bram Stoker's Dracula 1992.csv",
#  'Brave 2012.csv',
#  'Braveheart 1995.csv',
#  'Bridesmaids 2011.csv',
#  'Bridge of Spies 2015.csv',
#  "Bridget Jones's Diary 2001.csv",
#  'Bring It On 2000.csv',
#  'Brokeback Mountain 2005.csv',
#  'Bruce Almighty 2003.csv',
#  'Bull Durham 1988.csv',
#  'Burlesque 2010.csv',
#  'Burn After Reading 2008.csv',
#  'Butch Cassidy and the Sundance Kid 1969.csv',
#  'Caddyshack 1980.csv',
#  'Call Me by Your Name 2017.csv',
#  'Capote 2005.csv',
#  'Captain America_ Civil War 2016.csv',
#  'Captain America_ The First Avenger 2011.csv',
#  'Captain America_ The Winter Soldier 2014.csv',
#  "Captain Corelli's Mandolin 2001.csv",
#  'Captain Marvel 2019.csv',
#  'Captain Phillips 2013.csv',
#  'Carrie 1976.csv',
#  'Cars 2 2011.csv',
#  'Cars 2006.csv',
#  'Casablanca 1942.csv',
#  'Casino 1995.csv',
#  'Casino Royale 2006.csv',
#  'Cast Away 2000.csv',
#  'Castle in the Sky 1986.csv',
#  'Casualties of War 1989.csv',
#  'Catch Me If You Can 2002.csv',
#  'Catch-22 1970.csv',
#  'Centurion 2010.csv',
#  'Chak de! India 2007.csv',
#  'Changeling 2008.csv',
#  'Chariots of Fire 1981.csv',
#  'Charlie and the Chocolate Factory 2005.csv',
#  'Chicken Run 2000.csv',
#  'Child 44 2015.csv',
#  'Children of Heaven 1997.csv',
#  'Children of Men 2006.csv',
#  'Chinatown 1974.csv',
#  'Cinderella 1950.csv',
#  'Cinderella Man 2005.csv',
#  'Citizen Kane 1941.csv',
#  'City of God 2002.csv',
#  'Clash of the Titans 2010.csv',
#  'Click 2006.csv',
#  'Climax 2018.csv',
#  'Closer 2004.csv',
#  'Cloud Atlas 2012.csv',
#  'Cloudy with a Chance of Meatballs 2009.csv',
#  'Cloverfield 2008.csv',
#  'Coach Carter 2005.csv',
#  'Coco 2017.csv',
#  'Coffee and Cigarettes 2003.csv',
#  'Cold Mountain 2003.csv',
#  'Cold War 2018.csv',
#  'Collateral 2004.csv',
#  'Come and See 1985.csv',
#  'Con Air 1997.csv',
#  'Concussion 2015.csv',
#  'Conquest 1453 2012.csv',
#  'Constantine 2005.csv',
#  'Contact 1997.csv',
#  'Control 2007.csv',
#  'Coraline 2009.csv',
#  'Coriolanus 2011.csv',
#  'Corpse Bride 2005.csv',
#  'Coyote Ugly 2000.csv',
#  'Crash 2004.csv',
#  'Crazy Heart 2009.csv',
#  'Crazy, Stupid, Love 2011.csv',
#  'Creed 2015.csv',
#  'Creed II 2018.csv',
#  'Cross of Iron 1977.csv',
#  'Crouching Tiger, Hidden Dragon 2000.csv',
#  'Cube 1997.csv',
#  'Da 5 Bloods 2020.csv',
#  'Dallas Buyers Club 2013.csv',
#  'Dangal 2016.csv',
#  'Dark City 1998.csv',
#  'Dark Shadows 2012.csv',
#  'Darkest Hour 2017.csv',
#  'Dawn of the Dead 2004.csv',
#  'Days of Thunder 1990.csv',
#  'Dead Poets Society 1989.csv',
#  'Deadpool 2 2018.csv',
#  'Deadpool 2016.csv',
#  'Dear John 2010.csv',
#  'Deepwater Horizon 2016.csv',
#  'Defiance 2008.csv',
#  'Deja Vu 2006.csv',
#  'Departures 2008.csv',
#  'Despicable Me 2 2013.csv',
#  'Despicable Me 2010.csv',
#  'Detroit 2017.csv',
#  'Detroit Rock City 1999.csv',
#  'Die Hard 1988.csv',
#  'Die Hard 2 1990.csv',
#  'Die Hard with a Vengeance 1995.csv',
#  'Dirty Dancing 1987.csv',
#  'District 9 2009.csv',
#  'Disturbia 2007.csv',
#  'Divergent 2014.csv',
#  'Django Unchained 2012.csv',
#  'Doctor Strange 2016.csv',
#  'Doctor Zhivago 1965.csv',
#  'Dodgeball 2004.csv',
#  'Dog Day Afternoon 1975.csv',
#  'Don Jon 2013.csv',
#  "Don't Breathe 2016.csv",
#  'Donnie Brasco 1997.csv',
#  'Donnie Darko 2001.csv',
#  'Downfall 2004.csv',
#  'Dr. Strangelove or_ How I Learned to Stop Worrying and Love the Bomb 1964.csv',
#  'Draft Day 2014.csv',
#  'Drag Me to Hell 2009.csv',
#  'Dreamgirls 2006.csv',
#  'Drive 2011.csv',
#  'Driven 2001.csv',
#  'Duck Soup 1933.csv',
#  'Duck You Sucker 1971.csv',
#  'Dumb and Dumber 1994.csv',
#  'Dunkirk 2017.csv',
#  'E.T. the Extra-Terrestrial 1982.csv',
#  'Easy A 2010.csv',
#  'Ed Wood 1994.csv',
#  'Edge of Tomorrow 2014.csv',
#  'Edward Scissorhands 1990.csv',
#  'Elf 2003.csv',
#  'Elizabeth 1998.csv',
#  'Elizabeth_ The Golden Age 2007.csv',
#  'Elysium 2013.csv',
#  'Empire Records 1995.csv',
#  'Empire of the Sun 1987.csv',
#  'Enchanted 2007.csv',
#  "Ender's Game 2013.csv",
#  'Enemy at the Gates 2001.csv',
#  'Erin Brockovich 2000.csv',
#  'Eternal Sunshine of the Spotless Mind 2004.csv',
#  'Eurovision Song Contest_ The Story of Fire Saga 2020.csv',
#  'Event Horizon 1997.csv',
#  'Everest 2015.csv',
#  'Evil Dead 2013.csv',
#  'Evil Dead II 1987.csv',
#  'Ex Machina 2014.csv',
#  'Eyes Wide Shut 1999.csv',
#  'Face_Off 1997.csv',
#  'Fantastic 4_ Rise of the Silver Surfer 2007.csv',
#  'Fantastic Beasts and Where to Find Them 2016.csv',
#  'Fantastic Four 2005.csv',
#  'Fantastic Mr. Fox 2009.csv',
#  'Fargo 1996.csv',
#  'Fast & Furious 6 2013.csv',
#  'Fast Five 2011.csv',
#  'Fifty Shades of Grey 2015.csv',
#  'Fight Club 1999.csv',
#  'Final Destination 2 2003.csv',
#  'Final Destination 2000.csv',
#  'Finding Dory 2016.csv',
#  'Finding Nemo 2003.csv',
#  'Finding Neverland 2004.csv',
#  'First Man 2018.csv',
#  'Flashdance 1983.csv',
#  'Flight 2012.csv',
#  'Footloose 1984.csv',
#  'Footloose 2011.csv',
#  'For Love of the Game 1999.csv',
#  'Ford v Ferrari 2019.csv',
#  'Forgetting Sarah Marshall 2008.csv',
#  'Forrest Gump 1994.csv',
#  'Foxcatcher 2014.csv',
#  'Frank 2014.csv',
#  'Friday Night Lights 2004.csv',
#  'Friends with Benefits 2011.csv',
#  'From Dusk Till Dawn 1996.csv',
#  'From Hell 2001.csv',
#  'From Here to Eternity 1953.csv',
#  'Frost_Nixon 2008.csv',
#  'Frozen 2013.csv',
#  'Full Metal Jacket 1987.csv',
#  'Furious 7 2015.csv',
#  'Fury 2014.csv',
#  'G.I. Jane 1997.csv',
#  'Gandhi 1982.csv',
#  'Gangs of New York 2002.csv',
#  'Garden State 2004.csv',
#  'Get Him to the Greek 2010.csv',
#  'Get Out 2017.csv',
#  'Gettysburg 1993.csv',
#  'Ghost 1990.csv',
#  'Ghost Rider 2007.csv',
#  'Ghostbusters 1984.csv',
#  'Girl, Interrupted 1999.csv',
#  'Gladiator 2000.csv',
#  'Glory 1989.csv',
#  'Glory Road 2006.csv',
#  'Godzilla 2014.csv',
#  'Gone Baby Gone 2007.csv',
#  'Gone Girl 2014.csv',
#  'Gone with the Wind 1939.csv',
#  'Good Morning, Vietnam 1987.csv',
#  'Good Night, and Good Luck. 2005.csv',
#  'Good Will Hunting 1997.csv',
#  'Goodfellas 1990.csv',
#  'Goon 2011.csv',
#  'Gran Torino 2008.csv',
#  'Grave of the Fireflies 1988.csv',
#  'Gravity 2013.csv',
#  'Grease 1978.csv',
#  'Green Book 2018.csv',
#  'Green Room 2015.csv',
#  'Green Street Hooligans 2005.csv',
#  'Gremlins 1984.csv',
#  'Grindhouse 2007.csv',
#  'Groundhog Day 1993.csv',
#  'Grudge Match 2013.csv',
#  'Guardians of the Galaxy 2014.csv',
#  'Guardians of the Galaxy Vol. 2 2017.csv',
#  'Hacksaw Ridge 2016.csv',
#  'Hail, Caesar! 2016.csv',
#  'Halloween 1978.csv',
#  'Hancock 2008.csv',
#  'Hansel & Gretel_ Witch Hunters 2013.csv',
#  'Happy Feet 2006.csv',
#  'Happy Gilmore 1996.csv',
#  'Happy New Year 2014.csv',
#  'Hardball 2001.csv',
#  'Harry Potter and the Chamber of Secrets 2002.csv',
#  'Harry Potter and the Deathly Hallows_ Part 1 2010.csv',
#  'Harry Potter and the Deathly Hallows_ Part 2 2011.csv',
#  'Harry Potter and the Goblet of Fire 2005.csv',
#  'Harry Potter and the Order of the Phoenix 2007.csv',
#  'Harry Potter and the Prisoner of Azkaban 2004.csv',
#  "Harry Potter and the Sorcerer's Stone 2001.csv",
#  "Hart's War 2002.csv",
#  'He Got Game 1998.csv',
#  'Heartbreak Ridge 1986.csv',
#  'Heat 1995.csv',
#  'Hedwig and the Angry Inch 2001.csv',
#  'Hellboy 2004.csv',
#  'Hellboy II_ The Golden Army 2008.csv',
#  'Her 2013.csv',
#  'Hercules 1997.csv',
#  'Here Comes the Boom 2012.csv',
#  'Hereditary 2018.csv',
#  'Hero 2002.csv',
#  'Hidden Figures 2016.csv',
#  'High Fidelity 2000.csv',
#  'Hitch 2005.csv',
#  'Home Alone 1990.csv',
#  'Home Alone 2_ Lost in New York 1992.csv',
#  'Honey 2003.csv',
#  'Hoosiers 1986.csv',
#  'Horrible Bosses 2011.csv',
#  'Hostel 2005.csv',
#  'Hot Fuzz 2007.csv',
#  'Hot Rod 2007.csv',
#  'Hotel Mumbai 2018.csv',
#  'Hotel Rwanda 2004.csv',
#  'Hotel Transylvania 2012.csv',
#  'How to Lose a Guy in 10 Days 2003.csv',
#  'How to Train Your Dragon 2 2014.csv',
#  'How to Train Your Dragon 2010.csv',
#  "Howl's Moving Castle 2004.csv",
#  'Hugo 2011.csv',
#  'Hustle & Flow 2005.csv',
#  'I Am Legend 2007.csv',
#  'I Love You, Man 2009.csv',
#  "I'm Not There 2007.csv",
#  'I, Robot 2004.csv',
#  'I, Tonya 2017.csv',
#  'Ice Age 2002.csv',
#  'Ice Age_ Continental Drift 2012.csv',
#  'Ice Age_ Dawn of the Dinosaurs 2009.csv',
#  'Ice Age_ The Meltdown 2006.csv',
#  'Identity 2003.csv',
#  'If I Stay 2014.csv',
#  'In Bruges 2008.csv',
#  'In Time 2011.csv',
#  'In the Land of Blood and Honey 2011.csv',
#  'In the Name of the Father 1993.csv',
#  'Incendies 2010.csv',
#  'Inception 2010.csv',
#  'Incredibles 2 2018.csv',
#  'Independence Day 1996.csv',
#  'Indiana Jones and the Last Crusade 1989.csv',
#  'Inglourious Basterds 2009.csv',
#  'Inside Llewyn Davis 2013.csv',
#  'Inside Man 2006.csv',
#  'Inside Out 2015.csv',
#  'Insidious 2010.csv',
#  'Insidious_ Chapter 2 2013.csv',
#  'Insomnia 2002.csv',
#  'Interstellar 2014.csv',
#  'Interview with the Vampire_ The Vampire Chronicles 1994.csv',
#  'Into the Wild 2007.csv',
#  'Invictus 2009.csv',
#  'Invincible 2006.csv',
#  'Ip Man 2008.csv',
#  'Iron Man 2 2010.csv',
#  'Iron Man 2008.csv',
#  'Iron Man 3 2013.csv',
#  'It 2017.csv',
#  'It Chapter Two 2019.csv',
#  'It Follows 2014.csv',
#  "It's a Wonderful Life 1946.csv",
#  'JFK 1991.csv',
#  'Jack Reacher 2012.csv',
#  'Jackie 2016.csv',
#  'Jackie Brown 1997.csv',
#  'Jarhead 2005.csv',
#  'Jaws 1975.csv',
#  'Jerry Maguire 1996.csv',
#  'Jersey Boys 2014.csv',
#  'John Wick 2014.csv',
#  'John Wick_ Chapter 2 2017.csv',
#  'Jojo Rabbit 2019.csv',
#  'Joker 2019.csv',
#  'Joy 2015.csv',
#  'Judgment at Nuremberg 1961.csv',
#  'Juno 2007.csv',
#  'Jurassic Park 1993.csv',
#  'Jurassic World 2015.csv',
#  'Just Go with It 2011.csv',
#  'Justice League 2017.csv',
#  'K-19_ The Widowmaker 2002.csv',
#  'Kagemusha 1980.csv',
#  "Kelly's Heroes 1970.csv",
#  'Kick-Ass 2010.csv',
#  'Kickboxer 1989.csv',
#  'Kill Bill_ Vol. 1 2003.csv',
#  'Kill Bill_ Vol. 2 2004.csv',
#  'Kingpin 1996.csv',
#  'Kingsman_ The Secret Service 2014.csv',
#  'Knives Out 2019.csv',
#  'Knocked Up 2007.csv',
#  'Knowing 2009.csv',
#  'Kong_ Skull Island 2017.csv',
#  'Kung Fu Panda 2 2011.csv',
#  'Kung Fu Panda 2008.csv',
#  'L.A. Confidential 1997.csv',
#  'La Grande Illusion 1937.csv',
#  'La La Land 2016.csv',
#  'La Vie En Rose 2007.csv',
#  'Last Flag Flying 2017.csv',
#  'Law Abiding Citizen 2009.csv',
#  'Lawrence of Arabia 1962.csv',
#  'Legend 2015.csv',
#  'Legends of the Fall 1994.csv',
#  'Les Misérables 2012.csv',
#  'Léon_ The Professional 1994.csv',
#  'Liar Liar 1997.csv',
#  'Life 2017.csv',
#  'Life Is Beautiful 1997.csv',
#  'Life of Pi 2012.csv',
#  'Lifeboat 1944.csv',
#  'Lilo & Stitch 2002.csv',
#  'Limitless 2011.csv',
#  'Lincoln 2012.csv',
#  'Lion 2016.csv',
#  'Little Boy 2015.csv',
#  'Little Miss Sunshine 2006.csv',
#  'Live Free or Die Hard 2007.csv',
#  'Lock, Stock and Two Smoking Barrels 1998.csv',
#  'Logan 2017.csv',
#  'Lone Survivor 2013.csv',
#  'Looper 2012.csv',
#  'Lord of War 2005.csv',
#  'Lords of Dogtown 2005.csv',
#  'Lost in Translation 2003.csv',
#  'Love & Mercy 2014.csv',
#  'Love Actually 2003.csv',
#  'Love and Death 1975.csv',
#  'Lucky Number Slevin 2006.csv',
#  'Lucy 2014.csv',
#  'M.S. Dhoni_ The Untold Story 2016.csv',
#  'MASH 1970.csv',
#  'Macbeth 2015.csv',
#  'Mad Max_ Fury Road 2015.csv',
#  'Madagascar 2005.csv',
#  "Madagascar 3_ Europe's Most Wanted 2012.csv",
#  'Madagascar_ Escape 2 Africa 2008.csv',
#  'Magic Mike XXL 2015.csv',
#  'Major League 1989.csv',
#  'Malcolm X 1992.csv',
#  'Mama 2013.csv',
#  'Mamma Mia! 2008.csv',
#  'Man of Steel 2013.csv',
#  'Man on Fire 2004.csv',
#  'Man on the Moon 1999.csv',
#  'Marie Antoinette 2006.csv',
#  'Marriage Story 2019.csv',
#  'Mary and Max 2009.csv',
#  'Match Point 2005.csv',
#  'McFarland, USA 2015.csv',
#  'Me Before You 2016.csv',
#  'Meet Joe Black 1998.csv',
#  'Meet the Fockers 2004.csv',
#  'Meet the Parents 2000.csv',
#  'Megamind 2010.csv',
#  'Memento 2000.csv',
#  'Men in Black 1997.csv',
#  'Men in Black 3 2012.csv',
#  'Men in Black II 2002.csv',
#  'Midnight in Paris 2011.csv',
#  'Midsommar 2019.csv',
#  'Midway 2019.csv',
#  'Milk 2008.csv',
#  'Million Dollar Arm 2014.csv',
#  'Million Dollar Baby 2004.csv',
#  'Minions 2015.csv',
#  'Minority Report 2002.csv',
#  'Miracle 2004.csv',
#  'Mission_ Impossible - Ghost Protocol 2011.csv',
#  'Mission_ Impossible - Rogue Nation 2015.csv',
#  'Mission_ Impossible 1996.csv',
#  'Mission_ Impossible II 2000.csv',
#  'Mission_ Impossible III 2006.csv',
#  'Mississippi Burning 1988.csv',
#  'Moana 2016.csv',
#  "Molly's Game 2017.csv",
#  'Moneyball 2011.csv',
#  'Monster 2003.csv',
#  'Monsters University 2013.csv',
#  'Monsters vs. Aliens 2009.csv',
#  'Monsters, Inc. 2001.csv',
#  'Monty Python and the Holy Grail 1975.csv',
#  "Monty Python's Life of Brian 1979.csv",
#  'Moon 2009.csv',
#  'Moonrise Kingdom 2012.csv',
#  'Mother! 2017.csv',
#  'Moulin Rouge! 2001.csv',
#  'Mr. & Mrs. Smith 2005.csv',
#  "Mr. Holland's Opus 1995.csv",
#  'Mr. Nobody 2009.csv',
#  'Mudbound 2017.csv',
#  'Mulan 1998.csv',
#  'Mulholland Drive 2001.csv',
#  'Munich 2005.csv',
#  'Murder on the Orient Express 2017.csv',
#  'Music and Lyrics 2007.csv',
#  'My Neighbor Totoro 1988.csv',
#  'Mystic River 2003.csv',
#  'Nacho Libre 2006.csv',
#  'National Treasure 2004.csv',
#  'National Treasure_ Book of Secrets 2007.csv',
#  'Nausicaä of the Valley of the Wind 1984.csv',
#  'Never Back Down 2008.csv',
#  "Nick and Norah's Infinite Playlist 2008.csv",
#  'Nightcrawler 2014.csv',
#  'No Country for Old Men 2007.csv',
#  "No Man's Land 2001.csv",
#  'No Strings Attached 2011.csv',
#  'Non-Stop 2014.csv',
#  'North by Northwest 1959.csv',
#  'Notting Hill 1999.csv',
#  'Now You See Me 2013.csv',
#  'O Brother, Where Art Thou_ 2000.csv',
#  'Oblivion 2013.csv',
#  "Ocean's Eleven 2001.csv",
#  "Ocean's Thirteen 2007.csv",
#  "Ocean's Twelve 2004.csv",
#  'Oldboy 2003.csv',
#  'Once 2007.csv',
#  'Once Upon a Time in America 1984.csv',
#  'Once Upon a Time... in Hollywood 2019.csv',
#  "One Flew Over the Cuckoo's Nest 1975.csv",
#  'One Hundred and One Dalmatians 1961.csv',
#  'Orphan 2009.csv',
#  'Over the Hedge 2006.csv',
#  'Over the Top 1987.csv',
#  'P.S. I Love You 2007.csv',
#  'Pacific Rim 2013.csv',
#  "Pan's Labyrinth 2006.csv",
#  'Paranormal Activity 2007.csv',
#  'Parasite 2019.csv',
#  'Passengers 2016.csv',
#  'Paths of Glory 1957.csv',
#  'Patton 1970.csv',
#  'Pawn Sacrifice 2014.csv',
#  'Peaceful Warrior 2006.csv',
#  'Pearl Harbor 2001.csv',
#  'Pi 1998.csv',
#  'Pineapple Express 2008.csv',
#  'Pirate Radio 2009.csv',
#  "Pirates of the Caribbean_ At World's End 2007.csv",
#  "Pirates of the Caribbean_ Dead Man's Chest 2006.csv",
#  'Pirates of the Caribbean_ Dead Men Tell No Tales 2017.csv',
#  'Pirates of the Caribbean_ On Stranger Tides 2011.csv',
#  'Pirates of the Caribbean_ The Curse of the Black Pearl 2003.csv',
#  'Pitch Black 2000.csv',
#  'Pitch Perfect 2 2015.csv',
#  'Pitch Perfect 2012.csv',
#  'Pitch Perfect 3 2017.csv',
#  'Platoon 1986.csv',
#  'Pocahontas 1995.csv',
#  'Point Break 2015.csv',
#  'Popstar_ Never Stop Never Stopping 2016.csv',
#  'Predator 1987.csv',
#  'Pretty Woman 1990.csv',
#  'Pride & Prejudice 2005.csv',
#  'Prince of Persia_ The Sands of Time 2010.csv',
#  'Princess Mononoke 1997.csv',
#  'Prisoners 2013.csv',
#  'Prometheus 2012.csv',
#  'Psycho 1960.csv',
#  'Public Enemies 2009.csv',
#  'Pulp Fiction 1994.csv',
#  'Puss in Boots 2011.csv',
#  'Quantum of Solace 2008.csv',
#  'Quiz Show 1994.csv',
#  'RED 2010.csv',
#  'Rab Ne Bana Di Jodi 2008.csv',
#  'Radio 2003.csv',
#  'Raging Bull 1980.csv',
#  'Raiders of the Lost Ark 1981.csv',
#  'Ran 1985.csv',
#  'Rang De Basanti 2006.csv',
#  'Rango 2011.csv',
#  'Ratatouille 2007.csv',
#  'Ray 2004.csv',
#  'Ready Player One 2018.csv',
#  'Rear Window 1954.csv',
#  'Remember the Titans 2000.csv',
#  'Requiem for a Dream 2000.csv',
#  'Reservoir Dogs 1992.csv',
#  'Resident Evil 2002.csv',
#  'Resident Evil_ Afterlife 2010.csv',
#  'Resident Evil_ Apocalypse 2004.csv',
#  'Resident Evil_ Extinction 2007.csv',
#  'Revolutionary Road 2008.csv',
#  'Rio 2011.csv',
#  'Rise of the Guardians 2012.csv',
#  'Rise of the Planet of the Apes 2011.csv',
#  'Rock Star 2001.csv',
#  'Rocketman 2019.csv',
#  'Rockstar 2011.csv',
#  'Rocky 1976.csv',
#  'Rocky II 1979.csv',
#  'Rocky III 1982.csv',
#  'Rocky IV 1985.csv',
#  'Rocky V 1990.csv',
#  'Rogue One_ A Star Wars Story 2016.csv',
#  'Romeo + Juliet 1996.csv',
#  'Room 2015.csv',
#  "Rosemary's Baby 1968.csv",
#  'Rudy 1993.csv',
#  'Rules of Engagement 2000.csv',
#  'Run, Fat Boy, Run 2007.csv',
#  'Rush 2013.csv',
#  'Saboteur 1942.csv',
#  'Saints and Soldiers 2003.csv',
#  'Salò, or the 120 Days of Sodom 1975.csv',
#  'Salt 2010.csv',
#  'Saturday Night Fever 1977.csv',
#  'Sausage Party 2016.csv',
#  'Save the Last Dance 2001.csv',
#  'Saving Mr. Banks 2013.csv',
#  'Saving Private Ryan 1998.csv',
#  'Saw 2004.csv',
#  'Saw II 2005.csv',
#  'Saw III 2006.csv',
#  'Scarface 1983.csv',
#  'Scary Movie 2 2001.csv',
#  "Schindler's List 1993.csv",
#  'School of Rock 2003.csv',
#  'Scott Pilgrim vs. the World 2010.csv',
#  'Scream 1996.csv',
#  'Scream 2 1997.csv',
#  'Se7en 1995.csv',
#  'Seabiscuit 2003.csv',
#  'Selma 2014.csv',
#  'Semi-Pro 2008.csv',
#  'Seven Years in Tibet 1997.csv',
#  'Shakespeare in Love 1998.csv',
#  'Shall We Dance 2004.csv',
#  'Shark Tale 2004.csv',
#  'Shaun of the Dead 2004.csv',
#  "She's the Man 2006.csv",
#  'Sherlock Holmes 2009.csv',
#  'Sherlock Holmes_ A Game of Shadows 2011.csv',
#  'Shine 1996.csv',
#  'Shooter 2007.csv',
#  'Shrek 2 2004.csv',
#  'Shrek 2001.csv',
#  'Shrek Forever After 2010.csv',
#  'Shrek the Third 2007.csv',
#  'Shutter Island 2010.csv',
#  'Sicario 2015.csv',
#  'Signs 2002.csv',
#  'Silence 2016.csv',
#  'Silent Hill 2006.csv',
#  'Silver Linings Playbook 2012.csv',
#  'Sin City 2005.csv',
#  'Sing Street 2016.csv',
#  "Singin' in the Rain 1952.csv",
#  'Sinister 2012.csv',
#  'Skyfall 2012.csv',
#  'Slap Shot 1977.csv',
#  'Sleepy Hollow 1999.csv',
#  'Slumdog Millionaire 2008.csv',
#  'Snatch 2000.csv',
#  'Snow White and the Seven Dwarfs 1937.csv',
#  'Snowden 2016.csv',
#  'Some Like It Hot 1959.csv',
#  'Son of Saul 2015.csv',
#  'Source Code 2011.csv',
#  'South Park_ Bigger, Longer & Uncut 1999.csv',
#  'Southpaw 2015.csv',
#  'Space Jam 1996.csv',
#  'Spartacus 1960.csv',
#  'Spectre 2015.csv',
#  'Speed 1994.csv',
#  'Spice World 1997.csv',
#  'Spider-Man 2 2004.csv',
#  'Spider-Man 2002.csv',
#  'Spider-Man 3 2007.csv',
#  'Spider-Man_ Homecoming 2017.csv',
#  'Spider-Man_ Into the Spider-Verse 2018.csv',
#  'Spirited Away 2001.csv',
#  'Split 2016.csv',
#  'Spotlight 2015.csv',
#  'Stalag 17 1953.csv',
#  'Stalingrad 1993.csv',
#  'Star Trek 2009.csv',
#  'Star Trek Into Darkness 2013.csv',
#  'Star Wars_ Episode I - The Phantom Menace 1999.csv',
#  'Star Wars_ Episode II - Attack of the Clones 2002.csv',
#  'Star Wars_ Episode III - Revenge of the Sith 2005.csv',
#  'Star Wars_ Episode IV - A New Hope 1977.csv',
#  'Star Wars_ Episode IX - The Rise of Skywalker 2019.csv',
#  'Star Wars_ Episode V - The Empire Strikes Back 1980.csv',
#  'Star Wars_ Episode VI - Return of the Jedi 1983.csv',
#  'Star Wars_ Episode VII - The Force Awakens 2015.csv',
#  'Star Wars_ Episode VIII - The Last Jedi 2017.csv',
#  'Stardust 2007.csv',
#  'Step Up 2006.csv',
#  'Step Up 2_ The Streets 2008.csv',
#  'Steve Jobs 2015.csv',
#  'Stop-Loss 2008.csv',
#  'Straight Outta Compton 2015.csv',
#  'Stranger Than Fiction 2006.csv',
#  'Stripes 1981.csv',
#  'Sucker Punch 2011.csv',
#  'Suicide Squad 2016.csv',
#  'Sully 2016.csv',
#  'Sultan 2016.csv',
#  'Super 8 2011.csv',
#  'Superbad 2007.csv',
#  'Sweeney Todd_ The Demon Barber of Fleet Street 2007.csv',
#  'Sweet and Lowdown 1999.csv',
#  'Tae Guk Gi_ The Brotherhood of War 2004.csv',
#  'Taken 2 2012.csv',
#  'Taken 2008.csv',
#  'Talladega Nights_ The Ballad of Ricky Bobby 2006.csv',
#  'Tangled 2010.csv',
#  'Tarzan 1999.csv',
#  'Taxi Driver 1976.csv',
#  'Ted 2012.csv',
#  'Tenacious D in the Pick of Destiny 2006.csv',
#  'Terminator 2_ Judgment Day 1991.csv',
#  'Terminator 3_ Rise of the Machines 2003.csv',
#  'Terminator Salvation 2009.csv',
#  'That Thing You Do! 1996.csv',
#  'The 13th Warrior 1999.csv',
#  'The 40-Year-Old Virgin 2005.csv',
#  'The Adjustment Bureau 2011.csv',
#  'The Adventures of Priscilla, Queen of the Desert 1994.csv',
#  'The Adventures of Tintin 2011.csv',
#  'The Alamo 2004.csv',
#  'The Amazing Spider-Man 2 2014.csv',
#  'The Amazing Spider-Man 2012.csv',
#  'The Artist 2011.csv',
#  'The Assassination of Jesse James by the Coward Robert Ford 2007.csv',
#  'The Avengers 2012.csv',
#  'The Aviator 2004.csv',
#  'The Babadook 2014.csv',
#  'The Battle of Algiers 1966.csv',
#  'The Beach 2000.csv',
#  'The Benchwarmers 2006.csv',
#  'The Best Years of Our Lives 1946.csv',
#  'The Big Blue 1988.csv',
#  'The Big Lebowski 1998.csv',
#  'The Big Short 2015.csv',
#  'The Birds 1963.csv',
#  'The Birth of a Nation 1915.csv',
#  'The Blair Witch Project 1999.csv',
#  'The Blind Side 2009.csv',
#  'The Bodyguard 1992.csv',
#  'The Book Thief 2013.csv',
#  'The Bourne Identity 2002.csv',
#  'The Bourne Legacy 2012.csv',
#  'The Bourne Supremacy 2004.csv',
#  'The Bourne Ultimatum 2007.csv',
#  'The Boy in the Striped Pajamas 2008.csv',
#  'The Breakfast Club 1985.csv',
#  'The Bridge on the River Kwai 1957.csv',
#  'The Butterfly Effect 2004.csv',
#  'The Cabin in the Woods 2011.csv',
#  'The Caine Mutiny 1954.csv',
#  'The Cannonball Run 1981.csv',
#  'The Chorus 2004.csv',
#  'The Chronicles of Narnia_ The Lion, the Witch and the Wardrobe 2005.csv',
#  'The Color of Money 1986.csv',
#  'The Commitments 1991.csv',
#  'The Conjuring 2 2016.csv',
#  'The Conjuring 2013.csv',
#  'The Croods 2013.csv',
#  'The Curious Case of Benjamin Button 2008.csv',
#  'The Da Vinci Code 2006.csv',
#  'The Danish Girl 2015.csv',
#  'The Dark Knight 2008.csv',
#  'The Dark Knight Rises 2012.csv',
#  'The Day After Tomorrow 2004.csv',
#  'The Death of Stalin 2017.csv',
#  'The Deer Hunter 1978.csv',
#  'The Departed 2006.csv',
#  'The Descent 2005.csv',
#  'The Devil Wears Prada 2006.csv',
#  "The Devil's Advocate 1997.csv",
#  'The Dirty Dozen 1967.csv',
#  'The Disaster Artist 2017.csv',
#  'The Doors 1991.csv',
#  'The Double Life of Véronique 1991.csv',
#  'The Duchess 2008.csv',
#  'The Elephant Man 1980.csv',
#  "The Emperor's New Groove 2000.csv",
#  'The English Patient 1996.csv',
#  'The Equalizer 2014.csv',
#  'The Evil Dead 1981.csv',
#  'The Exorcist 1973.csv',
#  'The Expendables 2 2012.csv',
#  'The Expendables 2010.csv',
#  'The Fan 1996.csv',
#  'The Fast and the Furious 2001.csv',
#  'The Fault in Our Stars 2014.csv',
#  'The Favourite 2018.csv',
#  'The Fifth Element 1997.csv',
#  'The Fighter 2010.csv',
#  'The Finest Hours 2016.csv',
#  'The Flowers of War 2011.csv',
#  'The Fly 1986.csv',
#  'The Football Factory 2004.csv',
#  'The Fountain 2006.csv',
#  'The Game 1997.csv',
#  'The Girl Next Door 2004.csv',
#  'The Girl with the Dragon Tattoo 2009.csv',
#  'The Girl with the Dragon Tattoo 2011.csv',
#  'The Godfather 1972.csv',
#  'The Godfather_ Part II 1974.csv',
#  'The Godfather_ Part III 1990.csv',
#  'The Good Shepherd 2006.csv',
#  'The Graduate 1967.csv',
#  'The Grand Budapest Hotel 2014.csv',
#  'The Grapes of Wrath 1940.csv',
#  'The Great Dictator 1940.csv',
#  'The Great Escape 1963.csv',
#  'The Great Gatsby 2013.csv',
#  'The Great Raid 2005.csv',
#  'The Greatest Game Ever Played 2005.csv',
#  'The Greatest Showman 2017.csv',
#  'The Green Mile 1999.csv',
#  'The Guernsey Literary and Potato Peel Pie Society 2018.csv',
#  'The Hangover 2009.csv',
#  'The Hangover Part II 2011.csv',
#  'The Hangover Part III 2013.csv',
#  'The Happening 2008.csv',
#  'The Hateful Eight 2015.csv',
#  'The Hills Have Eyes 2006.csv',
#  'The Hobbit_ An Unexpected Journey 2012.csv',
#  'The Hobbit_ The Battle of the Five Armies 2014.csv',
#  'The Hobbit_ The Desolation of Smaug 2013.csv',
#  'The Holiday 2006.csv',
#  'The Hunger Games 2012.csv',
#  'The Hunger Games_ Catching Fire 2013.csv',
#  'The Hunger Games_ Mockingjay - Part 1 2014.csv',
#  'The Hurricane 1999.csv',
#  'The Hurt Locker 2008.csv',
#  'The Hustler 1961.csv',
#  'The Illusionist 2006.csv',
#  'The Imitation Game 2014.csv',
#  'The Impossible 2012.csv',
#  'The Incredible Hulk 2008.csv',
#  'The Incredibles 2004.csv',
#  'The Insider 1999.csv',
#  'The Intouchables 2011.csv',
#  'The Irishman 2019.csv',
#  'The Iron Giant 1999.csv',
#  'The Island 2005.csv',
#  'The Italian Job 2003.csv',
#  'The Jungle Book 1967.csv',
#  'The Killing Fields 1984.csv',
#  'The King 2019.csv',
#  "The King's Speech 2010.csv",
#  'The Last Emperor 1987.csv',
#  'The Last King of Scotland 2006.csv',
#  'The Last Legion 2007.csv',
#  'The Last Samurai 2003.csv',
#  'The Last Song 2010.csv',
#  'The Legend of 1900 1998.csv',
#  'The Legend of Bagger Vance 2000.csv',
#  'The Lego Movie 2014.csv',
#  'The Lion King 1994.csv',
#  'The Lion King 2019.csv',
#  'The Little Mermaid 1989.csv',
#  'The Lives of Others 2006.csv',
#  'The Lobster 2015.csv',
#  'The Longest Day 1962.csv',
#  'The Longest Yard 2005.csv',
#  'The Lord of the Rings_ The Fellowship of the Ring 2001.csv',
#  'The Lord of the Rings_ The Return of the King 2003.csv',
#  'The Lord of the Rings_ The Two Towers 2002.csv',
#  'The Lost City of Z 2016.csv',
#  'The Lost World_ Jurassic Park 1997.csv',
#  'The Love Guru 2008.csv',
#  'The Machinist 2004.csv',
#  'The Man Who Would Be King 1975.csv',
#  'The Martian 2015.csv',
#  'The Mask 1994.csv',
#  'The Matrix 1999.csv',
#  'The Matrix Reloaded 2003.csv',
#  'The Matrix Revolutions 2003.csv',
#  'The Maze Runner 2014.csv',
#  'The Men Who Stare at Goats 2009.csv',
#  'The Mission 1986.csv',
#  'The Mist 2007.csv',
#  'The Monuments Men 2014.csv',
#  'The Mountain II 2016.csv',
#  'The Mummy 1999.csv',
#  'The Mummy Returns 2001.csv',
#  'The Natural 1984.csv',
#  'The New World 2005.csv',
#  'The Nice Guys 2016.csv',
#  'The Nightmare Before Christmas 1993.csv',
#  'The Notebook 2004.csv',
#  'The Number 23 2007.csv',
#  'The Orphanage 2007.csv',
#  'The Other Boleyn Girl 2008.csv',
#  'The Others 2001.csv',
#  'The Ottoman Lieutenant 2017.csv',
#  'The Passion of Joan of Arc 1928.csv',
#  'The Patriot 2000.csv',
#  'The Perks of Being a Wallflower 2012.csv',
#  'The Pianist 2002.csv',
#  'The Piano 1993.csv',
#  'The Polar Express 2004.csv',
#  'The Prestige 2006.csv',
#  'The Princess Bride 1987.csv',
#  'The Producers 1967.csv',
#  'The Proposal 2009.csv',
#  'The Purge 2013.csv',
#  'The Pursuit of Happyness 2006.csv',
#  'The Queen 2006.csv',
#  'The Reader 2008.csv',
#  'The Red Violin 1998.csv',
#  'The Replacements 2000.csv',
#  'The Revenant 2015.csv',
#  'The Ring 2002.csv',
#  ...]

# %%
# For removing .csv for each component in the list
movie_name = []
for movie in reviewed_movie:
    if movie.count(".") == 1: 
        name = movie.split('.')[0]
        movie_name.append(name)
    else:
        for i in range(len(movie)-1,0,-1):
            if movie[i]=='.':
                movie_name.append(movie[:i])
                break
                
movie_name
# Out:
# ['10 Cloverfield Lane 2016',
#  '10 Things I Hate About You 1999',
#  '12 Angry Men 1957',
#  '12 Monkeys 1995',
#  '12 Strong 2018',
#  '12 Years a Slave 2013',
#  '127 Hours 2010',
#  '13 Hours 2016',
#  '1408 2007',
#  '1917 2019',
#  '1941 1979',
#  '2001_ A Space Odyssey 1968',
#  '2012 2009',
#  '21 2008',
#  '21 Jump Street 2012',
#  '22 Jump Street 2014',
#  '28 Days Later... 2002',
#  '28 Weeks Later 2007',
#  '3 Idiots 2009',
#  '30 Days of Night 2007',
#  '300 2006',
#  '3_10 to Yuma 2007',
#  '42 2013',
#  '50 First Dates 2004',
#  '500 Days of Summer 2009',
#  '50_50 2011',
#  '54 1998',
#  '8 Mile 2002',
#  'A Beautiful Mind 2001',
#  'A Bridge Too Far 1977',
#  "A Bug's Life 1998",
#  'A Clockwork Orange 1971',
#  "A Hard Day's Night 1964",
#  'A Night at the Roxbury 1998',
#  'A Nightmare on Elm Street 1984',
#  'A Quiet Place 2018',
#  'A Star Is Born 2018',
#  'A Walk to Remember 2002',
#  'About Time 2013',
#  'Abraham Lincoln_ Vampire Hunter 2012',
#  'Across the Universe 2007',
#  'Airlift 2016',
#  'Akira 1988',
#  'Aladdin 1992',
#  'Aladdin 2019',
#  'Alexander 2004',
#  'Ali 2001',
#  'Alice in Wonderland 2010',
#  'Alien 1979',
#  'Alien 3 1992',
#  'Alien vs. Predator 2004',
#  'Alien_ Covenant 2017',
#  'Alien_ Resurrection 1997',
#  'Aliens 1986',
#  'All Quiet on the Western Front 1930',
#  "All the President's Men 1976",
#  'Amadeus 1984',
#  'American Beauty 1999',
#  'American Gangster 2007',
#  'American History X 1998',
#  'American Hustle 2013',
#  'American Made 2017',
#  'American Pie 1999',
#  'American Psycho 2000',
#  'American Sniper 2014',
#  'Amélie 2001',
#  'Amistad 1997',
#  'Anchorman_ The Legend of Ron Burgundy 2004',
#  'Angels & Demons 2009',
#  'Annie Hall 1977',
#  'Annihilation 2018',
#  'Ant-Man 2015',
#  'Antz 1998',
#  'Any Given Sunday 1999',
#  'Apocalypse Now 1979',
#  'Apollo 13 1995',
#  'Aquaman 2018',
#  'Argo 2012',
#  'Armageddon 1998',
#  'Army of Darkness 1992',
#  'Arrival 2016',
#  'As Good as It Gets 1997',
#  'Atonement 2007',
#  'Au Revoir les Enfants 1987',
#  'August Rush 2007',
#  'Avatar 2009',
#  'Avengers_ Age of Ultron 2015',
#  'Avengers_ Endgame 2019',
#  'Avengers_ Infinity War 2018',
#  'BASEketball 1998',
#  'Baby Driver 2017',
#  'Back to the Future 1985',
#  'Back to the Future Part II 1989',
#  'Back to the Future Part III 1990',
#  'Bad Teacher 2011',
#  'Balls of Fury 2007',
#  'Barry Lyndon 1975',
#  'Batman Begins 2005',
#  'Batman Returns 1992',
#  'Batman v Superman_ Dawn of Justice 2016',
#  'Battleship Potemkin 1925',
#  'Beasts of No Nation 2015',
#  'Beauty and the Beast 1991',
#  'Beauty and the Beast 2017',
#  'Beetlejuice 1988',
#  'Before Sunrise 1995',
#  'Before Sunset 2004',
#  'Begin Again 2013',
#  'Behind The Candelabra 2013',
#  'Being John Malkovich 1999',
#  'Ben-Hur 1959',
#  'Beowulf 2007',
#  'Bhaag Milkha Bhaag 2013',
#  'Big Fish 2003',
#  'Big Hero 6 2014',
#  "Bill & Ted's Excellent Adventure 1989",
#  'Billy Elliot 2000',
#  'Bird Box 2018',
#  'Birdman or (The Unexpected Virtue of Ignorance) 2014',
#  'BlacKkKlansman 2018',
#  'Black Book 2006',
#  'Black Hawk Down 2001',
#  'Black Mass 2015',
#  'Black Panther 2018',
#  'Black Snake Moan 2006',
#  'Black Swan 2010',
#  'Blade 1998',
#  'Blade II 2002',
#  'Blade Runner 1982',
#  'Blade Runner 2049 2017',
#  'Blades of Glory 2007',
#  'Blood Diamond 2006',
#  'Bloody Sunday 2002',
#  'Blow 2001',
#  'Blue Crush 2002',
#  'Bohemian Rhapsody 2018',
#  'Bolt 2008',
#  'Borat_ Cultural Learnings of America for Make Benefit Glorious Nation of Kazakhstan 2006',
#  'Born on the Fourth of July 1989',
#  "Bram Stoker's Dracula 1992",
#  'Brave 2012',
#  'Braveheart 1995',
#  'Bridesmaids 2011',
#  'Bridge of Spies 2015',
#  "Bridget Jones's Diary 2001",
#  'Bring It On 2000',
#  'Brokeback Mountain 2005',
#  'Bruce Almighty 2003',
#  'Bull Durham 1988',
#  'Burlesque 2010',
#  'Burn After Reading 2008',
#  'Butch Cassidy and the Sundance Kid 1969',
#  'Caddyshack 1980',
#  'Call Me by Your Name 2017',
#  'Capote 2005',
#  'Captain America_ Civil War 2016',
#  'Captain America_ The First Avenger 2011',
#  'Captain America_ The Winter Soldier 2014',
#  "Captain Corelli's Mandolin 2001",
#  'Captain Marvel 2019',
#  'Captain Phillips 2013',
#  'Carrie 1976',
#  'Cars 2 2011',
#  'Cars 2006',
#  'Casablanca 1942',
#  'Casino 1995',
#  'Casino Royale 2006',
#  'Cast Away 2000',
#  'Castle in the Sky 1986',
#  'Casualties of War 1989',
#  'Catch Me If You Can 2002',
#  'Catch-22 1970',
#  'Centurion 2010',
#  'Chak de! India 2007',
#  'Changeling 2008',
#  'Chariots of Fire 1981',
#  'Charlie and the Chocolate Factory 2005',
#  'Chicken Run 2000',
#  'Child 44 2015',
#  'Children of Heaven 1997',
#  'Children of Men 2006',
#  'Chinatown 1974',
#  'Cinderella 1950',
#  'Cinderella Man 2005',
#  'Citizen Kane 1941',
#  'City of God 2002',
#  'Clash of the Titans 2010',
#  'Click 2006',
#  'Climax 2018',
#  'Closer 2004',
#  'Cloud Atlas 2012',
#  'Cloudy with a Chance of Meatballs 2009',
#  'Cloverfield 2008',
#  'Coach Carter 2005',
#  'Coco 2017',
#  'Coffee and Cigarettes 2003',
#  'Cold Mountain 2003',
#  'Cold War 2018',
#  'Collateral 2004',
#  'Come and See 1985',
#  'Con Air 1997',
#  'Concussion 2015',
#  'Conquest 1453 2012',
#  'Constantine 2005',
#  'Contact 1997',
#  'Control 2007',
#  'Coraline 2009',
#  'Coriolanus 2011',
#  'Corpse Bride 2005',
#  'Coyote Ugly 2000',
#  'Crash 2004',
#  'Crazy Heart 2009',
#  'Crazy, Stupid, Love 2011',
#  'Creed 2015',
#  'Creed II 2018',
#  'Cross of Iron 1977',
#  'Crouching Tiger, Hidden Dragon 2000',
#  'Cube 1997',
#  'Da 5 Bloods 2020',
#  'Dallas Buyers Club 2013',
#  'Dangal 2016',
#  'Dark City 1998',
#  'Dark Shadows 2012',
#  'Darkest Hour 2017',
#  'Dawn of the Dead 2004',
#  'Days of Thunder 1990',
#  'Dead Poets Society 1989',
#  'Deadpool 2 2018',
#  'Deadpool 2016',
#  'Dear John 2010',
#  'Deepwater Horizon 2016',
#  'Defiance 2008',
#  'Deja Vu 2006',
#  'Departures 2008',
#  'Despicable Me 2 2013',
#  'Despicable Me 2010',
#  'Detroit 2017',
#  'Detroit Rock City 1999',
#  'Die Hard 1988',
#  'Die Hard 2 1990',
#  'Die Hard with a Vengeance 1995',
#  'Dirty Dancing 1987',
#  'District 9 2009',
#  'Disturbia 2007',
#  'Divergent 2014',
#  'Django Unchained 2012',
#  'Doctor Strange 2016',
#  'Doctor Zhivago 1965',
#  'Dodgeball 2004',
#  'Dog Day Afternoon 1975',
#  'Don Jon 2013',
#  "Don't Breathe 2016",
#  'Donnie Brasco 1997',
#  'Donnie Darko 2001',
#  'Downfall 2004',
#  'Dr. Strangelove or_ How I Learned to Stop Worrying and Love the Bomb 1964',
#  'Draft Day 2014',
#  'Drag Me to Hell 2009',
#  'Dreamgirls 2006',
#  'Drive 2011',
#  'Driven 2001',
#  'Duck Soup 1933',
#  'Duck You Sucker 1971',
#  'Dumb and Dumber 1994',
#  'Dunkirk 2017',
#  'E.T. the Extra-Terrestrial 1982',
#  'Easy A 2010',
#  'Ed Wood 1994',
#  'Edge of Tomorrow 2014',
#  'Edward Scissorhands 1990',
#  'Elf 2003',
#  'Elizabeth 1998',
#  'Elizabeth_ The Golden Age 2007',
#  'Elysium 2013',
#  'Empire Records 1995',
#  'Empire of the Sun 1987',
#  'Enchanted 2007',
#  "Ender's Game 2013",
#  'Enemy at the Gates 2001',
#  'Erin Brockovich 2000',
#  'Eternal Sunshine of the Spotless Mind 2004',
#  'Eurovision Song Contest_ The Story of Fire Saga 2020',
#  'Event Horizon 1997',
#  'Everest 2015',
#  'Evil Dead 2013',
#  'Evil Dead II 1987',
#  'Ex Machina 2014',
#  'Eyes Wide Shut 1999',
#  'Face_Off 1997',
#  'Fantastic 4_ Rise of the Silver Surfer 2007',
#  'Fantastic Beasts and Where to Find Them 2016',
#  'Fantastic Four 2005',
#  'Fantastic Mr. Fox 2009',
#  'Fargo 1996',
#  'Fast & Furious 6 2013',
#  'Fast Five 2011',
#  'Fifty Shades of Grey 2015',
#  'Fight Club 1999',
#  'Final Destination 2 2003',
#  'Final Destination 2000',
#  'Finding Dory 2016',
#  'Finding Nemo 2003',
#  'Finding Neverland 2004',
#  'First Man 2018',
#  'Flashdance 1983',
#  'Flight 2012',
#  'Footloose 1984',
#  'Footloose 2011',
#  'For Love of the Game 1999',
#  'Ford v Ferrari 2019',
#  'Forgetting Sarah Marshall 2008',
#  'Forrest Gump 1994',
#  'Foxcatcher 2014',
#  'Frank 2014',
#  'Friday Night Lights 2004',
#  'Friends with Benefits 2011',
#  'From Dusk Till Dawn 1996',
#  'From Hell 2001',
#  'From Here to Eternity 1953',
#  'Frost_Nixon 2008',
#  'Frozen 2013',
#  'Full Metal Jacket 1987',
#  'Furious 7 2015',
#  'Fury 2014',
#  'G.I. Jane 1997',
#  'Gandhi 1982',
#  'Gangs of New York 2002',
#  'Garden State 2004',
#  'Get Him to the Greek 2010',
#  'Get Out 2017',
#  'Gettysburg 1993',
#  'Ghost 1990',
#  'Ghost Rider 2007',
#  'Ghostbusters 1984',
#  'Girl, Interrupted 1999',
#  'Gladiator 2000',
#  'Glory 1989',
#  'Glory Road 2006',
#  'Godzilla 2014',
#  'Gone Baby Gone 2007',
#  'Gone Girl 2014',
#  'Gone with the Wind 1939',
#  'Good Morning, Vietnam 1987',
#  'Good Night, and Good Luck. 2005',
#  'Good Will Hunting 1997',
#  'Goodfellas 1990',
#  'Goon 2011',
#  'Gran Torino 2008',
#  'Grave of the Fireflies 1988',
#  'Gravity 2013',
#  'Grease 1978',
#  'Green Book 2018',
#  'Green Room 2015',
#  'Green Street Hooligans 2005',
#  'Gremlins 1984',
#  'Grindhouse 2007',
#  'Groundhog Day 1993',
#  'Grudge Match 2013',
#  'Guardians of the Galaxy 2014',
#  'Guardians of the Galaxy Vol. 2 2017',
#  'Hacksaw Ridge 2016',
#  'Hail, Caesar! 2016',
#  'Halloween 1978',
#  'Hancock 2008',
#  'Hansel & Gretel_ Witch Hunters 2013',
#  'Happy Feet 2006',
#  'Happy Gilmore 1996',
#  'Happy New Year 2014',
#  'Hardball 2001',
#  'Harry Potter and the Chamber of Secrets 2002',
#  'Harry Potter and the Deathly Hallows_ Part 1 2010',
#  'Harry Potter and the Deathly Hallows_ Part 2 2011',
#  'Harry Potter and the Goblet of Fire 2005',
#  'Harry Potter and the Order of the Phoenix 2007',
#  'Harry Potter and the Prisoner of Azkaban 2004',
#  "Harry Potter and the Sorcerer's Stone 2001",
#  "Hart's War 2002",
#  'He Got Game 1998',
#  'Heartbreak Ridge 1986',
#  'Heat 1995',
#  'Hedwig and the Angry Inch 2001',
#  'Hellboy 2004',
#  'Hellboy II_ The Golden Army 2008',
#  'Her 2013',
#  'Hercules 1997',
#  'Here Comes the Boom 2012',
#  'Hereditary 2018',
#  'Hero 2002',
#  'Hidden Figures 2016',
#  'High Fidelity 2000',
#  'Hitch 2005',
#  'Home Alone 1990',
#  'Home Alone 2_ Lost in New York 1992',
#  'Honey 2003',
#  'Hoosiers 1986',
#  'Horrible Bosses 2011',
#  'Hostel 2005',
#  'Hot Fuzz 2007',
#  'Hot Rod 2007',
#  'Hotel Mumbai 2018',
#  'Hotel Rwanda 2004',
#  'Hotel Transylvania 2012',
#  'How to Lose a Guy in 10 Days 2003',
#  'How to Train Your Dragon 2 2014',
#  'How to Train Your Dragon 2010',
#  "Howl's Moving Castle 2004",
#  'Hugo 2011',
#  'Hustle & Flow 2005',
#  'I Am Legend 2007',
#  'I Love You, Man 2009',
#  "I'm Not There 2007",
#  'I, Robot 2004',
#  'I, Tonya 2017',
#  'Ice Age 2002',
#  'Ice Age_ Continental Drift 2012',
#  'Ice Age_ Dawn of the Dinosaurs 2009',
#  'Ice Age_ The Meltdown 2006',
#  'Identity 2003',
#  'If I Stay 2014',
#  'In Bruges 2008',
#  'In Time 2011',
#  'In the Land of Blood and Honey 2011',
#  'In the Name of the Father 1993',
#  'Incendies 2010',
#  'Inception 2010',
#  'Incredibles 2 2018',
#  'Independence Day 1996',
#  'Indiana Jones and the Last Crusade 1989',
#  'Inglourious Basterds 2009',
#  'Inside Llewyn Davis 2013',
#  'Inside Man 2006',
#  'Inside Out 2015',
#  'Insidious 2010',
#  'Insidious_ Chapter 2 2013',
#  'Insomnia 2002',
#  'Interstellar 2014',
#  'Interview with the Vampire_ The Vampire Chronicles 1994',
#  'Into the Wild 2007',
#  'Invictus 2009',
#  'Invincible 2006',
#  'Ip Man 2008',
#  'Iron Man 2 2010',
#  'Iron Man 2008',
#  'Iron Man 3 2013',
#  'It 2017',
#  'It Chapter Two 2019',
#  'It Follows 2014',
#  "It's a Wonderful Life 1946",
#  'JFK 1991',
#  'Jack Reacher 2012',
#  'Jackie 2016',
#  'Jackie Brown 1997',
#  'Jarhead 2005',
#  'Jaws 1975',
#  'Jerry Maguire 1996',
#  'Jersey Boys 2014',
#  'John Wick 2014',
#  'John Wick_ Chapter 2 2017',
#  'Jojo Rabbit 2019',
#  'Joker 2019',
#  'Joy 2015',
#  'Judgment at Nuremberg 1961',
#  'Juno 2007',
#  'Jurassic Park 1993',
#  'Jurassic World 2015',
#  'Just Go with It 2011',
#  'Justice League 2017',
#  'K-19_ The Widowmaker 2002',
#  'Kagemusha 1980',
#  "Kelly's Heroes 1970",
#  'Kick-Ass 2010',
#  'Kickboxer 1989',
#  'Kill Bill_ Vol. 1 2003',
#  'Kill Bill_ Vol. 2 2004',
#  'Kingpin 1996',
#  'Kingsman_ The Secret Service 2014',
#  'Knives Out 2019',
#  'Knocked Up 2007',
#  'Knowing 2009',
#  'Kong_ Skull Island 2017',
#  'Kung Fu Panda 2 2011',
#  'Kung Fu Panda 2008',
#  'L.A. Confidential 1997',
#  'La Grande Illusion 1937',
#  'La La Land 2016',
#  'La Vie En Rose 2007',
#  'Last Flag Flying 2017',
#  'Law Abiding Citizen 2009',
#  'Lawrence of Arabia 1962',
#  'Legend 2015',
#  'Legends of the Fall 1994',
#  'Les Misérables 2012',
#  'Léon_ The Professional 1994',
#  'Liar Liar 1997',
#  'Life 2017',
#  'Life Is Beautiful 1997',
#  'Life of Pi 2012',
#  'Lifeboat 1944',
#  'Lilo & Stitch 2002',
#  'Limitless 2011',
#  'Lincoln 2012',
#  'Lion 2016',
#  'Little Boy 2015',
#  'Little Miss Sunshine 2006',
#  'Live Free or Die Hard 2007',
#  'Lock, Stock and Two Smoking Barrels 1998',
#  'Logan 2017',
#  'Lone Survivor 2013',
#  'Looper 2012',
#  'Lord of War 2005',
#  'Lords of Dogtown 2005',
#  'Lost in Translation 2003',
#  'Love & Mercy 2014',
#  'Love Actually 2003',
#  'Love and Death 1975',
#  'Lucky Number Slevin 2006',
#  'Lucy 2014',
#  'M.S. Dhoni_ The Untold Story 2016',
#  'MASH 1970',
#  'Macbeth 2015',
#  'Mad Max_ Fury Road 2015',
#  'Madagascar 2005',
#  "Madagascar 3_ Europe's Most Wanted 2012",
#  'Madagascar_ Escape 2 Africa 2008',
#  'Magic Mike XXL 2015',
#  'Major League 1989',
#  'Malcolm X 1992',
#  'Mama 2013',
#  'Mamma Mia! 2008',
#  'Man of Steel 2013',
#  'Man on Fire 2004',
#  'Man on the Moon 1999',
#  'Marie Antoinette 2006',
#  'Marriage Story 2019',
#  'Mary and Max 2009',
#  'Match Point 2005',
#  'McFarland, USA 2015',
#  'Me Before You 2016',
#  'Meet Joe Black 1998',
#  'Meet the Fockers 2004',
#  'Meet the Parents 2000',
#  'Megamind 2010',
#  'Memento 2000',
#  'Men in Black 1997',
#  'Men in Black 3 2012',
#  'Men in Black II 2002',
#  'Midnight in Paris 2011',
#  'Midsommar 2019',
#  'Midway 2019',
#  'Milk 2008',
#  'Million Dollar Arm 2014',
#  'Million Dollar Baby 2004',
#  'Minions 2015',
#  'Minority Report 2002',
#  'Miracle 2004',
#  'Mission_ Impossible - Ghost Protocol 2011',
#  'Mission_ Impossible - Rogue Nation 2015',
#  'Mission_ Impossible 1996',
#  'Mission_ Impossible II 2000',
#  'Mission_ Impossible III 2006',
#  'Mississippi Burning 1988',
#  'Moana 2016',
#  "Molly's Game 2017",
#  'Moneyball 2011',
#  'Monster 2003',
#  'Monsters University 2013',
#  'Monsters vs. Aliens 2009',
#  'Monsters, Inc. 2001',
#  'Monty Python and the Holy Grail 1975',
#  "Monty Python's Life of Brian 1979",
#  'Moon 2009',
#  'Moonrise Kingdom 2012',
#  'Mother! 2017',
#  'Moulin Rouge! 2001',
#  'Mr. & Mrs. Smith 2005',
#  "Mr. Holland's Opus 1995",
#  'Mr. Nobody 2009',
#  'Mudbound 2017',
#  'Mulan 1998',
#  'Mulholland Drive 2001',
#  'Munich 2005',
#  'Murder on the Orient Express 2017',
#  'Music and Lyrics 2007',
#  'My Neighbor Totoro 1988',
#  'Mystic River 2003',
#  'Nacho Libre 2006',
#  'National Treasure 2004',
#  'National Treasure_ Book of Secrets 2007',
#  'Nausicaä of the Valley of the Wind 1984',
#  'Never Back Down 2008',
#  "Nick and Norah's Infinite Playlist 2008",
#  'Nightcrawler 2014',
#  'No Country for Old Men 2007',
#  "No Man's Land 2001",
#  'No Strings Attached 2011',
#  'Non-Stop 2014',
#  'North by Northwest 1959',
#  'Notting Hill 1999',
#  'Now You See Me 2013',
#  'O Brother, Where Art Thou_ 2000',
#  'Oblivion 2013',
#  "Ocean's Eleven 2001",
#  "Ocean's Thirteen 2007",
#  "Ocean's Twelve 2004",
#  'Oldboy 2003',
#  'Once 2007',
#  'Once Upon a Time in America 1984',
#  'Once Upon a Time... in Hollywood 2019',
#  "One Flew Over the Cuckoo's Nest 1975",
#  'One Hundred and One Dalmatians 1961',
#  'Orphan 2009',
#  'Over the Hedge 2006',
#  'Over the Top 1987',
#  'P.S. I Love You 2007',
#  'Pacific Rim 2013',
#  "Pan's Labyrinth 2006",
#  'Paranormal Activity 2007',
#  'Parasite 2019',
#  'Passengers 2016',
#  'Paths of Glory 1957',
#  'Patton 1970',
#  'Pawn Sacrifice 2014',
#  'Peaceful Warrior 2006',
#  'Pearl Harbor 2001',
#  'Pi 1998',
#  'Pineapple Express 2008',
#  'Pirate Radio 2009',
#  "Pirates of the Caribbean_ At World's End 2007",
#  "Pirates of the Caribbean_ Dead Man's Chest 2006",
#  'Pirates of the Caribbean_ Dead Men Tell No Tales 2017',
#  'Pirates of the Caribbean_ On Stranger Tides 2011',
#  'Pirates of the Caribbean_ The Curse of the Black Pearl 2003',
#  'Pitch Black 2000',
#  'Pitch Perfect 2 2015',
#  'Pitch Perfect 2012',
#  'Pitch Perfect 3 2017',
#  'Platoon 1986',
#  'Pocahontas 1995',
#  'Point Break 2015',
#  'Popstar_ Never Stop Never Stopping 2016',
#  'Predator 1987',
#  'Pretty Woman 1990',
#  'Pride & Prejudice 2005',
#  'Prince of Persia_ The Sands of Time 2010',
#  'Princess Mononoke 1997',
#  'Prisoners 2013',
#  'Prometheus 2012',
#  'Psycho 1960',
#  'Public Enemies 2009',
#  'Pulp Fiction 1994',
#  'Puss in Boots 2011',
#  'Quantum of Solace 2008',
#  'Quiz Show 1994',
#  'RED 2010',
#  'Rab Ne Bana Di Jodi 2008',
#  'Radio 2003',
#  'Raging Bull 1980',
#  'Raiders of the Lost Ark 1981',
#  'Ran 1985',
#  'Rang De Basanti 2006',
#  'Rango 2011',
#  'Ratatouille 2007',
#  'Ray 2004',
#  'Ready Player One 2018',
#  'Rear Window 1954',
#  'Remember the Titans 2000',
#  'Requiem for a Dream 2000',
#  'Reservoir Dogs 1992',
#  'Resident Evil 2002',
#  'Resident Evil_ Afterlife 2010',
#  'Resident Evil_ Apocalypse 2004',
#  'Resident Evil_ Extinction 2007',
#  'Revolutionary Road 2008',
#  'Rio 2011',
#  'Rise of the Guardians 2012',
#  'Rise of the Planet of the Apes 2011',
#  'Rock Star 2001',
#  'Rocketman 2019',
#  'Rockstar 2011',
#  'Rocky 1976',
#  'Rocky II 1979',
#  'Rocky III 1982',
#  'Rocky IV 1985',
#  'Rocky V 1990',
#  'Rogue One_ A Star Wars Story 2016',
#  'Romeo + Juliet 1996',
#  'Room 2015',
#  "Rosemary's Baby 1968",
#  'Rudy 1993',
#  'Rules of Engagement 2000',
#  'Run, Fat Boy, Run 2007',
#  'Rush 2013',
#  'Saboteur 1942',
#  'Saints and Soldiers 2003',
#  'Salò, or the 120 Days of Sodom 1975',
#  'Salt 2010',
#  'Saturday Night Fever 1977',
#  'Sausage Party 2016',
#  'Save the Last Dance 2001',
#  'Saving Mr. Banks 2013',
#  'Saving Private Ryan 1998',
#  'Saw 2004',
#  'Saw II 2005',
#  'Saw III 2006',
#  'Scarface 1983',
#  'Scary Movie 2 2001',
#  "Schindler's List 1993",
#  'School of Rock 2003',
#  'Scott Pilgrim vs. the World 2010',
#  'Scream 1996',
#  'Scream 2 1997',
#  'Se7en 1995',
#  'Seabiscuit 2003',
#  'Selma 2014',
#  'Semi-Pro 2008',
#  'Seven Years in Tibet 1997',
#  'Shakespeare in Love 1998',
#  'Shall We Dance 2004',
#  'Shark Tale 2004',
#  'Shaun of the Dead 2004',
#  "She's the Man 2006",
#  'Sherlock Holmes 2009',
#  'Sherlock Holmes_ A Game of Shadows 2011',
#  'Shine 1996',
#  'Shooter 2007',
#  'Shrek 2 2004',
#  'Shrek 2001',
#  'Shrek Forever After 2010',
#  'Shrek the Third 2007',
#  'Shutter Island 2010',
#  'Sicario 2015',
#  'Signs 2002',
#  'Silence 2016',
#  'Silent Hill 2006',
#  'Silver Linings Playbook 2012',
#  'Sin City 2005',
#  'Sing Street 2016',
#  "Singin' in the Rain 1952",
#  'Sinister 2012',
#  'Skyfall 2012',
#  'Slap Shot 1977',
#  'Sleepy Hollow 1999',
#  'Slumdog Millionaire 2008',
#  'Snatch 2000',
#  'Snow White and the Seven Dwarfs 1937',
#  'Snowden 2016',
#  'Some Like It Hot 1959',
#  'Son of Saul 2015',
#  'Source Code 2011',
#  'South Park_ Bigger, Longer & Uncut 1999',
#  'Southpaw 2015',
#  'Space Jam 1996',
#  'Spartacus 1960',
#  'Spectre 2015',
#  'Speed 1994',
#  'Spice World 1997',
#  'Spider-Man 2 2004',
#  'Spider-Man 2002',
#  'Spider-Man 3 2007',
#  'Spider-Man_ Homecoming 2017',
#  'Spider-Man_ Into the Spider-Verse 2018',
#  'Spirited Away 2001',
#  'Split 2016',
#  'Spotlight 2015',
#  'Stalag 17 1953',
#  'Stalingrad 1993',
#  'Star Trek 2009',
#  'Star Trek Into Darkness 2013',
#  'Star Wars_ Episode I - The Phantom Menace 1999',
#  'Star Wars_ Episode II - Attack of the Clones 2002',
#  'Star Wars_ Episode III - Revenge of the Sith 2005',
#  'Star Wars_ Episode IV - A New Hope 1977',
#  'Star Wars_ Episode IX - The Rise of Skywalker 2019',
#  'Star Wars_ Episode V - The Empire Strikes Back 1980',
#  'Star Wars_ Episode VI - Return of the Jedi 1983',
#  'Star Wars_ Episode VII - The Force Awakens 2015',
#  'Star Wars_ Episode VIII - The Last Jedi 2017',
#  'Stardust 2007',
#  'Step Up 2006',
#  'Step Up 2_ The Streets 2008',
#  'Steve Jobs 2015',
#  'Stop-Loss 2008',
#  'Straight Outta Compton 2015',
#  'Stranger Than Fiction 2006',
#  'Stripes 1981',
#  'Sucker Punch 2011',
#  'Suicide Squad 2016',
#  'Sully 2016',
#  'Sultan 2016',
#  'Super 8 2011',
#  'Superbad 2007',
#  'Sweeney Todd_ The Demon Barber of Fleet Street 2007',
#  'Sweet and Lowdown 1999',
#  'Tae Guk Gi_ The Brotherhood of War 2004',
#  'Taken 2 2012',
#  'Taken 2008',
#  'Talladega Nights_ The Ballad of Ricky Bobby 2006',
#  'Tangled 2010',
#  'Tarzan 1999',
#  'Taxi Driver 1976',
#  'Ted 2012',
#  'Tenacious D in the Pick of Destiny 2006',
#  'Terminator 2_ Judgment Day 1991',
#  'Terminator 3_ Rise of the Machines 2003',
#  'Terminator Salvation 2009',
#  'That Thing You Do! 1996',
#  'The 13th Warrior 1999',
#  'The 40-Year-Old Virgin 2005',
#  'The Adjustment Bureau 2011',
#  'The Adventures of Priscilla, Queen of the Desert 1994',
#  'The Adventures of Tintin 2011',
#  'The Alamo 2004',
#  'The Amazing Spider-Man 2 2014',
#  'The Amazing Spider-Man 2012',
#  'The Artist 2011',
#  'The Assassination of Jesse James by the Coward Robert Ford 2007',
#  'The Avengers 2012',
#  'The Aviator 2004',
#  'The Babadook 2014',
#  'The Battle of Algiers 1966',
#  'The Beach 2000',
#  'The Benchwarmers 2006',
#  'The Best Years of Our Lives 1946',
#  'The Big Blue 1988',
#  'The Big Lebowski 1998',
#  'The Big Short 2015',
#  'The Birds 1963',
#  'The Birth of a Nation 1915',
#  'The Blair Witch Project 1999',
#  'The Blind Side 2009',
#  'The Bodyguard 1992',
#  'The Book Thief 2013',
#  'The Bourne Identity 2002',
#  'The Bourne Legacy 2012',
#  'The Bourne Supremacy 2004',
#  'The Bourne Ultimatum 2007',
#  'The Boy in the Striped Pajamas 2008',
#  'The Breakfast Club 1985',
#  'The Bridge on the River Kwai 1957',
#  'The Butterfly Effect 2004',
#  'The Cabin in the Woods 2011',
#  'The Caine Mutiny 1954',
#  'The Cannonball Run 1981',
#  'The Chorus 2004',
#  'The Chronicles of Narnia_ The Lion, the Witch and the Wardrobe 2005',
#  'The Color of Money 1986',
#  'The Commitments 1991',
#  'The Conjuring 2 2016',
#  'The Conjuring 2013',
#  'The Croods 2013',
#  'The Curious Case of Benjamin Button 2008',
#  'The Da Vinci Code 2006',
#  'The Danish Girl 2015',
#  'The Dark Knight 2008',
#  'The Dark Knight Rises 2012',
#  'The Day After Tomorrow 2004',
#  'The Death of Stalin 2017',
#  'The Deer Hunter 1978',
#  'The Departed 2006',
#  'The Descent 2005',
#  'The Devil Wears Prada 2006',
#  "The Devil's Advocate 1997",
#  'The Dirty Dozen 1967',
#  'The Disaster Artist 2017',
#  'The Doors 1991',
#  'The Double Life of Véronique 1991',
#  'The Duchess 2008',
#  'The Elephant Man 1980',
#  "The Emperor's New Groove 2000",
#  'The English Patient 1996',
#  'The Equalizer 2014',
#  'The Evil Dead 1981',
#  'The Exorcist 1973',
#  'The Expendables 2 2012',
#  'The Expendables 2010',
#  'The Fan 1996',
#  'The Fast and the Furious 2001',
#  'The Fault in Our Stars 2014',
#  'The Favourite 2018',
#  'The Fifth Element 1997',
#  'The Fighter 2010',
#  'The Finest Hours 2016',
#  'The Flowers of War 2011',
#  'The Fly 1986',
#  'The Football Factory 2004',
#  'The Fountain 2006',
#  'The Game 1997',
#  'The Girl Next Door 2004',
#  'The Girl with the Dragon Tattoo 2009',
#  'The Girl with the Dragon Tattoo 2011',
#  'The Godfather 1972',
#  'The Godfather_ Part II 1974',
#  'The Godfather_ Part III 1990',
#  'The Good Shepherd 2006',
#  'The Graduate 1967',
#  'The Grand Budapest Hotel 2014',
#  'The Grapes of Wrath 1940',
#  'The Great Dictator 1940',
#  'The Great Escape 1963',
#  'The Great Gatsby 2013',
#  'The Great Raid 2005',
#  'The Greatest Game Ever Played 2005',
#  'The Greatest Showman 2017',
#  'The Green Mile 1999',
#  'The Guernsey Literary and Potato Peel Pie Society 2018',
#  'The Hangover 2009',
#  'The Hangover Part II 2011',
#  'The Hangover Part III 2013',
#  'The Happening 2008',
#  'The Hateful Eight 2015',
#  'The Hills Have Eyes 2006',
#  'The Hobbit_ An Unexpected Journey 2012',
#  'The Hobbit_ The Battle of the Five Armies 2014',
#  'The Hobbit_ The Desolation of Smaug 2013',
#  'The Holiday 2006',
#  'The Hunger Games 2012',
#  'The Hunger Games_ Catching Fire 2013',
#  'The Hunger Games_ Mockingjay - Part 1 2014',
#  'The Hurricane 1999',
#  'The Hurt Locker 2008',
#  'The Hustler 1961',
#  'The Illusionist 2006',
#  'The Imitation Game 2014',
#  'The Impossible 2012',
#  'The Incredible Hulk 2008',
#  'The Incredibles 2004',
#  'The Insider 1999',
#  'The Intouchables 2011',
#  'The Irishman 2019',
#  'The Iron Giant 1999',
#  'The Island 2005',
#  'The Italian Job 2003',
#  'The Jungle Book 1967',
#  'The Killing Fields 1984',
#  'The King 2019',
#  "The King's Speech 2010",
#  'The Last Emperor 1987',
#  'The Last King of Scotland 2006',
#  'The Last Legion 2007',
#  'The Last Samurai 2003',
#  'The Last Song 2010',
#  'The Legend of 1900 1998',
#  'The Legend of Bagger Vance 2000',
#  'The Lego Movie 2014',
#  'The Lion King 1994',
#  'The Lion King 2019',
#  'The Little Mermaid 1989',
#  'The Lives of Others 2006',
#  'The Lobster 2015',
#  'The Longest Day 1962',
#  'The Longest Yard 2005',
#  'The Lord of the Rings_ The Fellowship of the Ring 2001',
#  'The Lord of the Rings_ The Return of the King 2003',
#  'The Lord of the Rings_ The Two Towers 2002',
#  'The Lost City of Z 2016',
#  'The Lost World_ Jurassic Park 1997',
#  'The Love Guru 2008',
#  'The Machinist 2004',
#  'The Man Who Would Be King 1975',
#  'The Martian 2015',
#  'The Mask 1994',
#  'The Matrix 1999',
#  'The Matrix Reloaded 2003',
#  'The Matrix Revolutions 2003',
#  'The Maze Runner 2014',
#  'The Men Who Stare at Goats 2009',
#  'The Mission 1986',
#  'The Mist 2007',
#  'The Monuments Men 2014',
#  'The Mountain II 2016',
#  'The Mummy 1999',
#  'The Mummy Returns 2001',
#  'The Natural 1984',
#  'The New World 2005',
#  'The Nice Guys 2016',
#  'The Nightmare Before Christmas 1993',
#  'The Notebook 2004',
#  'The Number 23 2007',
#  'The Orphanage 2007',
#  'The Other Boleyn Girl 2008',
#  'The Others 2001',
#  'The Ottoman Lieutenant 2017',
#  'The Passion of Joan of Arc 1928',
#  'The Patriot 2000',
#  'The Perks of Being a Wallflower 2012',
#  'The Pianist 2002',
#  'The Piano 1993',
#  'The Polar Express 2004',
#  'The Prestige 2006',
#  'The Princess Bride 1987',
#  'The Producers 1967',
#  'The Proposal 2009',
#  'The Purge 2013',
#  'The Pursuit of Happyness 2006',
#  'The Queen 2006',
#  'The Reader 2008',
#  'The Red Violin 1998',
#  'The Replacements 2000',
#  'The Revenant 2015',
#  'The Ring 2002',
#  ...]

# %%
# str = 'Come and See 1985'
# str[:-5]

# %%
movie_reviewed = []

for i in movie_name:
  movie_reviewed.append(i[:-5])

# movie_name_new
len(movie_reviewed)
# Out:
# 1150

# %%
movie_reviewed[0]
# Out:
# '10 Cloverfield Lane'

# %%
df_5000 = pd.read_csv('/content/drive/MyDrive/DTU/Computational Tools for Data Science/project/dataset_movie/tmdb_5000_movies.csv')
df_5000.head(320)
# Out:
#         budget                                             genres  \
# 0    237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1    300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2    245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3    250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4    260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ..         ...                                                ...
# 315   98000000  [{"id": 12, "name": "Adventure"}, {"id": 28, "...
# 316  100000000  [{"id": 18, "name": "Drama"}, {"id": 36, "name...
# 317   94000000  [{"id": 18, "name": "Drama"}, {"id": 36, "name...
# 318   85000000  [{"id": 16, "name": "Animation"}, {"id": 35, "...
# 319   90000000  [{"id": 28, "name": "Action"}, {"id": 35, "nam...
#
#                                            homepage      id  \
# 0                       http://www.avatarmovie.com/   19995
# 1      http://disney.go.com/disneypictures/pirates/     285
# 2       http://www.sonypictures.com/movies/spectre/  206647
# 3                http://www.thedarkknightrises.com/   49026
# 4              http://movies.disney.com/john-carter   49529
# ..                                              ...     ...
# 315                                             NaN    1734
# 316      http://video.movies.go.com/gangsofnewyork/    3131
# 317            http://www.theflowersofwarmovie.com/   76758
# 318  http://www.sonypictures.com/homevideo/surfsup/    9408
# 319                                             NaN    9890
#
#                                               keywords original_language  \
# 0    [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1    [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2    [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3    [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4    [{"id": 818, "name": "based on novel"}, {"id":...                en
# ..                                                 ...               ...
# 315  [{"id": 5153, "name": "son"}, {"id": 157894, "...                en
# 316  [{"id": 657, "name": "fire"}, {"id": 1857, "na...                en
# 317  [{"id": 173251, "name": "forced prostitution"}...                zh
# 318  [{"id": 658, "name": "sea"}, {"id": 1477, "nam...                en
# 319  [{"id": 803, "name": "android"}, {"id": 3451, ...                en
#
#                                original_title  \
# 0                                      Avatar
# 1    Pirates of the Caribbean: At World's End
# 2                                     Spectre
# 3                       The Dark Knight Rises
# 4                                 John Carter
# ..                                        ...
# 315                         The Mummy Returns
# 316                         Gangs of New York
# 317                                     金陵十三釵
# 318                                 Surf's Up
# 319                        The Stepford Wives
#
#                                               overview  popularity  \
# 0    In the 22nd century, a paraplegic Marine is di...  150.437577
# 1    Captain Barbossa, long believed to be dead, ha...  139.082615
# 2    A cryptic message from Bond’s past sends him o...  107.376788
# 3    Following the death of District Attorney Harve...  112.312950
# 4    John Carter is a war-weary, former military ca...   43.926995
# ..                                                 ...         ...
# 315  Rick and Evelyn O'Connell, along with their 8 ...   41.862983
# 316  It's 1863. America was born in the streets. Am...   46.160048
# 317  A Westerner finds refuge with a group of women...   12.516546
# 318  Cody is a surfing penguin from Shiverpool who ...   23.230851
# 319  What does it take to become a Stepford wife, a...   19.224754
#
#                                   production_companies  \
# 0    [{"name": "Ingenious Film Partners", "id": 289...
# 1    [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 2    [{"name": "Columbia Pictures", "id": 5}, {"nam...
# 3    [{"name": "Legendary Pictures", "id": 923}, {"...
# 4          [{"name": "Walt Disney Pictures", "id": 2}]
# ..                                                 ...
# 315  [{"name": "Universal Pictures", "id": 33}, {"n...
# 316  [{"name": "Miramax Films", "id": 14}, {"name":...
# 317  [{"name": "Beijing New Picture Film Co. Ltd.",...
# 318  [{"name": "Columbia Pictures", "id": 5}, {"nam...
# 319  [{"name": "Paramount Pictures", "id": 4}, {"na...
#
#                                   production_countries release_date  \
# 0    [{"iso_3166_1": "US", "name": "United States o...   2009-12-10
# 1    [{"iso_3166_1": "US", "name": "United States o...   2007-05-19
# 2    [{"iso_3166_1": "GB", "name": "United Kingdom"...   2015-10-26
# 3    [{"iso_3166_1": "US", "name": "United States o...   2012-07-16
# 4    [{"iso_3166_1": "US", "name": "United States o...   2012-03-07
# ..                                                 ...          ...
# 315  [{"iso_3166_1": "US", "name": "United States o...   2001-04-28
# 316  [{"iso_3166_1": "US", "name": "United States o...   2002-12-14
# 317  [{"iso_3166_1": "CN", "name": "China"}, {"iso_...   2011-12-15
# 318  [{"iso_3166_1": "US", "name": "United States o...   2007-06-08
# 319  [{"iso_3166_1": "US", "name": "United States o...   2004-06-10
#
#         revenue  runtime                                   spoken_languages  \
# 0    2787965087    162.0  [{"iso_639_1": "en", "name": "English"}, {"iso...
# 1     961000000    169.0           [{"iso_639_1": "en", "name": "English"}]
# 2     880674609    148.0  [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...
# 3    1084939099    165.0           [{"iso_639_1": "en", "name": "English"}]
# 4     284139100    132.0           [{"iso_639_1": "en", "name": "English"}]
# ..          ...      ...                                                ...
# 315   433013274    130.0  [{"iso_639_1": "en", "name": "English"}, {"iso...
# 316   193772504    167.0  [{"iso_639_1": "en", "name": "English"}, {"iso...
# 317    95311434    145.0  [{"iso_639_1": "zh", "name": "\u666e\u901a\u8b...
# 318   149044513     85.0           [{"iso_639_1": "en", "name": "English"}]
# 319   102000000     93.0           [{"iso_639_1": "en", "name": "English"}]
#
#        status                                            tagline  \
# 0    Released                        Enter the World of Pandora.
# 1    Released     At the end of the world, the adventure begins.
# 2    Released                              A Plan No One Escapes
# 3    Released                                    The Legend Ends
# 4    Released               Lost in our world, found in another.
# ..        ...                                                ...
# 315  Released  The most powerful force on earth is about to b...
# 316  Released                   America was born in the streets.
# 317  Released                                                NaN
# 318  Released  In the coldest place on Earth, he's the hottes...
# 319  Released               The wives of Stepford have a secret.
#
#                                         title  vote_average  vote_count
# 0                                      Avatar           7.2       11800
# 1    Pirates of the Caribbean: At World's End           6.9        4500
# 2                                     Spectre           6.3        4466
# 3                       The Dark Knight Rises           7.6        9106
# 4                                 John Carter           6.1        2124
# ..                                        ...           ...         ...
# 315                         The Mummy Returns           6.0        2206
# 316                         Gangs of New York           7.1        1910
# 317                        The Flowers of War           7.1         187
# 318                                 Surf's Up           5.9         601
# 319                        The Stepford Wives           5.4         334
#
# [320 rows x 20 columns]

# %%
movie_5000_name = df_5000[['original_title']]
movie_5000_name
# Out:
#                                 original_title
# 0                                       Avatar
# 1     Pirates of the Caribbean: At World's End
# 2                                      Spectre
# 3                        The Dark Knight Rises
# 4                                  John Carter
# ...                                        ...
# 4798                               El Mariachi
# 4799                                 Newlyweds
# 4800                 Signed, Sealed, Delivered
# 4801                          Shanghai Calling
# 4802                         My Date with Drew
#
# [4803 rows x 1 columns]

# %%
# movie_5000_list = list(movie_5000_name)
# movie_5000_list

movie_5000_list = df_5000['original_title'].to_list()
movie_5000_list
# Out:
# ['Avatar',
#  "Pirates of the Caribbean: At World's End",
#  'Spectre',
#  'The Dark Knight Rises',
#  'John Carter',
#  'Spider-Man 3',
#  'Tangled',
#  'Avengers: Age of Ultron',
#  'Harry Potter and the Half-Blood Prince',
#  'Batman v Superman: Dawn of Justice',
#  'Superman Returns',
#  'Quantum of Solace',
#  "Pirates of the Caribbean: Dead Man's Chest",
#  'The Lone Ranger',
#  'Man of Steel',
#  'The Chronicles of Narnia: Prince Caspian',
#  'The Avengers',
#  'Pirates of the Caribbean: On Stranger Tides',
#  'Men in Black 3',
#  'The Hobbit: The Battle of the Five Armies',
#  'The Amazing Spider-Man',
#  'Robin Hood',
#  'The Hobbit: The Desolation of Smaug',
#  'The Golden Compass',
#  'King Kong',
#  'Titanic',
#  'Captain America: Civil War',
#  'Battleship',
#  'Jurassic World',
#  'Skyfall',
#  'Spider-Man 2',
#  'Iron Man 3',
#  'Alice in Wonderland',
#  'X-Men: The Last Stand',
#  'Monsters University',
#  'Transformers: Revenge of the Fallen',
#  'Transformers: Age of Extinction',
#  'Oz: The Great and Powerful',
#  'The Amazing Spider-Man 2',
#  'TRON: Legacy',
#  'Cars 2',
#  'Green Lantern',
#  'Toy Story 3',
#  'Terminator Salvation',
#  'Furious 7',
#  'World War Z',
#  'X-Men: Days of Future Past',
#  'Star Trek Into Darkness',
#  'Jack the Giant Slayer',
#  'The Great Gatsby',
#  'Prince of Persia: The Sands of Time',
#  'Pacific Rim',
#  'Transformers: Dark of the Moon',
#  'Indiana Jones and the Kingdom of the Crystal Skull',
#  'The Good Dinosaur',
#  'Brave',
#  'Star Trek Beyond',
#  'WALL·E',
#  'Rush Hour 3',
#  '2012',
#  'A Christmas Carol',
#  'Jupiter Ascending',
#  'The Legend of Tarzan',
#  'The Chronicles of Narnia: The Lion, the Witch and the Wardrobe',
#  'X-Men: Apocalypse',
#  'The Dark Knight',
#  'Up',
#  'Monsters vs Aliens',
#  'Iron Man',
#  'Hugo',
#  'Wild Wild West',
#  'The Mummy: Tomb of the Dragon Emperor',
#  'Suicide Squad',
#  'Evan Almighty',
#  'Edge of Tomorrow',
#  'Waterworld',
#  'G.I. Joe: The Rise of Cobra',
#  'Inside Out',
#  'The Jungle Book',
#  'Iron Man 2',
#  'Snow White and the Huntsman',
#  'Maleficent',
#  'Dawn of the Planet of the Apes',
#  'The Lovers',
#  '47 Ronin',
#  'Captain America: The Winter Soldier',
#  'Shrek Forever After',
#  'Tomorrowland',
#  'Big Hero 6',
#  'Wreck-It Ralph',
#  'The Polar Express',
#  'Independence Day: Resurgence',
#  'How to Train Your Dragon',
#  'Terminator 3: Rise of the Machines',
#  'Guardians of the Galaxy',
#  'Interstellar',
#  'Inception',
#  'シン・ゴジラ',
#  'The Hobbit: An Unexpected Journey',
#  'The Fast and the Furious',
#  'The Curious Case of Benjamin Button',
#  'X-Men: First Class',
#  'The Hunger Games: Mockingjay - Part 2',
#  "The Sorcerer's Apprentice",
#  'Poseidon',
#  'Alice Through the Looking Glass',
#  'Shrek the Third',
#  'Warcraft',
#  'Terminator Genisys',
#  'The Chronicles of Narnia: The Voyage of the Dawn Treader',
#  'Pearl Harbor',
#  'Transformers',
#  'Alexander',
#  'Harry Potter and the Order of the Phoenix',
#  'Harry Potter and the Goblet of Fire',
#  'Hancock',
#  'I Am Legend',
#  'Charlie and the Chocolate Factory',
#  'Ratatouille',
#  'Batman Begins',
#  'Madagascar: Escape 2 Africa',
#  'Night at the Museum: Battle of the Smithsonian',
#  'X-Men Origins: Wolverine',
#  'The Matrix Revolutions',
#  'Frozen',
#  'The Matrix Reloaded',
#  'Thor: The Dark World',
#  'Mad Max: Fury Road',
#  'Angels & Demons',
#  'Thor',
#  'Bolt',
#  'G-Force',
#  'Wrath of the Titans',
#  'Dark Shadows',
#  'Mission: Impossible - Rogue Nation',
#  'The Wolfman',
#  'Bee Movie',
#  'Kung Fu Panda 2',
#  'The Last Airbender',
#  'Mission: Impossible III',
#  'White House Down',
#  'Mars Needs Moms',
#  'Flushed Away',
#  'Pan',
#  'Mr. Peabody & Sherman',
#  'Troy',
#  "Madagascar 3: Europe's Most Wanted",
#  'Die Another Day',
#  'Ghostbusters',
#  'Armageddon',
#  'Men in Black II',
#  'Beowulf',
#  'Kung Fu Panda 3',
#  'Mission: Impossible - Ghost Protocol',
#  'Rise of the Guardians',
#  'Fun with Dick and Jane',
#  'The Last Samurai',
#  'Exodus: Gods and Kings',
#  'Star Trek',
#  'Spider-Man',
#  'How to Train Your Dragon 2',
#  'Gods of Egypt',
#  'Stealth',
#  'Watchmen',
#  'Lethal Weapon 4',
#  'Hulk',
#  'G.I. Joe: Retaliation',
#  'Sahara',
#  'Final Fantasy: The Spirits Within',
#  'Captain America: The First Avenger',
#  'The World Is Not Enough',
#  'Master and Commander: The Far Side of the World',
#  'The Twilight Saga: Breaking Dawn - Part 2',
#  'Happy Feet Two',
#  'The Incredible Hulk',
#  'The BFG',
#  'The Revenant',
#  'Turbo',
#  'Rango',
#  'Penguins of Madagascar',
#  'The Bourne Ultimatum',
#  'Kung Fu Panda',
#  'Ant-Man',
#  'The Hunger Games: Catching Fire',
#  'Home',
#  'War of the Worlds',
#  'Bad Boys II',
#  'Puss in Boots',
#  'Salt',
#  'Noah',
#  'The Adventures of Tintin',
#  'Harry Potter and the Prisoner of Azkaban',
#  'Australia',
#  'After Earth',
#  'Dinosaur',
#  'Night at the Museum: Secret of the Tomb',
#  'Megamind',
#  "Harry Potter and the Philosopher's Stone",
#  'R.I.P.D.',
#  'Pirates of the Caribbean: The Curse of the Black Pearl',
#  'The Hunger Games: Mockingjay - Part 1',
#  'The Da Vinci Code',
#  'Rio 2',
#  'X2',
#  'Fast Five',
#  'Sherlock Holmes: A Game of Shadows',
#  'Clash of the Titans',
#  'Total Recall',
#  'The 13th Warrior',
#  'The Bourne Legacy',
#  'Batman & Robin',
#  'How the Grinch Stole Christmas',
#  'The Day After Tomorrow',
#  'Mission: Impossible II',
#  'The Perfect Storm',
#  '4: Rise of the Silver Surfer',
#  'Life of Pi',
#  'Ghost Rider',
#  'Jason Bourne',
#  "Charlie's Angels: Full Throttle",
#  'Prometheus',
#  'Stuart Little 2',
#  'Elysium',
#  'The Chronicles of Riddick',
#  'RoboCop',
#  'Speed Racer',
#  'How Do You Know',
#  'Knight and Day',
#  'Oblivion',
#  'Star Wars: Episode III - Revenge of the Sith',
#  'Star Wars: Episode II - Attack of the Clones',
#  'Monsters, Inc.',
#  'The Wolverine',
#  'Star Wars: Episode I - The Phantom Menace',
#  'The Croods',
#  'Astérix aux Jeux Olympiques',
#  'Windtalkers',
#  "The Huntsman: Winter's War",
#  'Teenage Mutant Ninja Turtles',
#  'Gravity',
#  "Dante's Peak",
#  'Teenage Mutant Ninja Turtles: Out of the Shadows',
#  'Fantastic Four',
#  'Night at the Museum',
#  'San Andreas',
#  'Tomorrow Never Dies',
#  'The Patriot',
#  "Ocean's Twelve",
#  'Mr. & Mrs. Smith',
#  'Insurgent',
#  'The Aviator',
#  "Gulliver's Travels",
#  'The Green Hornet',
#  '300: Rise of an Empire',
#  'The Smurfs',
#  'Home on the Range',
#  'Allegiant',
#  'Real Steel',
#  'The Smurfs 2',
#  'Speed 2: Cruise Control',
#  "Ender's Game",
#  'Live Free or Die Hard',
#  'The Lord of the Rings: The Fellowship of the Ring',
#  'Around the World in 80 Days',
#  'Ali',
#  'The Cat in the Hat',
#  'I, Robot',
#  'Kingdom of Heaven',
#  'Stuart Little',
#  'The Princess and the Frog',
#  'The Martian',
#  'The Island',
#  'Town & Country',
#  'Gone in Sixty Seconds',
#  'Gladiator',
#  'Minority Report',
#  'Harry Potter and the Chamber of Secrets',
#  'Casino Royale',
#  'Planet of the Apes',
#  'Terminator 2: Judgment Day',
#  'Public Enemies',
#  'American Gangster',
#  'True Lies',
#  'The Taking of Pelham 1 2 3',
#  'Little Fockers',
#  'The Other Guys',
#  'Eraser',
#  'Django Unchained',
#  'The Hunchback of Notre Dame',
#  "The Emperor's New Groove",
#  'The Expendables 2',
#  'National Treasure',
#  'Eragon',
#  'Where the Wild Things Are',
#  'Epic',
#  'The Tourist',
#  'End of Days',
#  'Blood Diamond',
#  'The Wolf of Wall Street',
#  'Batman Forever',
#  'Starship Troopers',
#  'Cloud Atlas',
#  "Legend of the Guardians: The Owls of Ga'Hoole",
#  'Catwoman',
#  'Hercules',
#  'Treasure Planet',
#  'Land of the Lost',
#  'The Expendables 3',
#  'Point Break',
#  'Son of the Mask',
#  'In the Heart of the Sea',
#  'The Adventures of Pluto Nash',
#  'Green Zone',
#  'The Peanuts Movie',
#  'The Spanish Prisoner',
#  'The Mummy Returns',
#  'Gangs of New York',
#  '金陵十三釵',
#  "Surf's Up",
#  'The Stepford Wives',
#  'Black Hawk Down',
#  'The Campaign',
#  'The Fifth Element',
#  'Sex and the City 2',
#  'The Road to El Dorado',
#  'Ice Age: Continental Drift',
#  'Cinderella',
#  'The Lovely Bones',
#  'Finding Nemo',
#  'The Lord of the Rings: The Return of the King',
#  'The Lord of the Rings: The Two Towers',
#  'Seventh Son',
#  'Lara Croft: Tomb Raider',
#  'Transcendence',
#  'Jurassic Park III',
#  'Rise of the Planet of the Apes',
#  'The Spiderwick Chronicles',
#  'A Good Day to Die Hard',
#  'The Alamo',
#  'The Incredibles',
#  'Cutthroat Island',
#  'Percy Jackson & the Olympians: The Lightning Thief',
#  'Men in Black',
#  'Toy Story 2',
#  'Unstoppable',
#  'Rush Hour 2',
#  'What Lies Beneath',
#  'Cloudy with a Chance of Meatballs',
#  'Ice Age: Dawn of the Dinosaurs',
#  'The Secret Life of Walter Mitty',
#  "Charlie's Angels",
#  'The Departed',
#  'Mulan',
#  'Tropic Thunder',
#  'The Girl with the Dragon Tattoo',
#  'Die Hard: With a Vengeance',
#  'Sherlock Holmes',
#  'Ben-Hur',
#  'Atlantis: The Lost Empire',
#  'Alvin and the Chipmunks: The Road Chip',
#  'Valkyrie',
#  "You Don't Mess with the Zohan",
#  'Pixels',
#  'A.I. Artificial Intelligence',
#  'The Haunted Mansion',
#  'Contact',
#  'Hollow Man',
#  'The Interpreter',
#  'Percy Jackson: Sea of Monsters',
#  'Lara Croft Tomb Raider: The Cradle of Life',
#  'Now You See Me 2',
#  'The Saint',
#  'Spy Game',
#  'Mission to Mars',
#  'Rio',
#  'Bicentennial Man',
#  'Volcano',
#  "The Devil's Own",
#  'K-19: The Widowmaker',
#  'Conan the Barbarian',
#  'Cinderella Man',
#  'The Nutcracker: The Untold Story',
#  'Seabiscuit',
#  'Twister',
#  'Cast Away',
#  'Happy Feet',
#  'The Bourne Supremacy',
#  'Air Force One',
#  "Ocean's Eleven",
#  'The Three Musketeers',
#  'Hotel Transylvania',
#  'Enchanted',
#  'Safe House',
#  '102 Dalmatians',
#  'Tower Heist',
#  'The Holiday',
#  'Enemy of the State',
#  "It's Complicated",
#  "Ocean's Thirteen",
#  'Open Season',
#  'Divergent',
#  'Enemy at the Gates',
#  'The Rundown',
#  'Last Action Hero',
#  'Memoirs of a Geisha',
#  'The Fast and the Furious: Tokyo Drift',
#  'Arthur Christmas',
#  'Meet Joe Black',
#  'Collateral Damage',
#  'All That Jazz',
#  'Mirror Mirror',
#  'Scott Pilgrim vs. the World',
#  'The Core',
#  'Nutty Professor II: The Klumps',
#  'Scooby-Doo',
#  'Dredd',
#  'Click',
#  'Creepshow',
#  'Cats & Dogs 2 : The Revenge of Kitty Galore',
#  'Jumper',
#  'Hellboy II: The Golden Army',
#  'Zodiac',
#  'The 6th Day',
#  'Bruce Almighty',
#  'The Expendables',
#  'Mission: Impossible',
#  'The Hunger Games',
#  'The Hangover Part II',
#  'Batman Returns',
#  'Over the Hedge',
#  'Lilo & Stitch',
#  "Charlotte's Web",
#  'Deep Impact',
#  'RED 2',
#  'The Longest Yard',
#  'Alvin and the Chipmunks: Chipwrecked',
#  'Grown Ups 2',
#  'Get Smart',
#  "Something's Gotta Give",
#  'Shutter Island',
#  'Four Christmases',
#  'Robots',
#  'Face/Off',
#  'Bedtime Stories',
#  'Road to Perdition',
#  'Just Go with It',
#  'Con Air',
#  'Eagle Eye',
#  'Cold Mountain',
#  'The Book of Eli',
#  'Flubber',
#  'The Haunting',
#  'Space Jam',
#  'The Pink Panther',
#  'The Day the Earth Stood Still',
#  'Conspiracy Theory',
#  'Fury',
#  'Six Days Seven Nights',
#  'Yogi Bear',
#  'Spirit: Stallion of the Cimarron',
#  'Zookeeper',
#  'Lost in Space',
#  'The Manchurian Candidate',
#  'Déjà Vu',
#  'Hotel Transylvania 2',
#  'Fantasia 2000',
#  'The Time Machine',
#  'Mighty Joe Young',
#  'Swordfish',
#  'The Legend of Zorro',
#  'What Dreams May Come',
#  'Little Nicky',
#  'The Brothers Grimm',
#  'Mars Attacks!',
#  'Évolution',
#  'The Edge',
#  'Surrogates',
#  'Thirteen Days',
#  'Daylight',
#  'Walking With Dinosaurs',
#  'Battlefield Earth',
#  'Looney Tunes: Back in Action',
#  'Nine',
#  'Timeline',
#  'The Postman',
#  'Babe: Pig in the City',
#  'The Last Witch Hunter',
#  'Red Planet',
#  'Arthur et les Minimoys',
#  'Oceans',
#  'A Sound of Thunder',
#  'Pompeii',
#  'Don Gato: El inicio de la pandilla',
#  'A Beautiful Mind',
#  'The Lion King',
#  'Journey 2: The Mysterious Island',
#  'Cloudy with a Chance of Meatballs 2',
#  'Red Dragon',
#  'Hidalgo',
#  'Jack and Jill',
#  '2 Fast 2 Furious',
#  'The Little Prince',
#  'The Invasion',
#  'The Adventures of Rocky & Bullwinkle',
#  'The Secret Life of Pets',
#  'The League of Extraordinary Gentlemen',
#  'Despicable Me 2',
#  'Independence Day',
#  'The Lost World: Jurassic Park',
#  'Madagascar',
#  'Children of Men',
#  'X-Men',
#  'Wanted',
#  'The Rock',
#  'Ice Age: The Meltdown',
#  '50 First Dates',
#  'Hairspray',
#  'Exorcist: The Beginning',
#  'Inspector Gadget',
#  'Now You See Me',
#  'Grown Ups',
#  'The Terminal',
#  'Hotel for Dogs',
#  'Vertical Limit',
#  "Charlie Wilson's War",
#  'Shark Tale',
#  'Dreamgirls',
#  'Be Cool',
#  'Munich',
#  'Tears of the Sun',
#  'Killers',
#  'The Man from U.N.C.L.E.',
#  'Spanglish',
#  'Monster House',
#  'Bandits',
#  'First Knight',
#  'Anna and the King',
#  'Immortals',
#  'Hostage',
#  'Titan A.E.',
#  'Hollywood Homicide',
#  'Soldier',
#  'Carriers',
#  'Monkeybone',
#  'Flight of the Phoenix',
#  'Unbreakable',
#  'Minions',
#  'Sucker Punch',
#  'Snake Eyes',
#  'Sphere',
#  'The Angry Birds Movie',
#  "Fool's Gold",
#  'Funny People',
#  'The Kingdom',
#  'Talladega Nights: The Ballad of Ricky Bobby',
#  'Dr. Dolittle 2',
#  'Braveheart',
#  'Jarhead',
#  'The Simpsons Movie',
#  'The Majestic',
#  'Driven',
#  'Deux frères',
#  'The Village',
#  'Doctor Dolittle',
#  'Signs',
#  'Shrek 2',
#  'Cars',
#  'Runaway Bride',
#  'xXx',
#  'The SpongeBob Movie: Sponge Out of Water',
#  'Ransom',
#  'Inglourious Basterds',
#  'Hook',
#  'Die Hard 2',
#  'S.W.A.T.',
#  'Vanilla Sky',
#  'Lady in the Water',
#  'AVP: Alien vs. Predator',
#  'Alvin and the Chipmunks: The Squeakquel',
#  'We Were Soldiers',
#  'Olympus Has Fallen',
#  'Star Trek: Insurrection',
#  'Battle: Los Angeles',
#  'Big Fish',
#  'Wolf',
#  'War Horse',
#  'The Monuments Men',
#  'The Abyss',
#  'Wall Street: Money Never Sleeps',
#  'Dracula Untold',
#  'The Siege',
#  'Stardust',
#  'Seven Years in Tibet',
#  'The Dilemma',
#  'Bad Company',
#  'Doom',
#  'I Spy',
#  'Underworld: Awakening',
#  'Rock of Ages',
#  "Hart's War",
#  'Killer Elite',
#  'Rollerball',
#  'Ballistic: Ecks vs. Sever',
#  'Hard Rain',
#  'Osmosis Jones',
#  "Legends of Oz: Dorothy's Return",
#  'Blackhat',
#  'Sky Captain and the World of Tomorrow',
#  'Basic Instinct 2',
#  'Escape Plan',
#  'The Legend of Hercules',
#  'The Sum of All Fears',
#  'The Twilight Saga: Eclipse',
#  'The Score',
#  'Despicable Me',
#  'Money Train',
#  'Ted 2',
#  'Agora',
#  'Mystery Men',
#  'Hall Pass',
#  'The Insider',
#  'The Finest Hours',
#  'Body of Lies',
#  'Dinner for Schmucks',
#  'Abraham Lincoln: Vampire Hunter',
#  'Entrapment',
#  'The X Files',
#  'The Last Legion',
#  'Saving Private Ryan',
#  'Need for Speed',
#  'What Women Want',
#  'Ice Age',
#  'Dreamcatcher',
#  'Lincoln',
#  'The Matrix',
#  'Apollo 13',
#  'The Santa Clause 2',
#  'Les Misérables',
#  "You've Got Mail",
#  'Step Brothers',
#  'The Mask of Zorro',
#  'Due Date',
#  'Unbroken',
#  'Space Cowboys',
#  'Cliffhanger',
#  'Broken Arrow',
#  'The Kid',
#  'World Trade Center',
#  'Mona Lisa Smile',
#  'The Dictator',
#  'Eyes Wide Shut',
#  'Annie',
#  'Focus',
#  'This Means War',
#  'Blade: Trinity',
#  'Red Dawn',
#  'Primary Colors',
#  'Resident Evil: Retribution',
#  'Death Race',
#  'The Long Kiss Goodnight',
#  'Proof of Life',
#  'Zathura: A Space Adventure',
#  'Fight Club',
#  'We Are Marshall',
#  'Hudson Hawk',
#  'Lucky Numbers',
#  'I, Frankenstein',
#  'Oliver Twist',
#  'Elektra',
#  'Sin City: A Dame to Kill For',
#  'Random Hearts',
#  'Everest',
#  'Perfume: The Story of a Murderer',
#  'Austin Powers in Goldmember',
#  'Astro Boy',
#  'Jurassic Park',
#  'Wyatt Earp',
#  'Clear and Present Danger',
#  '天將雄師',
#  'Little Man',
#  'U-571',
#  'The American President',
#  'The Love Guru',
#  '3000 Miles to Graceland',
#  'The Hateful Eight',
#  'Blades of Glory',
#  'Hop',
#  '300',
#  'Meet the Fockers',
#  'Marley & Me',
#  'The Green Mile',
#  'Wild Hogs',
#  'Chicken Little',
#  'Gone Girl',
#  'The Bourne Identity',
#  'GoldenEye',
#  "The General's Daughter",
#  'The Truman Show',
#  'The Prince of Egypt',
#  'Daddy Day Care',
#  '2 Guns',
#  'Cats & Dogs',
#  'The Italian Job',
#  'Two Weeks Notice',
#  'Antz',
#  'Couples Retreat',
#  'Days of Thunder',
#  'Cheaper by the Dozen 2',
#  'Maze Runner: The Scorch Trials',
#  'Eat Pray Love',
#  'The Family Man',
#  'RED',
#  'Any Given Sunday',
#  'The Horse Whisperer',
#  'Collateral',
#  'The Scorpion King',
#  'Ladder 49',
#  'Jack Reacher',
#  'Deep Blue Sea',
#  "Michael Jackson's This Is It",
#  'Contagion',
#  'Kangaroo Jack',
#  'Coraline',
#  'The Happening',
#  'Man on Fire',
#  'The Shaggy Dog',
#  'Starsky & Hutch',
#  'Jingle All the Way',
#  'Hellboy',
#  'A Civil Action',
#  'ParaNorman',
#  'The Jackal',
#  'Paycheck',
#  'Up Close & Personal',
#  'The Tale of Despereaux',
#  'The Tuxedo',
#  'Under Siege 2: Dark Territory',
#  'Jack Ryan: Shadow Recruit',
#  'Joy',
#  'London Has Fallen',
#  'Alien: Resurrection',
#  'Shooter',
#  'The Boxtrolls',
#  'Practical Magic',
#  'The Lego Movie',
#  'Miss Congeniality 2: Armed and Fabulous',
#  'Reign of Fire',
#  'Gangster Squad',
#  'Year One',
#  'Invictus',
#  'State of Play',
#  'Duplicity',
#  'My Favorite Martian',
#  'The Sentinel',
#  'Planet 51',
#  'Star Trek: Nemesis',
#  'Intolerable Cruelty',
#  'Trouble with the Curve',
#  'Edge of Darkness',
#  'The Relic',
#  'Analyze That',
#  'Righteous Kill',
#  'Mercury Rising',
#  'The Soloist',
#  'The Legend of Bagger Vance',
#  'Almost Famous',
#  'Garfield: A Tail of Two Kitties',
#  'xXx: State of the Union',
#  'Priest',
#  'Sinbad: Legend of the Seven Seas',
#  'Event Horizon',
#  'Dragonfly',
#  'The Black Dahlia',
#  'Flyboys',
#  'The Last Castle',
#  'Supernova',
#  "Winter's Tale",
#  'The Mortal Instruments: City of Bones',
#  'Meet Dave',
#  'Dark Water',
#  'Edtv',
#  'Inkheart',
#  'The Spirit',
#  'Mortdecai',
#  'In the Name of the King: A Dungeon Siege Tale',
#  'Beyond Borders',
#  '西游记之孙悟空三打白骨精',
#  'The Great Raid',
#  'Deadpool',
#  'Holy Man',
#  'American Sniper',
#  'Goosebumps',
#  'Just Like Heaven',
#  'The Flintstones in Viva Rock Vegas',
#  'Rambo III',
#  'Leatherheads',
#  'The Ridiculous 6',
#  'Did You Hear About the Morgans?',
#  'The Internship',
#  'Resident Evil: Afterlife',
#  'Red Tails',
#  "The Devil's Advocate",
#  "That's My Boy",
#  'DragonHeart',
#  'After the Sunset',
#  'Ghost Rider: Spirit of Vengeance',
#  "Captain Corelli's Mandolin",
#  'The Pacifier',
#  'Walking Tall',
#  'Forrest Gump',
#  'Alvin and the Chipmunks',
#  'Meet the Parents',
#  'Pocahontas',
#  'Superman',
#  'The Nutty Professor',
#  'Hitch',
#  'George of the Jungle',
#  'American Wedding',
#  'Captain Phillips',
#  'Date Night',
#  'Casper',
#  'The Equalizer',
#  'Maid in Manhattan',
#  'Crimson Tide',
#  'The Pursuit of Happyness',
#  'Flightplan',
#  'Disclosure',
#  'City of Angels',
#  'Kill Bill: Vol. 1',
#  'Bowfinger',
#  'Kill Bill: Vol. 2',
#  'Tango & Cash',
#  'Death Becomes Her',
#  'Shanghai Noon',
#  'Executive Decision',
#  "Mr. Popper's Penguins",
#  'The Forbidden Kingdom',
#  'Free Birds',
#  'Alien³',
#  'Evita',
#  'Ronin',
#  'The Ghost and the Darkness',
#  'Paddington',
#  'The Watch',
#  'The Hunted',
#  'Instinct',
#  'Stuck on You',
#  'Semi-Pro',
#  'The Pirates! In an Adventure with Scientists!',
#  'Changeling',
#  'Chain Reaction',
#  'The Fan',
#  'The Phantom of the Opera',
#  'Elizabeth: The Golden Age',
#  'Æon Flux',
#  'Gods and Generals',
#  'Turbulence',
#  'Imagine That',
#  'Muppets Most Wanted',
#  'Thunderbirds',
#  'Burlesque',
#  'Un long dimanche de fiançailles',
#  'Lolita',
#  'D-Tox',
#  'Blade II',
#  'Seven Pounds',
#  'Bullet to the Head',
#  'The Godfather: Part III',
#  'Elizabethtown',
#  'You, Me and Dupree',
#  'Superman II',
#  'Gigli',
#  "All the King's Men",
#  'Shaft',
#  'Anastasia',
#  'Moulin Rouge!',
#  'Domestic Disturbance',
#  'Black Mass',
#  'Flags of Our Fathers',
#  'Law Abiding Citizen',
#  'Grindhouse',
#  'Beloved',
#  'Lucky You',
#  'Catch Me If You Can',
#  'Zero Dark Thirty',
#  'The Break-Up',
#  'Mamma Mia!',
#  "Valentine's Day",
#  'The Dukes of Hazzard',
#  'The Thin Red Line',
#  'The Change-Up',
#  'Man on the Moon',
#  'Casino',
#  'From Paris with Love',
#  'Bulletproof Monk',
#  'Me, Myself & Irene',
#  'Barnyard',
#  'Deck the Halls',
#  'The Twilight Saga: New Moon',
#  'Shrek',
#  'The Adjustment Bureau',
#  'Robin Hood: Prince of Thieves',
#  'Jerry Maguire',
#  'Ted',
#  'As Good as It Gets',
#  'Patch Adams',
#  'Anchorman 2: The Legend Continues',
#  'Mr. Deeds',
#  'Super 8',
#  'Erin Brockovich',
#  'How to Lose a Guy in 10 Days',
#  '22 Jump Street',
#  'Interview with the Vampire',
#  'Yes Man',
#  'Central Intelligence',
#  'Stepmom',
#  "Daddy's Home",
#  'Into the Woods',
#  'Inside Man',
#  'Payback',
#  'Congo',
#  'We Bought a Zoo',
#  'Knowing',
#  'Failure to Launch',
#  'The Ring Two',
#  'Crazy, Stupid, Love.',
#  'Garfield',
#  'Christmas with the Kranks',
#  'Moneyball',
#  'Outbreak',
#  'Non-Stop',
#  'Race to Witch Mountain',
#  'V for Vendetta',
#  'Shanghai Knights',
#  'Curious George',
#  'Herbie Fully Loaded',
#  "Don't Say a Word",
#  'Hansel & Gretel: Witch Hunters',
#  'Unfaithful',
#  'I Am Number Four',
#  'Syriana',
#  '13 Hours: The Secret Soldiers of Benghazi',
#  'The Book of Life',
#  'Firewall',
#  'Absolute Power',
#  'G.I. Jane',
#  'The Game',
#  'Silent Hill',
#  'The Replacements',
#  'American Reunion',
#  'The Negotiator',
#  'Into the Storm',
#  'Beverly Hills Cop III',
#  'Gremlins 2: The New Batch',
#  'The Judge',
#  'The Peacemaker',
#  'Resident Evil: Apocalypse',
#  'Bridget Jones: The Edge of Reason',
#  'Out of Time',
#  'On Deadly Ground',
#  'The Adventures of Sharkboy and Lavagirl',
#  'The Beach',
#  'Raising Helen',
#  'Ninja Assassin',
#  'For Love of the Game',
#  'Striptease',
#  'Marmaduke',
#  'Hereafter',
#  'Murder by Numbers',
#  'Assassins',
#  'Hannibal Rising',
#  'The Story of Us',
#  'The Host',
#  'Basic',
#  'Blood Work',
#  'The International',
#  'Escape from L.A.',
#  'The Iron Giant',
#  'The Life Aquatic with Steve Zissou',
#  'Free State of Jones',
#  'The Life of David Gale',
#  'Man of the House',
#  'Run All Night',
#  'Eastern Promises',
#  'Into the Blue',
#  'Joan of Arc',
#  'Your Highness',
#  'Dream House',
#  'Mad City',
#  "Baby's Day Out",
#  'The Scarlet Letter',
#  'Fair Game',
#  'Domino',
#  'Jade',
#  'Gamer',
#  'Beautiful Creatures',
#  'Death to Smoochy',
#  'Zoolander 2',
#  'The Big Bounce',
#  'What Planet Are You From?',
#  ...]

# %%
len(movie_5000_list)
# Out:
# 4803

# %%
set_movie_reviewed = set(movie_reviewed)
set_movie_5000 = set(movie_5000_list)

common = set_movie_reviewed.intersection(set_movie_5000)

print(common)
# Out:
# {'The Last King of Scotland', 'The Mummy Returns', 'Thirteen Days', 'Ant-Man', 'The Finest Hours', 'The Thing', 'Toy Story 3', 'Peaceful Warrior', 'Jaws', 'Watchmen', 'Rango', 'Gone Girl', 'Munich', 'Back to the Future Part II', 'Big Fish', 'Con Air', 'Knocked Up', 'Orphan', 'Big Hero 6', 'The Thin Red Line', 'I Am Legend', 'The Witch', 'The Wolf of Wall Street', 'The Expendables', 'Dawn of the Dead', 'The Lego Movie', 'The Game', 'Mamma Mia!', 'I Love You, Man', 'Don Jon', '300', 'Finding Nemo', 'Vanilla Sky', 'Mama', 'How to Train Your Dragon', 'Elysium', 'Pitch Black', 'Pitch Perfect', 'The Fast and the Furious', "One Flew Over the Cuckoo's Nest", 'Cloud Atlas', 'Sucker Punch', 'The Butterfly Effect', 'The Producers', 'Jarhead', 'I, Robot', 'The Departed', 'Back to the Future', 'The Adventures of Tintin', 'Love Actually', 'Shark Tale', 'Space Jam', 'The Exorcist', 'Edge of Tomorrow', 'The Girl with the Dragon Tattoo', 'Cinderella Man', 'Nacho Libre', 'Identity', 'The Hurricane', 'The Benchwarmers', 'A Nightmare on Elm Street', 'The Town', 'Happy Gilmore', 'The Expendables 2', 'There Will Be Blood', 'Casablanca', '12 Years a Slave', 'The Dark Knight Rises', 'Dreamgirls', 'Enchanted', 'Monty Python and the Holy Grail', 'Paranormal Activity', 'Mulholland Drive', 'August Rush', 'The Greatest Game Ever Played', 'World Trade Center', 'Yes Man', 'U-571', 'Hancock', 'Monster', 'Valkyrie', 'Lucky Number Slevin', 'Sin City', 'Ben-Hur', 'Concussion', "The World's Fastest Indian", 'Good Morning, Vietnam', 'Gravity', 'Cloudy with a Chance of Meatballs', 'Total Recall', 'Deadpool', 'Saving Private Ryan', 'The Color of Money', '1408', 'Incendies', 'Megamind', 'Scream', 'Notting Hill', 'Creed', 'Glory Road', 'Stranger Than Fiction', 'The Patriot', 'Meet the Parents', 'Alexander', 'Child 44', '30 Days of Night', 'Insomnia', 'Platoon', 'Seabiscuit', 'The Girl Next Door', 'The Wolverine', 'Elf', 'The Love Guru', 'The Big Lebowski', 'Star Trek', 'Scott Pilgrim vs. the World', 'The Green Mile', 'Madagascar', 'Bridesmaids', 'WALL·E', 'Ghost', 'Taken', 'The Bridge on the River Kwai', 'The Hangover Part II', 'The Ugly Truth', '50 First Dates', 'Halloween', 'Girl, Interrupted', 'The Rookie', 'The English Patient', 'Guardians of the Galaxy', 'The Other Boleyn Girl', 'Her', 'Saving Mr. Banks', 'Gladiator', 'We Are Marshall', 'Fury', 'The Number 23', 'Lilo & Stitch', 'The Sixth Sense', 'Rise of the Planet of the Apes', 'The Legend of Bagger Vance', 'Insidious', 'Magic Mike XXL', 'Aliens', 'The Shining', 'The Pianist', 'Superbad', 'In Time', 'Everest', "Ocean's Eleven", 'Revolutionary Road', 'Hellboy', 'Carrie', 'About Time', 'Bloody Sunday', 'Harry Potter and the Goblet of Fire', 'Black Swan', 'Jurassic World', 'High Fidelity', 'Spotlight', 'Rang De Basanti', 'American History X', 'Into the Wild', 'Cold Mountain', 'Seven Years in Tibet', 'Ray', 'Black Hawk Down', 'War of the Worlds', 'The Incredible Hulk', 'Shrek 2', 'Gettysburg', 'The Village', '12 Angry Men', 'In the Land of Blood and Honey', "A Bug's Life", 'The Rocker', 'Avatar', 'The Matrix', 'Pearl Harbor', 'Resident Evil', 'The Conjuring 2', 'The Monuments Men', 'United 93', 'Crazy Heart', 'Up', 'Joy', 'Lords of Dogtown', 'Captain Phillips', 'Interstellar', 'Pocahontas', 'Man on Fire', 'The Young Victoria', 'Inception', "Hart's War", "Schindler's List", 'The Blind Side', 'The Equalizer', 'The Secret Life of Pets', 'The Happening', 'Black Snake Moan', 'The Fighter', 'Ghostbusters', 'Pacific Rim', 'Evil Dead', 'Stop-Loss', 'The Social Network', 'Unbroken', 'The Great Escape', 'L.A. Confidential', 'Lost in Translation', 'Raging Bull', 'Rise of the Guardians', 'Closer', 'Casino', 'Despicable Me 2', 'Antz', 'Brave', '54', 'Fantastic Mr. Fox', 'From Here to Eternity', 'Hot Fuzz', 'How to Train Your Dragon 2', 'Saints and Soldiers', "A Hard Day's Night", 'A Beautiful Mind', 'Over the Hedge', 'Spectre', 'American Pie', 'The Dark Knight', 'In Bruges', 'The Others', 'Pride & Prejudice', 'Music and Lyrics ...

# %%
len(common)
# Out:
# 749

# %%
common_list = list(common)
common_list
# Out:
# ['The Last King of Scotland',
#  'The Mummy Returns',
#  'Thirteen Days',
#  'Ant-Man',
#  'The Finest Hours',
#  'The Thing',
#  'Toy Story 3',
#  'Peaceful Warrior',
#  'Jaws',
#  'Watchmen',
#  'Rango',
#  'Gone Girl',
#  'Munich',
#  'Back to the Future Part II',
#  'Big Fish',
#  'Con Air',
#  'Knocked Up',
#  'Orphan',
#  'Big Hero 6',
#  'The Thin Red Line',
#  'I Am Legend',
#  'The Witch',
#  'The Wolf of Wall Street',
#  'The Expendables',
#  'Dawn of the Dead',
#  'The Lego Movie',
#  'The Game',
#  'Mamma Mia!',
#  'I Love You, Man',
#  'Don Jon',
#  '300',
#  'Finding Nemo',
#  'Vanilla Sky',
#  'Mama',
#  'How to Train Your Dragon',
#  'Elysium',
#  'Pitch Black',
#  'Pitch Perfect',
#  'The Fast and the Furious',
#  "One Flew Over the Cuckoo's Nest",
#  'Cloud Atlas',
#  'Sucker Punch',
#  'The Butterfly Effect',
#  'The Producers',
#  'Jarhead',
#  'I, Robot',
#  'The Departed',
#  'Back to the Future',
#  'The Adventures of Tintin',
#  'Love Actually',
#  'Shark Tale',
#  'Space Jam',
#  'The Exorcist',
#  'Edge of Tomorrow',
#  'The Girl with the Dragon Tattoo',
#  'Cinderella Man',
#  'Nacho Libre',
#  'Identity',
#  'The Hurricane',
#  'The Benchwarmers',
#  'A Nightmare on Elm Street',
#  'The Town',
#  'Happy Gilmore',
#  'The Expendables 2',
#  'There Will Be Blood',
#  'Casablanca',
#  '12 Years a Slave',
#  'The Dark Knight Rises',
#  'Dreamgirls',
#  'Enchanted',
#  'Monty Python and the Holy Grail',
#  'Paranormal Activity',
#  'Mulholland Drive',
#  'August Rush',
#  'The Greatest Game Ever Played',
#  'World Trade Center',
#  'Yes Man',
#  'U-571',
#  'Hancock',
#  'Monster',
#  'Valkyrie',
#  'Lucky Number Slevin',
#  'Sin City',
#  'Ben-Hur',
#  'Concussion',
#  "The World's Fastest Indian",
#  'Good Morning, Vietnam',
#  'Gravity',
#  'Cloudy with a Chance of Meatballs',
#  'Total Recall',
#  'Deadpool',
#  'Saving Private Ryan',
#  'The Color of Money',
#  '1408',
#  'Incendies',
#  'Megamind',
#  'Scream',
#  'Notting Hill',
#  'Creed',
#  'Glory Road',
#  'Stranger Than Fiction',
#  'The Patriot',
#  'Meet the Parents',
#  'Alexander',
#  'Child 44',
#  '30 Days of Night',
#  'Insomnia',
#  'Platoon',
#  'Seabiscuit',
#  'The Girl Next Door',
#  'The Wolverine',
#  'Elf',
#  'The Love Guru',
#  'The Big Lebowski',
#  'Star Trek',
#  'Scott Pilgrim vs. the World',
#  'The Green Mile',
#  'Madagascar',
#  'Bridesmaids',
#  'WALL·E',
#  'Ghost',
#  'Taken',
#  'The Bridge on the River Kwai',
#  'The Hangover Part II',
#  'The Ugly Truth',
#  '50 First Dates',
#  'Halloween',
#  'Girl, Interrupted',
#  'The Rookie',
#  'The English Patient',
#  'Guardians of the Galaxy',
#  'The Other Boleyn Girl',
#  'Her',
#  'Saving Mr. Banks',
#  'Gladiator',
#  'We Are Marshall',
#  'Fury',
#  'The Number 23',
#  'Lilo & Stitch',
#  'The Sixth Sense',
#  'Rise of the Planet of the Apes',
#  'The Legend of Bagger Vance',
#  'Insidious',
#  'Magic Mike XXL',
#  'Aliens',
#  'The Shining',
#  'The Pianist',
#  'Superbad',
#  'In Time',
#  'Everest',
#  "Ocean's Eleven",
#  'Revolutionary Road',
#  'Hellboy',
#  'Carrie',
#  'About Time',
#  'Bloody Sunday',
#  'Harry Potter and the Goblet of Fire',
#  'Black Swan',
#  'Jurassic World',
#  'High Fidelity',
#  'Spotlight',
#  'Rang De Basanti',
#  'American History X',
#  'Into the Wild',
#  'Cold Mountain',
#  'Seven Years in Tibet',
#  'Ray',
#  'Black Hawk Down',
#  'War of the Worlds',
#  'The Incredible Hulk',
#  'Shrek 2',
#  'Gettysburg',
#  'The Village',
#  '12 Angry Men',
#  'In the Land of Blood and Honey',
#  "A Bug's Life",
#  'The Rocker',
#  'Avatar',
#  'The Matrix',
#  'Pearl Harbor',
#  'Resident Evil',
#  'The Conjuring 2',
#  'The Monuments Men',
#  'United 93',
#  'Crazy Heart',
#  'Up',
#  'Joy',
#  'Lords of Dogtown',
#  'Captain Phillips',
#  'Interstellar',
#  'Pocahontas',
#  'Man on Fire',
#  'The Young Victoria',
#  'Inception',
#  "Hart's War",
#  "Schindler's List",
#  'The Blind Side',
#  'The Equalizer',
#  'The Secret Life of Pets',
#  'The Happening',
#  'Black Snake Moan',
#  'The Fighter',
#  'Ghostbusters',
#  'Pacific Rim',
#  'Evil Dead',
#  'Stop-Loss',
#  'The Social Network',
#  'Unbroken',
#  'The Great Escape',
#  'L.A. Confidential',
#  'Lost in Translation',
#  'Raging Bull',
#  'Rise of the Guardians',
#  'Closer',
#  'Casino',
#  'Despicable Me 2',
#  'Antz',
#  'Brave',
#  '54',
#  'Fantastic Mr. Fox',
#  'From Here to Eternity',
#  'Hot Fuzz',
#  'How to Train Your Dragon 2',
#  'Saints and Soldiers',
#  "A Hard Day's Night",
#  'A Beautiful Mind',
#  'Over the Hedge',
#  'Spectre',
#  'American Pie',
#  'The Dark Knight',
#  'In Bruges',
#  'The Others',
#  'Pride & Prejudice',
#  'Music and Lyrics',
#  'Inglourious Basterds',
#  "Ocean's Thirteen",
#  "Nick and Norah's Infinite Playlist",
#  'Tucker and Dale vs Evil',
#  'The Last Emperor',
#  'Ghost Rider',
#  '21 Jump Street',
#  "Ocean's Twelve",
#  'Tangled',
#  'Memento',
#  'Clash of the Titans',
#  'Charlie and the Chocolate Factory',
#  'The Island',
#  'Being John Malkovich',
#  'The Da Vinci Code',
#  'Finding Neverland',
#  'The Fountain',
#  'Wreck-It Ralph',
#  'Back to the Future Part III',
#  'Apollo 13',
#  'Edward Scissorhands',
#  'Changeling',
#  'Dallas Buyers Club',
#  'Jersey Boys',
#  'The Truman Show',
#  'For Love of the Game',
#  'Centurion',
#  'Groundhog Day',
#  'The Curious Case of Benjamin Button',
#  'Final Destination 2',
#  'Taxi Driver',
#  'Iron Man 2',
#  'Rock Star',
#  'The Amazing Spider-Man',
#  'Warrior',
#  'Jerry Maguire',
#  'Jackie Brown',
#  'Shrek Forever After',
#  'Control',
#  'Saw III',
#  'Horrible Bosses',
#  'Meet Joe Black',
#  '8 Mile',
#  'Angels & Demons',
#  'The Queen',
#  'Evil Dead II',
#  'Blood Diamond',
#  'Blades of Glory',
#  'Scream 2',
#  'How to Lose a Guy in 10 Days',
#  'The Waterboy',
#  'G.I. Jane',
#  'Burn After Reading',
#  'RED',
#  'Footloose',
#  'Source Code',
#  'Southpaw',
#  'The Holiday',
#  'Blade Runner',
#  'Fantastic Four',
#  'The Silence of the Lambs',
#  'Nightcrawler',
#  'The Conjuring',
#  'The Fault in Our Stars',
#  'Titanic',
#  'The Hangover',
#  'Saw',
#  'The Duchess',
#  'Harry Potter and the Prisoner of Azkaban',
#  'Any Given Sunday',
#  'Independence Day',
#  'Beetlejuice',
#  'Catch Me If You Can',
#  'Iron Man 3',
#  'Liar Liar',
#  'Non-Stop',
#  'The Longest Yard',
#  'Flashdance',
#  'To Kill a Mockingbird',
#  'Patton',
#  'The Water Diviner',
#  'When Harry Met Sally...',
#  'Snatch',
#  'Inside Out',
#  'Glory',
#  'No Country for Old Men',
#  'Garden State',
#  'Mr. & Mrs. Smith',
#  'District 9',
#  'Thor',
#  'The Matrix Reloaded',
#  'Home Alone',
#  'The Hunger Games',
#  'Blue Crush',
#  'Underworld',
#  'Looper',
#  "The King's Speech",
#  'Live Free or Die Hard',
#  'Shine',
#  'Scarface',
#  "Wayne's World",
#  'The Birth of a Nation',
#  'Jurassic Park',
#  'The Day After Tomorrow',
#  'Hotel Transylvania',
#  'A Walk to Remember',
#  'Ice Age',
#  'Public Enemies',
#  'The Bourne Supremacy',
#  'Men in Black 3',
#  'Moneyball',
#  'Some Like It Hot',
#  'The Notebook',
#  'Spider-Man',
#  'Unbreakable',
#  'Coraline',
#  'Drive',
#  'Lincoln',
#  'Blade',
#  'Friends with Benefits',
#  'The Deer Hunter',
#  'Pretty Woman',
#  'Kick-Ass',
#  'The Polar Express',
#  'Unknown',
#  'Argo',
#  'Alien',
#  'Trouble with the Curve',
#  'The Bourne Legacy',
#  'Divergent',
#  'Meet the Fockers',
#  'Training Day',
#  'Warcraft',
#  'The Amazing Spider-Man 2',
#  'Toy Story 2',
#  'Major League',
#  'Lock, Stock and Two Smoking Barrels',
#  'Ted',
#  'Me Before You',
#  'Now You See Me',
#  "Ender's Game",
#  'Hercules',
#  'Life of Pi',
#  'The Usual Suspects',
#  'The Great Gatsby',
#  'Suicide Squad',
#  'Shrek the Third',
#  'Zulu',
#  'The Terminator',
#  'Save the Last Dance',
#  'Million Dollar Baby',
#  'The Evil Dead',
#  'Shutter Island',
#  'The Princess Bride',
#  'Army of Darkness',
#  'Ratatouille',
#  "Singin' in the Rain",
#  'The Jungle Book',
#  'The Wizard of Oz',
#  'Django Unchained',
#  'Toy Story',
#  'The Best Years of Our Lives',
#  'A Bridge Too Far',
#  'The Pursuit of Happyness',
#  'The Hurt Locker',
#  'The Imitation Game',
#  'If I Stay',
#  'Legends of the Fall',
#  'Mystic River',
#  'Good Will Hunting',
#  'Spice World',
#  'Disturbia',
#  'No Strings Attached',
#  'Days of Thunder',
#  'Forrest Gump',
#  'Slumdog Millionaire',
#  'X-Men',
#  'Capote',
#  'Once',
#  'Kingpin',
#  'Once Upon a Time in America',
#  'Hotel Rwanda',
#  'Apocalypse Now',
#  'It Follows',
#  'The Red Violin',
#  "Bridget Jones's Diary",
#  'Up in the Air',
#  'The Maze Runner',
#  'Billy Elliot',
#  'Coach Carter',
#  'Easy A',
#  'As Good as It Gets',
#  'Hardball',
#  'The Avengers',
#  'Contact',
#  'The Revenant',
#  'Coyote Ugly',
#  'Braveheart',
#  'Aladdin',
#  'The Piano',
#  'Die Hard 2',
#  '10 Cloverfield Lane',
#  'Pi',
#  'American Hustle',
#  'Elizabeth',
#  'Inside Llewyn Davis',
#  'Terminator Salvation',
#  'The Beach',
#  "It's a Wonderful Life",
#  'Pineapple Express',
#  'Cube',
#  'Fight Club',
#  'Stardust',
#  'Jack Reacher',
#  'True Romance',
#  'The Bourne Ultimatum',
#  "The Emperor's New Groove",
#  'Selma',
#  'Crash',
#  'The Aviator',
#  'Men in Black',
#  'American Psycho',
#  'Hedwig and the Angry Inch',
#  'Radio',
#  'V for Vendetta',
#  'Doctor Zhivago',
#  'Sausage Party',
#  'Zombieland',
#  "There's Something About Mary",
#  '1941',
#  'The Untouchables',
#  'Despicable Me',
#  'Monsters, Inc.',
#  'The Artist',
#  'Honey',
#  'Get Him to the Greek',
#  'Here Comes the Boom',
#  'Before Sunset',
#  'Mulan',
#  'Troy',
#  'Judgment at Nuremberg',
#  'Juno',
#  'Annie Hall',
#  'Se7en',
#  '10 Things I Hate About You',
#  'Atonement',
#  'Law Abiding Citizen',
#  'The Perks of Being a Wallflower',
#  'Gangs of New York',
#  'The Woman in Black',
#  'The Assassination of Jesse James by the Coward Robert Ford',
#  'Monsters University',
#  'Flight',
#  'Black Mass',
#  'Event Horizon',
#  'Lucy',
#  'The Blair Witch Project',
#  'Oblivion',
#  'Zero Dark Thirty',
#  'JFK',
#  'The Godfather',
#  'Pitch Perfect 2',
#  'The Simpsons Movie',
#  'Signs',
#  'Green Room',
#  'American Sniper',
#  'Moon',
#  'The Descent',
#  'The Bourne Identity',
#  'The Replacements',
#  'Malcolm X',
#  'Reservoir Dogs',
#  'Brokeback Mountain',
#  'Straight Outta Compton',
#  'Coriolanus',
#  'Milk',
#  'Blow',
#  'The Alamo',
#  'Happy Feet',
#  'The Elephant Man',
#  'Beowulf',
#  'Shakespeare in Love',
#  'Requiem for a Dream',
#  'Twilight',
#  'Match Point',
#  'Step Up',
#  'Driven',
#  'Little Miss Sunshine',
#  'Man on the Moon',
#  'The Hustler',
#  'The Terminal',
#  'The Great Raid',
#  'Saw II',
#  "Captain Corelli's Mandolin",
#  'Miracle',
#  'Cast Away',
#  'The Matrix Revolutions',
#  'The 13th Warrior',
#  'The Mist',
#  'Batman Begins',
#  'Never Back Down',
#  'Kung Fu Panda 2',
#  'From Hell',
#  'Grease',
#  'Marie Antoinette',
#  '42',
#  'The Cabin in the Woods',
#  'Gran Torino',
#  'Legend',
#  'Draft Day',
#  'The Adjustment Bureau',
#  'Wanted',
#  'Donnie Brasco',
#  'Die Hard',
#  'The Transporter',
#  'A Night at the Roxbury',
#  'Indiana Jones and the Last Crusade',
#  'Windtalkers',
#  'Skyfall',
#  'Bring It On',
#  'Dark Shadows',
#  'The Rock',
#  'Gremlins',
#  'Airlift',
#  'The Incredibles',
#  'Ex Machina',
#  'Bruce Almighty',
#  'Cinderella',
#  'Kung Fu Panda',
#  'The Bodyguard',
#  'Silent Hill',
#  'Dead Poets Society',
#  'Dumb and Dumber',
#  'Frozen',
#  'Harry Potter and the Chamber of Secrets',
#  'The Fan',
#  'Chicken Run',
#  'Begin Again',
#  'World War Z',
#  'Man of Steel',
#  'Before Sunrise',
#  'Furious 7',
#  'Prisoners',
#  'American Beauty',
#  'Butch Cassidy and the Sundance Kid',
#  'E.T. the Extra-Terrestrial',
#  'Salt',
#  '28 Weeks Later',
#  'The Martian',
#  'The Secret Life of Walter Mitty',
#  'Chariots of Fire',
#  'The Longest Day',
#  'He Got Game',
#  'Cars 2',
#  'Midnight in Paris',
#  'Final Destination',
#  'Eyes Wide Shut',
#  'Blade II',
#  'School of Rock',
#  'Erin Brockovich',
#  'Tropic Thunder',
#  'Bolt',
#  'Iron Man',
#  'Sinister',
#  'Raiders of the Lost Ark',
#  'Speed',
#  'The Illusionist',
#  'Hot Rod',
#  'Inside Man',
#  'Casino Royale',
#  'Enemy at the Gates',
#  'The Reader',
#  'Donnie Darko',
#  'Point Break',
#  'Wimbledon',
#  'Drag Me to Hell',
#  'National Treasure',
#  'The Fifth Element',
#  'Romeo + Juliet',
#  'Amadeus',
#  'Transformers',
#  'Batman Returns',
#  'The Last Legion',
#  'Hail, Caesar!',
#  'Across the Universe',
#  'Catch-22',
#  'Spider-Man 3',
#  'Star Trek Into Darkness',
#  'Click',
#  'Corpse Bride',
#  'The Mask',
#  'The Insider',
#  '21',
#  'Armageddon',
#  'Lawrence of Arabia',
#  'The Purge',
#  'Taken 2',
#  'Grudge Match',
#  'We Were Soldiers',
#  'The Book Thief',
#  'Shaun of the Dead',
#  'Shrek',
#  'The Wrestler',
#  'Fifty Shades of Grey',
#  'Super 8',
#  'That Thing You Do!',
#  'Woman in Gold',
#  'Moonrise Kingdom',
#  'The Hateful Eight',
#  'Warm Bodies',
#  'The Men Who Stare at Goats',
#  'The Devil Wears Prada',
#  '2012',
#  'Hustle & Flow',
#  'Zodiac',
#  'Rocky',
#  'Harry Potter and the Order of the Phoenix',
#  'Hitch',
#  'The New World',
#  'McFarland, USA',
#  'Hostel',
#  "Rosemary's Baby",
#  'Ali',
#  'Lord of War',
#  'Million Dollar Arm',
#  'Quantum of Solace',
#  'Rio',
#  'American Gangster',
#  'Moulin Rouge!',
#  'The Sound of Music',
#  'Vicky Cristina Barcelona',
#  'The Croods',
#  'Barry Lyndon',
#  'Just Go with It',
#  'Dark City',
#  'Sicario',
#  'Men in Black II',
#  'The Theory of Everything',
#  'The Big Short',
#  'Velvet Goldmine',
#  'Tombstone',
#  'Born on the Fourth of July',
#  "She's the Man",
#  'The Last Song',
#  'Steve Jobs',
#  'Shooter',
#  'Whip It',
#  'Prometheus',
#  'Grindhouse',
#  'Trainspotting',
#  'Puss in Boots',
#  'Cloverfield',
#  'Semi-Pro',
#  'The Last Samurai',
#  'Fast Five',
#  'Pulp Fiction',
#  'The Lion King',
#  'The Iron Giant',
#  'From Dusk Till Dawn',
#  'Dear John',
#  'Silver Linings Playbook',
#  'Ed Wood',
#  'Cars',
#  'Detroit Rock City',
#  'The Doors',
#  'Forgetting Sarah Marshall',
#  'Collateral',
#  'Good Night, and Good Luck.',
#  'Scary Movie 2',
#  'Alice in Wonderland',
#  'Snow White and the Seven Dwarfs',
#  'Remember the Titans',
#  "Mr. Holland's Opus",
#  'This Is the End',
#  'Little Boy',
#  'Whiplash',
#  'Stripes',
#  'Lone Survivor',
#  'Minions',
#  "Bill & Ted's Excellent Adventure",
#  'Psycho',
#  'Rush',
#  'The Italian Job',
#  'The Hills Have Eyes',
#  'The Soloist',
#  'Knowing',
#  'Caddyshack',
#  "We're the Millers",
#  'Spider-Man 2',
#  'Burlesque',
#  'Bridge of Spies',
#  'The Machinist',
#  '22 Jump Street',
#  'Children of Men',
#  'P.S. I Love You',
#  'Gandhi',
#  'Invictus',
#  'Gone with the Wind',
#  'Amistad',
#  'The Prestige',
#  'Hugo',
#  'Eternal Sunshine of the Spotless Mind',
#  'Bad Teacher',
#  'The Runaways',
#  'Room',
#  'Predator',
#  'Sherlock Holmes',
#  'The Proposal',
#  'The Shawshank Redemption',
#  'The Grand Budapest Hotel',
#  'Tinker Tailor Soldier Spy',
#  '127 Hours',
#  'Minority Report',
#  'Walk the Line',
#  "The Devil's Advocate"]

# %%
len(common_list)
# Out:
# 749

# %%
# columns: movie_name, rating, helpful, total, date, title, review
all_movie_reviewed = pd.DataFrame(columns = ['movie_name','rating','helpful','total','date','title','review'])
# all_movie_reviewed.reindex(columns=['movie_name','rating','helpful','total','date','title','review'])
all_movie_reviewed
# Out:
# Empty DataFrame
# Columns: [movie_name, rating, helpful, total, date, title, review]
# Index: []

# %%
folder = os.listdir('/content/drive/MyDrive/DTU/Computational Tools for Data Science/project/dataset/2_reviews_per_movie_raw/')

# %%
cd /content/drive/MyDrive/DTU/Computational Tools for Data Science/project/dataset/2_reviews_per_movie_raw/
# Out:
# /content/drive/MyDrive/DTU/Computational Tools for Data Science/project/dataset/2_reviews_per_movie_raw

# %%
folder = sorted(folder,key=lambda y: y.lower())
folder[0]
# Out:
# '10 Cloverfield Lane 2016.csv'

# %%
movie_reviewed[0]
# Out:
# '10 Cloverfield Lane'

# %%
cnt = 0
df_fin = pd.DataFrame()
for files in folder:

  df = pd.read_csv(files)
  
  list_movie = []
  for j in range(len(df)):
    list_movie.append(movie_reviewed[cnt])

  df.insert(0,'movie_name',list_movie)
  df = df.drop(['username'],axis=1)
  rating_list = []
  
  helpful = []

  total = []

  date = []

  title = []

  review = []

  for i in df['rating']:
    rating_list.append(i)

  for h in df['helpful']:
    helpful.append(h)
  
  for j in df['total']:
    total.append(j)

  for k in df['date']:
    date.append(k)

  for l in df['title']:
    title.append(l)

  for m in df['review']:
    review.append(m)
  
  row = []
  row.append(movie_reviewed[cnt])
  row.append(rating_list)
  row.append(helpful)
  row.append(total)
  row.append(date)
  row.append(title)
  row.append(review)

  df_tem = pd.DataFrame(columns=['movie_name','rating','helpful','total','date','title','review'])
  df_tem = df_tem.append(pd.Series(row, index=df.columns), ignore_index=True)

  df_fin = pd.concat([df_fin,df_tem])
  cnt+=1
 
df_fin = df_fin.reset_index()
df_fin
# Out:
#       index                  movie_name  \
# 0         0         10 Cloverfield Lane
# 1         0  10 Things I Hate About You
# 2         0                12 Angry Men
# 3         0                  12 Monkeys
# 4         0                   12 Strong
# ...     ...                         ...
# 1145      0            Zero Dark Thirty
# 1146      0                      Zodiac
# 1147      0                  Zombieland
# 1148      0                    Zootopia
# 1149      0                        Zulu
#
#                                                  rating  \
# 0     [7, 5, 5, 5, 7, 9, 9, 8, 8, 9, 9, 7, 9, 10, Nu...
# 1     [Null, 10, 9, 9, 10, Null, 10, 10, 7, Null, Nu...
# 2     [10, 10, 9, 10, 10, Null, Null, 10, Null, 9, 1...
# 3     [10, Null, 9, 9, 10, 10, 9, 9, 9, 8, 10, Null,...
# 4     [1, Null, Null, 1, 2, Null, 1, 5, 1, Null, 3, ...
# ...                                                 ...
# 1145  [5, 7, 7, 5, 1, 1, 5, 10, 5, 10, 1, 1, 1, 10, ...
# 1146  [9, 8, 10, 10, 9, 7, 10, 8, 6, 10, 8, 8, 10, 8...
# 1147  [8, 8, 9, 10, 9, 8, 7, 9, 7, 8, 9, 5, 9, 8, 8,...
# 1148  [8, 10, 8, 10, 8, 9, Null, 8, 10, 10, 10, 10, ...
# 1149  [10, Null, 10, 10, Null, 10, 9, 9, Null, 9, 10...
#
#                                                 helpful  \
# 0     [102, 385, 110, 73, 42, 242, 278, 32, 165, 130...
# 1     [109, 190, 151, 113, 23, 140, 106, 15, 70, 7, ...
# 2     [764, 590, 508, 363, 418, 237, 314, 23, 206, 2...
# 3     [633, 140, 226, 141, 19, 82, 235, 27, 98, 115,...
# 4     [228, 114, 130, 98, 120, 104, 139, 118, 59, 11...
# ...                                                 ...
# 1145  [673, 73, 471, 386, 228, 354, 231, 146, 214, 2...
# 1146  [474, 398, 358, 147, 236, 173, 184, 399, 68, 2...
# 1147  [30, 254, 392, 38, 277, 114, 217, 40, 118, 174...
# 1148  [54, 91, 25, 24, 7, 59, 94, 16, 161, 21, 183, ...
# 1149  [73, 210, 153, 108, 14, 167, 97, 12, 12, 47, 1...
#
#                                                   total  \
# 0     [123, 500, 143, 100, 56, 371, 431, 44, 258, 21...
# 1     [124, 224, 178, 137, 25, 180, 142, 17, 94, 7, ...
# 2     [829, 649, 565, 405, 487, 274, 369, 24, 244, 3...
# 3     [687, 159, 262, 168, 20, 98, 294, 30, 120, 150...
# 4     [321, 158, 182, 137, 171, 148, 201, 170, 82, 1...
# ...                                                 ...
# 1145  [1019, 101, 785, 640, 377, 598, 398, 246, 381,...
# 1146  [539, 505, 457, 190, 320, 232, 250, 572, 91, 3...
# 1147  [33, 324, 542, 47, 389, 164, 323, 54, 178, 272...
# 1148  [62, 110, 29, 29, 7, 85, 141, 20, 267, 29, 331...
# 1149  [80, 240, 175, 125, 14, 204, 116, 12, 12, 54, ...
#
#                                                    date  \
# 0     [30 January 2019, 10 May 2016, 4 August 2017, ...
# 1     [13 October 2002, 27 November 2004, 5 April 19...
# 2     [1 July 2000, 18 September 2002, 23 October 20...
# 3     [29 November 2000, 13 February 2005, 15 Septem...
# 4     [13 July 2019, 12 October 2019, 22 September 2...
# ...                                                 ...
# 1145  [4 February 2013, 17 December 2013, 11 January...
# 1146  [26 March 2007, 2 March 2007, 2 March 2007, 19...
# 1147  [26 December 2019, 28 September 2009, 3 Octobe...
# 1148  [16 November 2017, 9 January 2018, 23 December...
# 1149  [6 July 2008, 14 August 2004, 6 August 2005, 9...
#
#                                                   title  \
# 0     [ Unfortunately the ending ruined an otherwise...
# 1     [ Funny, lively and enjoyable despite being a ...
# 2     [ Excellent\n,  No bombs, no car chases but ed...
# 3     [ Gilliam's Masterpiece of Madness\n,  Imagina...
# 4     [ Jingositic nonsense\n,  Don't watch this\n, ...
# ...                                                 ...
# 1145  [ Zero IQ Thirty\n,  High quality (little acti...
# 1146  [ Not Your Average Serial Killer Movie (And Th...
# 1147  [ Hop onto this drop tower ride n be ready for...
# 1148  [ "I don't know when to quit!"\n,  Best Disney...
# 1149  [ Men of Harlech onto glory.\n,  An edge of yo...
#
#                                                  review
# 0     [This movie is full of suspense. It makes you ...
# 1     [On his first day at a new school, Cameron fal...
# 2     [An excellent courtroom drama with a unique tw...
# 3     [Terry Gilliam's fantastic, twisted story of a...
# 4     [When I see films like this, it really underli...
# ...                                                 ...
# 1145  [I totally agree with the blog posted on Dawn....
# 1146  ["Zodiac" may frustrate viewers who come to Da...
# 1147  [First saw this in 2010 on a dvd which i own.\...
# 1148  [Well, I'll tell you what. I'm not a big fan o...
# 1149  ["In the hundred years since the Victoria Cros...
#
# [1150 rows x 8 columns]

# %%
df_fin = df_fin.rename(columns={"movie_name":"original_title"})
df_fin
# Out:
#       index              original_title  \
# 0         0         10 Cloverfield Lane
# 1         0  10 Things I Hate About You
# 2         0                12 Angry Men
# 3         0                  12 Monkeys
# 4         0                   12 Strong
# ...     ...                         ...
# 1145      0            Zero Dark Thirty
# 1146      0                      Zodiac
# 1147      0                  Zombieland
# 1148      0                    Zootopia
# 1149      0                        Zulu
#
#                                                  rating  \
# 0     [7, 5, 5, 5, 7, 9, 9, 8, 8, 9, 9, 7, 9, 10, Nu...
# 1     [Null, 10, 9, 9, 10, Null, 10, 10, 7, Null, Nu...
# 2     [10, 10, 9, 10, 10, Null, Null, 10, Null, 9, 1...
# 3     [10, Null, 9, 9, 10, 10, 9, 9, 9, 8, 10, Null,...
# 4     [1, Null, Null, 1, 2, Null, 1, 5, 1, Null, 3, ...
# ...                                                 ...
# 1145  [5, 7, 7, 5, 1, 1, 5, 10, 5, 10, 1, 1, 1, 10, ...
# 1146  [9, 8, 10, 10, 9, 7, 10, 8, 6, 10, 8, 8, 10, 8...
# 1147  [8, 8, 9, 10, 9, 8, 7, 9, 7, 8, 9, 5, 9, 8, 8,...
# 1148  [8, 10, 8, 10, 8, 9, Null, 8, 10, 10, 10, 10, ...
# 1149  [10, Null, 10, 10, Null, 10, 9, 9, Null, 9, 10...
#
#                                                 helpful  \
# 0     [102, 385, 110, 73, 42, 242, 278, 32, 165, 130...
# 1     [109, 190, 151, 113, 23, 140, 106, 15, 70, 7, ...
# 2     [764, 590, 508, 363, 418, 237, 314, 23, 206, 2...
# 3     [633, 140, 226, 141, 19, 82, 235, 27, 98, 115,...
# 4     [228, 114, 130, 98, 120, 104, 139, 118, 59, 11...
# ...                                                 ...
# 1145  [673, 73, 471, 386, 228, 354, 231, 146, 214, 2...
# 1146  [474, 398, 358, 147, 236, 173, 184, 399, 68, 2...
# 1147  [30, 254, 392, 38, 277, 114, 217, 40, 118, 174...
# 1148  [54, 91, 25, 24, 7, 59, 94, 16, 161, 21, 183, ...
# 1149  [73, 210, 153, 108, 14, 167, 97, 12, 12, 47, 1...
#
#                                                   total  \
# 0     [123, 500, 143, 100, 56, 371, 431, 44, 258, 21...
# 1     [124, 224, 178, 137, 25, 180, 142, 17, 94, 7, ...
# 2     [829, 649, 565, 405, 487, 274, 369, 24, 244, 3...
# 3     [687, 159, 262, 168, 20, 98, 294, 30, 120, 150...
# 4     [321, 158, 182, 137, 171, 148, 201, 170, 82, 1...
# ...                                                 ...
# 1145  [1019, 101, 785, 640, 377, 598, 398, 246, 381,...
# 1146  [539, 505, 457, 190, 320, 232, 250, 572, 91, 3...
# 1147  [33, 324, 542, 47, 389, 164, 323, 54, 178, 272...
# 1148  [62, 110, 29, 29, 7, 85, 141, 20, 267, 29, 331...
# 1149  [80, 240, 175, 125, 14, 204, 116, 12, 12, 54, ...
#
#                                                    date  \
# 0     [30 January 2019, 10 May 2016, 4 August 2017, ...
# 1     [13 October 2002, 27 November 2004, 5 April 19...
# 2     [1 July 2000, 18 September 2002, 23 October 20...
# 3     [29 November 2000, 13 February 2005, 15 Septem...
# 4     [13 July 2019, 12 October 2019, 22 September 2...
# ...                                                 ...
# 1145  [4 February 2013, 17 December 2013, 11 January...
# 1146  [26 March 2007, 2 March 2007, 2 March 2007, 19...
# 1147  [26 December 2019, 28 September 2009, 3 Octobe...
# 1148  [16 November 2017, 9 January 2018, 23 December...
# 1149  [6 July 2008, 14 August 2004, 6 August 2005, 9...
#
#                                                   title  \
# 0     [ Unfortunately the ending ruined an otherwise...
# 1     [ Funny, lively and enjoyable despite being a ...
# 2     [ Excellent\n,  No bombs, no car chases but ed...
# 3     [ Gilliam's Masterpiece of Madness\n,  Imagina...
# 4     [ Jingositic nonsense\n,  Don't watch this\n, ...
# ...                                                 ...
# 1145  [ Zero IQ Thirty\n,  High quality (little acti...
# 1146  [ Not Your Average Serial Killer Movie (And Th...
# 1147  [ Hop onto this drop tower ride n be ready for...
# 1148  [ "I don't know when to quit!"\n,  Best Disney...
# 1149  [ Men of Harlech onto glory.\n,  An edge of yo...
#
#                                                  review
# 0     [This movie is full of suspense. It makes you ...
# 1     [On his first day at a new school, Cameron fal...
# 2     [An excellent courtroom drama with a unique tw...
# 3     [Terry Gilliam's fantastic, twisted story of a...
# 4     [When I see films like this, it really underli...
# ...                                                 ...
# 1145  [I totally agree with the blog posted on Dawn....
# 1146  ["Zodiac" may frustrate viewers who come to Da...
# 1147  [First saw this in 2010 on a dvd which i own.\...
# 1148  [Well, I'll tell you what. I'm not a big fan o...
# 1149  ["In the hundred years since the Victoria Cros...
#
# [1150 rows x 8 columns]

# %%
df_5000
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# 1          http://disney.go.com/disneypictures/pirates/     285
# 2           http://www.sonypictures.com/movies/spectre/  206647
# 3                    http://www.thedarkknightrises.com/   49026
# 4                  http://movies.disney.com/john-carter   49529
# ...                                                 ...     ...
# 4798                                                NaN    9367
# 4799                                                NaN   72766
# 4800  http://www.hallmarkchannel.com/signedsealeddel...  231617
# 4801                        http://shanghaicalling.com/  126186
# 4802                                                NaN   25975
#
#                                                keywords original_language  \
# 0     [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1     [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2     [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3     [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4     [{"id": 818, "name": "based on novel"}, {"id":...                en
# ...                                                 ...               ...
# 4798  [{"id": 5616, "name": "united states\u2013mexi...                es
# 4799                                                 []                en
# 4800  [{"id": 248, "name": "date"}, {"id": 699, "nam...                en
# 4801                                                 []                en
# 4802  [{"id": 1523, "name": "obsession"}, {"id": 224...                en
#
#                                 original_title  \
# 0                                       Avatar
# 1     Pirates of the Caribbean: At World's End
# 2                                      Spectre
# 3                        The Dark Knight Rises
# 4                                  John Carter
# ...                                        ...
# 4798                               El Mariachi
# 4799                                 Newlyweds
# 4800                 Signed, Sealed, Delivered
# 4801                          Shanghai Calling
# 4802                         My Date with Drew
#
#                                                overview  popularity  \
# 0     In the 22nd century, a paraplegic Marine is di...  150.437577
# 1     Captain Barbossa, long believed to be dead, ha...  139.082615
# 2     A cryptic message from Bond’s past sends him o...  107.376788
# 3     Following the death of District Attorney Harve...  112.312950
# 4     John Carter is a war-weary, former military ca...   43.926995
# ...                                                 ...         ...
# 4798  El Mariachi just wants to play his guitar and ...   14.269792
# 4799  A newlywed couple's honeymoon is upended by th...    0.642552
# 4800  "Signed, Sealed, Delivered" introduces a dedic...    1.444476
# 4801  When ambitious New York attorney Sam is sent t...    0.857008
# 4802  Ever since the second grade when he first saw ...    1.929883
#
#                                    production_companies  \
# 0     [{"name": "Ingenious Film Partners", "id": 289...
# 1     [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 2     [{"name": "Columbia Pictures", "id": 5}, {"nam...
# 3     [{"name": "Legendary Pictures", "id": 923}, {"...
# 4           [{"name": "Walt Disney Pictures", "id": 2}]
# ...                                                 ...
# 4798           [{"name": "Columbia Pictures", "id": 5}]
# 4799                                                 []
# 4800  [{"name": "Front Street Pictures", "id": 3958}...
# 4801                                                 []
# 4802  [{"name": "rusty bear entertainment", "id": 87...
#
#                                    production_countries release_date  \
# 0     [{"iso_3166_1": "US", "name": "United States o...   2009-12-10
# 1     [{"iso_3166_1": "US", "name": "United States o...   2007-05-19
# 2     [{"iso_3166_1": "GB", "name": "United Kingdom"...   2015-10-26
# 3     [{"iso_3166_1": "US", "name": "United States o...   2012-07-16
# 4     [{"iso_3166_1": "US", "name": "United States o...   2012-03-07
# ...                                                 ...          ...
# 4798  [{"iso_3166_1": "MX", "name": "Mexico"}, {"iso...   1992-09-04
# 4799                                                 []   2011-12-26
# 4800  [{"iso_3166_1": "US", "name": "United States o...   2013-10-13
# 4801  [{"iso_3166_1": "US", "name": "United States o...   2012-05-03
# 4802  [{"iso_3166_1": "US", "name": "United States o...   2005-08-05
#
#          revenue  runtime                                   spoken_languages  \
# 0     2787965087    162.0  [{"iso_639_1": "en", "name": "English"}, {"iso...
# 1      961000000    169.0           [{"iso_639_1": "en", "name": "English"}]
# 2      880674609    148.0  [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...
# 3     1084939099    165.0           [{"iso_639_1": "en", "name": "English"}]
# 4      284139100    132.0           [{"iso_639_1": "en", "name": "English"}]
# ...          ...      ...                                                ...
# 4798     2040920     81.0      [{"iso_639_1": "es", "name": "Espa\u00f1ol"}]
# 4799           0     85.0                                                 []
# 4800           0    120.0           [{"iso_639_1": "en", "name": "English"}]
# 4801           0     98.0           [{"iso_639_1": "en", "name": "English"}]
# 4802           0     90.0           [{"iso_639_1": "en", "name": "English"}]
#
#         status                                            tagline  \
# 0     Released                        Enter the World of Pandora.
# 1     Released     At the end of the world, the adventure begins.
# 2     Released                              A Plan No One Escapes
# 3     Released                                    The Legend Ends
# 4     Released               Lost in our world, found in another.
# ...        ...                                                ...
# 4798  Released  He didn't come looking for trouble, but troubl...
# 4799  Released  A newlywed couple's honeymoon is upended by th...
# 4800  Released                                                NaN
# 4801  Released                           A New Yorker in Shanghai
# 4802  Released                                                NaN
#
#                                          title  vote_average  vote_count
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# 4                                  John Carter           6.1        2124
# ...                                        ...           ...         ...
# 4798                               El Mariachi           6.6         238
# 4799                                 Newlyweds           5.9           5
# 4800                 Signed, Sealed, Delivered           7.0           6
# 4801                          Shanghai Calling           5.7           7
# 4802                         My Date with Drew           6.3          16
#
# [4803 rows x 20 columns]

# %%
final_df = pd.merge(df_5000, df_fin, how='inner', on='original_title').reset_index()
final_df
# Out:
#      level_0     budget                                             genres  \
# 0          0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1          1  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 2          2  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 3          3  258000000  [{"id": 14, "name": "Fantasy"}, {"id": 28, "na...
# 4          4  260000000  [{"id": 16, "name": "Animation"}, {"id": 10751...
# ..       ...        ...                                                ...
# 748      748     350000                      [{"id": 18, "name": "Drama"}]
# 749      749     250000  [{"id": 53, "name": "Thriller"}, {"id": 878, "...
# 750      750     160000  [{"id": 18, "name": "Drama"}, {"id": 10402, "n...
# 751      751    8500000                      [{"id": 18, "name": "Drama"}]
# 752      752      60000  [{"id": 9648, "name": "Mystery"}, {"id": 18, "...
#
#                                              homepage      id  \
# 0                         http://www.avatarmovie.com/   19995
# 1         http://www.sonypictures.com/movies/spectre/  206647
# 2                  http://www.thedarkknightrises.com/   49026
# 3     http://www.sonypictures.com/movies/spider-man3/     559
# 4        http://disney.go.com/disneypictures/tangled/   38757
# ..                                                ...     ...
# 748                                               NaN     389
# 749                                               NaN     431
# 750               http://www.foxsearchlight.com/once/    5723
# 751  http://www.foxsearchlight.com/thebirthofanation/  339408
# 752                        http://www.pithemovie.com/     473
#
#                                               keywords original_language  \
# 0    [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1    [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 2    [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 3    [{"id": 851, "name": "dual identity"}, {"id": ...                en
# 4    [{"id": 1562, "name": "hostage"}, {"id": 2343,...                en
# ..                                                 ...               ...
# 748  [{"id": 934, "name": "judge"}, {"id": 1417, "n...                en
# 749  [{"id": 483, "name": "riddle"}, {"id": 1646, "...                en
# 750  [{"id": 578, "name": "rock and roll"}, {"id": ...                en
# 751                  [{"id": 2831, "name": "slavery"}]                en
# 752  [{"id": 2157, "name": "hacker"}, {"id": 2303, ...                en
#
#             original_title                                           overview  \
# 0                   Avatar  In the 22nd century, a paraplegic Marine is di...
# 1                  Spectre  A cryptic message from Bond’s past sends him o...
# 2    The Dark Knight Rises  Following the death of District Attorney Harve...
# 3             Spider-Man 3  The seemingly invincible Spider-Man goes up ag...
# 4                  Tangled  When the kingdom's most wanted-and most charmi...
# ..                     ...                                                ...
# 748           12 Angry Men  The defense and the prosecution have rested an...
# 749                   Cube  Seven strangers are taken out of their daily l...
# 750                   Once  A vacuum repairman moonlights as a street musi...
# 751  The Birth of a Nation  Nat Turner, a former slave in America, leads a...
# 752                     Pi  The debut film from Darren Aronofsky in which ...
#
#      popularity  ...                title_x vote_average vote_count  index  \
# 0    150.437577  ...                 Avatar          7.2      11800      0
# 1    107.376788  ...                Spectre          6.3       4466      0
# 2    112.312950  ...  The Dark Knight Rises          7.6       9106      0
# 3    115.699814  ...           Spider-Man 3          5.9       3576      0
# 4     48.681969  ...                Tangled          7.4       3330      0
# ..          ...  ...                    ...          ...        ...    ...
# 748   59.259204  ...           12 Angry Men          8.2       2078      0
# 749   44.656151  ...                   Cube          6.9       1069      0
# 750   19.052179  ...                   Once          7.3        453      0
# 751    9.452808  ...  The Birth of a Nation          6.5        178      0
# 752   27.788067  ...                     Pi          7.1        586      0
#
#                                                 rating  \
# 0    [9, 8, Null, 6, 10, 6, 10, 9, 10, 8, 9, 9, 1, ...
# 1    [9, 5, 1, Null, 3, 1, 3, 7, 7, 1, 6, 1, 10, Nu...
# 2    [10, 10, 10, 9, 9, 10, 10, 10, 10, 10, 9, 10, ...
# 3    [7, 10, 5, 6, 9, 6, 10, 10, 10, 6, Null, 10, 8...
# 4    [10, 9, 10, 10, 10, 10, 10, 8, 10, 10, 10, 10,...
# ..                                                 ...
# 748  [10, 10, 9, 10, 10, Null, Null, 10, Null, 9, 1...
# 749  [Null, 8, 8, 10, 6, 7, 10, 10, Null, 5, 5, Nul...
# 750  [9, 10, 10, 9, 9, 8, 10, 9, 10, 10, 10, 10, 9,...
# 751  [Null, 10, 10, 9, Null, 10, 7, Null, Null, Nul...
# 752  [Null, 10, 9, Null, 9, 9, 9, 7, 10, 8, 7, Null...
#
#                                                helpful  \
# 0    [43, 1777, 2272, 957, 2668, 366, 1911, 846, 58...
# 1    [52, 551, 122, 409, 175, 397, 88, 22, 188, 380...
# 2    [54, 141, 58, 91, 14, 1952, 99, 51, 41, 1439, ...
# 3    [56, 12, 1018, 526, 578, 328, 123, 101, 77, 19...
# 4    [96, 46, 363, 40, 43, 42, 316, 187, 326, 37, 2...
# ..                                                 ...
# 748  [764, 590, 508, 363, 418, 237, 314, 23, 206, 2...
# 749  [322, 268, 123, 217, 90, 78, 102, 107, 138, 20...
# 750  [261, 561, 216, 21, 30, 28, 26, 146, 22, 109, ...
# 751  [218, 166, 168, 114, 217, 51, 112, 80, 83, 106...
# 752  [26, 294, 229, 122, 125, 36, 164, 87, 79, 99, ...
#
#                                                  total  \
# 0    [47, 2705, 3506, 1463, 4223, 559, 3057, 1353, ...
# 1    [66, 790, 185, 657, 295, 700, 146, 33, 348, 74...
# 2    [57, 172, 69, 113, 15, 2804, 131, 65, 53, 2335...
# 3    [62, 12, 1478, 768, 882, 494, 181, 152, 114, 3...
# 4    [102, 48, 413, 42, 46, 45, 368, 217, 386, 40, ...
# ..                                                 ...
# 748  [829, 649, 565, 405, 487, 274, 369, 24, 244, 3...
# 749  [374, 319, 151, 275, 114, 102, 136, 149, 195, ...
# 750  [288, 635, 241, 21, 31, 29, 27, 170, 23, 127, ...
# 751  [287, 226, 238, 167, 336, 79, 188, 134, 141, 1...
# 752  [26, 368, 303, 160, 166, 45, 233, 124, 112, 14...
#
#                                                   date  \
# 0    [23 February 2020, 13 December 2009, 11 Decemb...
# 1    [13 February 2020, 9 November 2015, 4 April 20...
# 2    [12 February 2020, 1 January 2013, 20 July 201...
# 3    [24 February 2020, 5 January 2020, 6 May 2007,...
# 4    [21 August 2012, 5 January 2011, 24 November 2...
# ..                                                 ...
# 748  [1 July 2000, 18 September 2002, 23 October 20...
# 749  [26 March 2001, 19 January 2005, 17 August 199...
# 750  [24 January 2007, 9 June 2007, 26 January 2007...
# 751  [26 January 2005, 31 July 2005, 9 February 200...
# 752  [24 May 2004, 15 May 2000, 9 November 1999, 11...
#
#                                                title_y  \
# 0    [ Great\n,  After a decade, Cameron sets the a...
# 1    [ 007\n,  Let down by poor script, confused to...
# 2    [ Batman\n,  A wonderful conclusion to a wonde...
# 3    [ I enjoyed this movie\n,  Spiderman Into Dark...
# 4    [ Definitely one of the best animated films I'...
# ..                                                 ...
# 748  [ Excellent\n,  No bombs, no car chases but ed...
# 749  [ This is one freaky movie...\n,  Low Budget, ...
# 750  [ Music Music Music Music\n,  The heart has re...
# 751  [ The Conventional Wisdom is Partially Right\n...
# 752  [ psihedellic\n,  Indie film at its best\n,  F...
#
#                                                 review
# 0    [Avatar tells a familiar story but its a story...
# 1    [Spectre was a classy action movie....making t...
# 2    [Christopher Nolan's epic trilogy concludes in...
# 3    [And of course the rumor of three good movies ...
# 4    [Let me start by saying that I'm an 18 year ol...
# ..                                                 ...
# 748  [An excellent courtroom drama with a unique tw...
# 749  [Cube is a movie that explores human nature an...
# 750  [This is a wonderful, fun and touching movie. ...
# 751  [The conventional wisdom about "The Birth of a...
# 752  [3.1415926535897932384626433832795028841971693...
#
# [753 rows x 28 columns]

# %%
final_df.to_pickle('/content/drive/MyDrive/DTU/Computational Tools for Data Science/project/final_df.pkl')
