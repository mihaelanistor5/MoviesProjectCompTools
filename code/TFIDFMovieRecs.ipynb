# %%
import pandas as pd
import os
import glob
import re
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.metrics import adjusted_rand_score
import matplotlib.pyplot as plt
import numpy as np
import ast

# %%
def combine_document(df,movielist):
    DocumentDict = {}
    for movie in movielist:
        keywords = ''
        document = df[df['original_title'] == movie]['keywords']
        for ele in ast.literal_eval(document.values[0]):
            keywords += ele['name']+' '
        keywords += str(df[df['original_title'] == movie]['overview'])
        DocumentDict[movie] = keywords
    return DocumentDict

def train_model(Dict,nclusters,vectorizer):
    documents = DocumentDict.values()
    X = vectorizer.fit_transform(documents)
    return X

def score_movies(Dict,vectorizer):
    MovieDict = {}
    for movie in Dict:
        Y = vectorizer.transform([Dict[movie]])
        MovieDict[movie] = Y
    return MovieDict

def recommend_movies(Dict,movie1,n_recs):
    RecDict = {}
    for movie in Dict:
        dotprod = np.dot(Dict[movie1].toarray(),np.transpose(Dict[movie].toarray()))
        RecDict[movie] = dotprod
    recs = sorted(RecDict, key=RecDict.get, reverse=True)[1:n_recs+1]
    print('If you liked '+movie1+' you will also like:')
    print(recs)
    return RecDict

# %%
df1 = pd.read_csv('./sentiment_dataset/ratings_and_sentiment_v2.csv')
directory = './dataset_5000/tmdb_5000_movies.csv'
df = pd.read_csv(directory)
# Find the common movies between the two conflicting datasets
common = []    
for movie in df['original_title']:
    if movie in df1['original_title'].tolist():
        common.append(movie)

# Initialize the TFIDF vectorizer
vectorizer = TfidfVectorizer(stop_words='english')
# Compile all the movie documents, i.e. keywords and movie descriptions
DocumentDict = combine_document(df,common)
# Once we have the list of movies and dataframes we compute the TFIDF scores of all the documents
model = train_model(DocumentDict,10,vectorizer)
# Create a dictionary that organizes movies with their TFIDF matrix
MovieDict = score_movies(DocumentDict,vectorizer)
# Finally given any movie in the dataset, the 5 movies with the most in common will be recommended
recommend_movies(MovieDict,'Borat: Cultural Learnings of America for Make Benefit Glorious Nation of Kazakhstan',5)
# Out:
# If you liked Borat: Cultural Learnings of America for Make Benefit Glorious Nation of Kazakhstan you will also like:
# ['Good Night, and Good Luck.', 'Chicken Run', 'Zodiac', 'Love Actually', 'American Beauty']
# {'Avatar': array([[0.02644983]]),
#  "Pirates of the Caribbean: At World's End": array([[0.01790174]]),
#  'Spectre': array([[0.00427673]]),
#  'The Dark Knight Rises': array([[0.00283706]]),
#  'Spider-Man 3': array([[0.00327108]]),
#  'Tangled': array([[0.01415989]]),
#  'Avengers: Age of Ultron': array([[0.01777868]]),
#  'Batman v Superman: Dawn of Justice': array([[0.00341671]]),
#  'Quantum of Solace': array([[0.00479516]]),
#  "Pirates of the Caribbean: Dead Man's Chest": array([[0.01751397]]),
#  'Man of Steel': array([[0.00382914]]),
#  'The Avengers': array([[0.03375739]]),
#  'Pirates of the Caribbean: On Stranger Tides': array([[0.01807983]]),
#  'Men in Black 3': array([[0.00390799]]),
#  'The Hobbit: The Battle of the Five Armies': array([[0.00372206]]),
#  'The Amazing Spider-Man': array([[0.01348586]]),
#  'The Hobbit: The Desolation of Smaug': array([[0.0041235]]),
#  'Titanic': array([[0.00261242]]),
#  'Captain America: Civil War': array([[0.03556539]]),
#  'Jurassic World': array([[0.00295545]]),
#  'Skyfall': array([[0.00306165]]),
#  'Spider-Man 2': array([[0.00379968]]),
#  'Iron Man 3': array([[0.01519698]]),
#  'Alice in Wonderland': array([[0.00376298]]),
#  'X-Men: The Last Stand': array([[0.02368701]]),
#  'Monsters University': array([[0.02464626]]),
#  'Transformers: Revenge of the Fallen': array([[0.01850585]]),
#  'The Amazing Spider-Man 2': array([[0.00391499]]),
#  'Cars 2': array([[0.01900829]]),
#  'Toy Story 3': array([[0.04256393]]),
#  'Terminator Salvation': array([[0.0033545]]),
#  'Furious 7': array([[0.00361208]]),
#  'World War Z': array([[0.00392216]]),
#  'X-Men: Days of Future Past': array([[0.02169657]]),
#  'Star Trek Into Darkness': array([[0.00422253]]),
#  'The Great Gatsby': array([[0.0051729]]),
#  'Prince of Persia: The Sands of Time': array([[0.00406103]]),
#  'Pacific Rim': array([[0.01965721]]),
#  'Transformers: Dark of the Moon': array([[0.01553411]]),
#  'Brave': array([[0.05072706]]),
#  'WALL·E': array([[0.00663069]]),
#  '2012': array([[0.00305684]]),
#  'The Chronicles of Narnia: The Lion, the Witch and the Wardrobe': array([[0.01435608]]),
#  'X-Men: Apocalypse': array([[0.02168049]]),
#  'The Dark Knight': array([[0.00267719]]),
#  'Up': array([[0.01693531]]),
#  'Iron Man': array([[0.01756887]]),
#  'Hugo': array([[0.00325656]]),
#  'Suicide Squad': array([[0.0312662]]),
#  'Edge of Tomorrow': array([[0.00373604]]),
#  'Inside Out': array([[0.01837372]]),
#  'The Jungle Book': array([[0.03572432]]),
#  'Iron Man 2': array([[0.02491894]]),
#  'Captain America: The Winter Soldier': array([[0.03435226]]),
#  'Shrek Forever After': array([[0.00538945]]),
#  'Big Hero 6': array([[0.01726912]]),
#  'Wreck-It Ralph': array([[0.02414535]]),
#  'The Polar Express': array([[0.00354088]]),
#  'How to Train Your Dragon': array([[0.00332833]]),
#  'Terminator 3: Rise of the Machines': array([[0.00311203]]),
#  'Guardians of the Galaxy': array([[0.03441186]]),
#  'Interstellar': array([[0.00223292]]),
#  'Inception': array([[0.0039566]]),
#  'The Hobbit: An Unexpected Journey': array([[0.00273892]]),
#  'The Fast and the Furious': array([[0.03123588]]),
#  'The Curious Case of Benjamin Button': array([[0.0048766]]),
#  'X-Men: First Class': array([[0.00338034]]),
#  'Shrek the Third': array([[0.02461171]]),
#  'Warcraft': array([[0.00303733]]),
#  'Pearl Harbor': array([[0.00374767]]),
#  'Transformers': array([[0.02023035]]),
#  'Alexander': array([[0.00346316]]),
#  'Harry Potter and the Order of the Phoenix': array([[0.01997956]]),
#  'Harry Potter and the Goblet of Fire': array([[0.03623867]]),
#  'Hancock': array([[0.01704376]]),
#  'I Am Legend': array([[0.0039908]]),
#  'Charlie and the Chocolate Factory': array([[0.00338733]]),
#  'Ratatouille': array([[0.00259723]]),
#  'Batman Begins': array([[0.00235528]]),
#  'Madagascar: Escape 2 Africa': array([[0.01426264]]),
#  'X-Men Origins: Wolverine': array([[0.04138975]]),
#  'The Matrix Revolutions': array([[0.00211835]]),
#  'Frozen': array([[0.01953097]]),
#  'The Matrix Reloaded': array([[0.00266976]]),
#  'Thor: The Dark World': array([[0.03140005]]),
#  'Mad Max: Fury Road': array([[0.00362555]]),
#  'Angels & Demons': array([[0.0329293]]),
#  'Thor': array([[0.01697382]]),
#  'Bolt': array([[0.0146862]]),
#  'Dark Shadows': array([[0.00296339]]),
#  'Mission: Impossible - Rogue Nation': array([[0.00417283]]),
#  'Kung Fu Panda 2': array([[0.00452646]]),
#  'Mission: Impossible III': array([[0.00209281]]),
#  'Troy': array([[0.00220814]]),
#  "Madagascar 3: Europe's Most Wanted": array([[0.00536661]]),
#  'Ghostbusters': array([[0.00408166]]),
#  'Armageddon': array([[0.01258109]]),
#  'Men in Black II': array([[0.0032464]]),
#  'Beowulf': array([[0.00287671]]),
#  'Mission: Impossible - Ghost Protocol': array([[0.00434591]]),
#  'Rise of the Guardians': array([[0.01652162]]),
#  'The Last Samurai': array([[0.00227463]]),
#  'Star Trek': array([[0.00271831]]),
#  'Spider-Man': array([[0.00366074]]),
#  'How to Train Your Dragon 2': array([[0.00357759]]),
#  'Watchmen': array([[0.00302624]]),
#  'Captain America: The First Avenger': array([[0.04155977]]),
#  'The Twilight Saga: Breaking Dawn - Part 2': array([[0.00268282]]),
#  'The Incredible Hulk': array([[0.00282748]]),
#  'The Revenant': array([[0.08730273]]),
#  'Rango': array([[0.00306077]]),
#  'The Bourne Ultimatum': array([[0.0027476]]),
#  'Kung Fu Panda': array([[0.01475159]]),
#  'Ant-Man': array([[0.03859814]]),
#  'The Hunger Games: Catching Fire': array([[0.00291341]]),
#  'War of the Worlds': array([[0.00392602]]),
#  'Puss in Boots': array([[0.00539994]]),
#  'Salt': array([[0.00280585]]),
#  'The Adventures of Tintin': array([[0.06555775]]),
#  'Harry Potter and the Prisoner of Azkaban': array([[0.03371781]]),
#  'Megamind': array([[0.07270756]]),
#  'Pirates of the Caribbean: The Curse of the Black Pearl': array([[0.01405399]]),
#  'The Hunger Games: Mockingjay - Part 1': array([[0.00345893]]),
#  'The Da Vinci Code': array([[0.00255275]]),
#  'Fast Five': array([[0.01468755]]),
#  'Sherlock Holmes: A Game of Shadows': array([[0.00434594]]),
#  'Clash of the Titans': array([[0.0027982]]),
#  'Total Recall': array([[0.00294647]]),
#  'The 13th Warrior': array([[0.00359377]]),
#  'The Bourne Legacy': array([[0.00245976]]),
#  'The Day After Tomorrow': array([[0.00217413]]),
#  'Mission: Impossible II': array([[0.00287959]]),
#  'Life of Pi': array([[0.00354006]]),
#  'Ghost Rider': array([[0.00389711]]),
#  'Prometheus': array([[0.01722071]]),
#  'Elysium': array([[0.00505045]]),
#  'Oblivion': array([[0.00421298]]),
#  'Star Wars: Episode III - Revenge of the Sith': array([[0.00356203]]),
#  'Star Wars: Episode II - Attack of the Clones': array([[0.00314833]]),
#  'Monsters, Inc.': array([[0.00297515]]),
#  'The Wolverine': array([[0.01826853]]),
#  'Star Wars: Episode I - The Phantom Menace': array([[0.00404997]]),
#  'The Croods': array([[0.03473333]]),
#  'Windtalkers': array([[0.00344762]]),
#  'Gravity': array([[0.00403374]]),
#  'Fantastic Four': array([[0.00365362]]),
#  'The Patriot': array([[0.03163597]]),
#  "Ocean's Twelve": array([[0.00346577]]),
#  'Mr. & Mrs. Smith': array([[0.00308944]]),
#  'The Aviator': array([[0.00386746]]),
#  "Ender's Game": array([[0.02098973]]),
#  'Live Free or Die Hard': array([[0.02466793]]),
#  'The Lord of the Rings: The Fellowship of the Ring': array([[0.00310361]]),
#  'Ali': array([[0.03954743]]),
#  'I, Robot': array([[0.00356855]]),
#  'The Martian': array([[0.01336903]]),
#  'The Island': array([[0.00422101]]),
#  'Gladiator': array([[0.00280399]]),
#  'Minority Report': array([[0.0037294]]),
#  'Harry Potter and the Chamber of Secrets': array([[0.0378856]]),
#  'Casino Royale': array([[0.00349984]]),
#  'Terminator 2: Judgment Day': array([[0.00304509]]),
#  'Public Enemies': array([[0.00357995]]),
#  'American Gangster': array([[0.0161516]]),
#  'Django Unchained': array([[0.01527618]]),
#  "The Emperor's New Groove": array([[0.00383425]]),
#  'The Expendables 2': array([[0.00341018]]),
#  'National Treasure': array([[0.00352849]]),
#  'Blood Diamond': array([[0.0548165]]),
#  'The Wolf of Wall Street': array([[0.00345475]]),
#  'Cloud Atlas': array([[0.01921789]]),
#  'Hercules': array([[0.00437947]]),
#  'Point Break': array([[0.00363109]]),
#  'The Mummy Returns': array([[0.00543378]]),
#  'Gangs of New York': array([[0.00347126]]),
#  'Black Hawk Down': array([[0.00346063]]),
#  'The Fifth Element': array([[0.00236343]]),
#  'Ice Age: Continental Drift': array([[0.00306202]]),
#  'Cinderella': array([[0.00374806]]),
#  'Finding Nemo': array([[0.02565402]]),
#  'The Lord of the Rings: The Return of the King': array([[0.00340459]]),
#  'The Lord of the Rings: The Two Towers': array([[0.00333458]]),
#  'Rise of the Planet of the Apes': array([[0.00377546]]),
#  'The Alamo': array([[0.00519707]]),
#  'The Incredibles': array([[0.00387433]]),
#  'Men in Black': array([[0.00304889]]),
#  'Toy Story 2': array([[0.01308833]]),
#  'Cloudy with a Chance of Meatballs': array([[0.00513848]]),
#  'Ice Age: Dawn of the Dinosaurs': array([[0.01929417]]),
#  'The Secret Life of Walter Mitty': array([[0.0031071]]),
#  'The Departed': array([[0.00327685]]),
#  'Mulan': array([[0.00468264]]),
#  'Tropic Thunder': array([[0.01542336]]),
#  'The Girl with the Dragon Tattoo': array([[0.05543178]]),
#  'Sherlock Holmes': array([[0.00317149]]),
#  'Ben-Hur': array([[0.0052917]]),
#  'Valkyrie': array([[0.00291301]]),
#  'Contact': array([[0.00249319]]),
#  'Rio': array([[0.01767132]]),
#  'K-19: The Widowmaker': array([[0.00366894]]),
#  'Cinderella Man': array([[0.00308921]]),
#  'Seabiscuit': array([[0.00428934]]),
#  'Cast Away': array([[0.00345045]]),
#  'Happy Feet': array([[0.01734948]]),
#  'The Bourne Supremacy': array([[0.00281608]]),
#  "Ocean's Eleven": array([[0.02884437]]),
#  'Hotel Transylvania': array([[0.01376584]]),
#  'Enchanted': array([[0.0037853]]),
#  'The Holiday': array([[0.00339919]]),
#  "Ocean's Thirteen": array([[0.00408068]]),
#  'Divergent': array([[0.00407614]]),
#  'Enemy at the Gates': array([[0.00474155]]),
#  'Meet Joe Black': array([[0.00378073]]),
#  'Scott Pilgrim vs. the World': array([[0.01869328]]),
#  'Click': array([[0.00280952]]),
#  'Hellboy II: The Golden Army': array([[0.00287731]]),
#  'Zodiac': array([[0.10828829]]),
#  'Bruce Almighty': array([[0.00364797]]),
#  'The Expendables': array([[0.01560192]]),
#  'Mission: Impossible': array([[0.00273804]]),
#  'The Hunger Games': array([[0.00303039]]),
#  'The Hangover Part II': array([[0.01852523]]),
#  'Batman Returns': array([[0.00264464]]),
#  'Over the Hedge': array([[0.03352186]]),
#  'Lilo & Stitch': array([[0.00329279]]),
#  'The Longest Yard': array([[0.00445886]]),
#  'Shutter Island': array([[0.00389957]]),
#  'Just Go with It': array([[0.00359426]]),
#  'Con Air': array([[0.00305142]]),
#  'Cold Mountain': array([[0.00449261]]),
#  'Space Jam': array([[0.02851383]]),
#  'Fury': array([[0.00421539]]),
#  'Thirteen Days': array([[0.03948449]]),
#  'A Beautiful Mind': array([[0.00288203]]),
#  'The Lion King': array([[0.00365568]]),
#  'The Secret Life of Pets': array([[0.00323041]]),
#  'Despicable Me 2': array([[0.05708962]]),
#  'Independence Day': array([[0.00375264]]),
#  'The Lost World: Jurassic Park': array([[0.00343874]]),
#  'Madagascar': array([[0.00432899]]),
#  'Children of Men': array([[0.00377877]]),
#  'X-Men': array([[0.00451622]]),
#  'Wanted': array([[0.00461175]]),
#  'The Rock': array([[0.00397592]]),
#  'Ice Age: The Meltdown': array([[0.00307067]]),
#  '50 First Dates': array([[0.00448811]]),
#  'Now You See Me': array([[0.00353375]]),
#  'The Terminal': array([[0.00256344]]),
#  'Shark Tale': array([[0.00423291]]),
#  'Dreamgirls': array([[0.00261373]]),
#  'Munich': array([[0.00249409]]),
#  'Unbreakable': array([[0.00411398]]),
#  'Minions': array([[0.03817538]]),
#  'Sucker Punch': array([[0.00405644]]),
#  'Talladega Nights: The Ballad of Ricky Bobby': array([[0.02713244]]),
#  'Braveheart': array([[0.00409874]]),
#  'Jarhead': array([[0.00368981]]),
#  'The Simpsons Movie': array([[0.01220127]]),
#  'Driven': array([[0.00427012]]),
#  'The Village': array([[0.00336926]]),
#  'Signs': array([[0.00197209]]),
#  'Shrek 2': array([[0.00335147]]),
#  'Cars': array([[0.02721717]]),
#  'Inglourious Basterds': array([[0.05942559]]),
#  'Die Hard 2': array([[0.04650906]]),
#  'Vanilla Sky': array([[0.00469204]]),
#  'We Were Soldiers': array([[0.00334439]]),
#  'Big Fish': array([[0.00336017]]),
#  'The Monuments Men': array([[0.00458704]]),
#  'Stardust': array([[0.00356016]]),
#  'Seven Years in Tibet': array([[0.00300447]]),
#  "Hart's War": array([[0.00330485]]),
#  'The Twilight Saga: Eclipse': array([[0.00477214]]),
#  'Despicable Me': array([[0.0133079]]),
#  'The Insider': array([[0.03361581]]),
#  'The Finest Hours': array([[0.00338798]]),
#  'Abraham Lincoln: Vampire Hunter': array([[0.03184135]]),
#  'The Last Legion': array([[0.00279876]]),
#  'Saving Private Ryan': array([[0.00256659]]),
#  'Ice Age': array([[0.00218694]]),
#  'Lincoln': array([[0.02311682]]),
#  'The Matrix': array([[0.0033056]]),
#  'Apollo 13': array([[0.0027805]]),
#  'Les Misérables': array([[0.00351314]]),
#  'Unbroken': array([[0.0039522]]),
#  'World Trade Center': array([[0.00337354]]),
#  'Eyes Wide Shut': array([[0.0035647]]),
#  'Fight Club': array([[0.00416874]]),
#  'We Are Marshall': array([[0.00479467]]),
#  'Everest': array([[0.00329856]]),
#  'Jurassic Park': array([[0.00291248]]),
#  'U-571': array([[0.00492528]]),
#  'The Love Guru': array([[0.00309975]]),
#  'The Hateful Eight': array([[0.00345236]]),
#  'Blades of Glory': array([[0.00380829]]),
#  '300': array([[0.00418257]]),
#  'Meet the Fockers': array([[0.02897179]]),
#  'The Green Mile': array([[0.02256408]]),
#  'Gone Girl': array([[0.00303129]]),
#  'The Bourne Identity': array([[0.00247651]]),
#  'The Truman Show': array([[0.0040297]]),
#  'The Italian Job': array([[0.02346952]]),
#  'Antz': array([[0.0036509]]),
#  'Days of Thunder': array([[0.00370637]]),
#  'RED': array([[0.00456274]]),
#  'Any Given Sunday': array([[0.00340619]]),
#  'Collateral': array([[0.03274535]]),
#  'Jack Reacher': array([[0.00525988]]),
#  'Coraline': array([[0.03674381]]),
#  'The Happening': array([[0.00432286]]),
#  'Man on Fire': array([[0.00319644]]),
#  'Hellboy': array([[0.01636985]]),
#  'Joy': array([[0.00458623]]),
#  'Alien: Resurrection': array([[0.00271989]]),
#  'Shooter': array([[0.00379133]]),
#  'The Lego Movie': array([[0.01403826]]),
#  'Invictus': array([[0.01327086]]),
#  'Trouble with the Curve': array([[0.00225105]]),
#  'The Soloist': array([[0.08125457]]),
#  'The Legend of Bagger Vance': array([[0.00436195]]),
#  'Event Horizon': array([[0.02553171]]),
#  'The Great Raid': array([[0.00335647]]),
#  'Deadpool': array([[0.06891842]]),
#  'American Sniper': array([[0.00382947]]),
#  'Resident Evil: Afterlife': array([[0.01684602]]),
#  "The Devil's Advocate": array([[0.04296131]]),
#  "Captain Corelli's Mandolin": array([[0.00302659]]),
#  'Forrest Gump': array([[0.00277415]]),
#  'Meet the Parents': array([[0.00332677]]),
#  'Pocahontas': array([[0.00223358]]),
#  'Hitch': array([[0.00410191]]),
#  'Captain Phillips': array([[0.00263996]]),
#  'The Equalizer': array([[0.0344106]]),
#  'The Pursuit of Happyness': array([[0.00339498]]),
#  'Kill Bill: Vol. 1': array([[0.00312027]]),
#  'Kill Bill: Vol. 2': array([[0.0338574]]),
#  'Semi-Pro': array([[0.00352223]]),
#  'Changeling': array([[0.03511135]]),
#  'The Fan': array([[0.0388988]]),
#  'Elizabeth: The Golden Age': array([[0.00300773]]),
#  'Burlesque': array([[0.00369828]]),
#  'Blade II': array([[0.00244866]]),
#  'The Godfather: Part III': array([[0.00383837]]),
#  'Moulin Rouge!': array([[0.00266225]]),
#  'Black Mass': array([[0.00499552]]),
#  'Law Abiding Citizen': array([[0.00372627]]),
#  'Grindhouse': array([[0.0049085]]),
#  'Catch Me If You Can': array([[0.00327059]]),
#  'Zero Dark Thirty': array([[0.00193066]]),
#  'Mamma Mia!': array([[0.01771468]]),
#  'The Thin Red Line': array([[0.0027125]]),
#  'Man on the Moon': array([[0.00582434]]),
#  'Casino': array([[0.00469296]]),
#  'The Twilight Saga: New Moon': array([[0.00435928]]),
#  'Shrek': array([[0.00345429]]),
#  'The Adjustment Bureau': array([[0.00301449]]),
#  'Jerry Maguire': array([[0.00432758]]),
#  'Ted': array([[0.04885056]]),
#  'As Good as It Gets': array([[0.00314649]]),
#  'Super 8': array([[0.02030195]]),
#  'Erin Brockovich': array([[0.0043673]]),
#  'How to Lose a Guy in 10 Days': array([[0.0727286]]),
#  '22 Jump Street': array([[0.089572]]),
#  'Yes Man': array([[0.00477518]]),
#  'Inside Man': array([[0.00347162]]),
#  'Knowing': array([[0.00292558]]),
#  'Moneyball': array([[0.03514633]]),
#  'Non-Stop': array([[0.00414572]]),
#  'V for Vendetta': array([[0.00230226]]),
#  'Hansel & Gretel: Witch Hunters': array([[0.01212456]]),
#  'G.I. Jane': array([[0.00264344]]),
#  'The Game': array([[0.00360301]]),
#  'Silent Hill': array([[0.00249012]]),
#  'The Replacements': array([[0.00361199]]),
#  'Resident Evil: Apocalypse': array([[0.00463255]]),
#  'The Beach': array([[0.04143281]]),
#  'For Love of the Game': array([[0.00432592]]),
#  'The Iron Giant': array([[0.00396636]]),
#  'Indiana Jones and the Last Crusade': array([[0.00270715]]),
#  'Child 44': array([[0.00338142]]),
#  '3:10 to Yuma': array([[0.00268176]]),
#  'Insomnia': array([[0.00357211]]),
#  'Liar Liar': array([[0.04095812]]),
#  'Taken 2': array([[0.00288437]]),
#  'Prisoners': array([[0.00449485]]),
#  'Training Day': array([[0.00381505]]),
#  'Scary Movie 2': array([[0.00493954]]),
#  'Blade': array([[0.0019283]]),
#  'Coach Carter': array([[0.02393627]]),
#  'Coyote Ugly': array([[0.00468034]]),
#  'Love Actually': array([[0.10588403]]),
#  "A Bug's Life": array([[0.01693635]]),
#  'From Hell': array([[0.00463129]]),
#  'Resident Evil: Extinction': array([[0.00425398]]),
#  'Across the Universe': array([[0.03553392]]),
#  'Revolutionary Road': array([[0.00413175]]),
#  'The Producers': array([[0.02023544]]),
#  'Argo': array([[0.00251272]]),
#  '21 Jump Street': array([[0.07618219]]),
#  'Notting Hill': array([[0.00327227]]),
#  'Chicken Run': array([[0.11007805]]),
#  'Here Comes the Boom': array([[0.03956172]]),
#  'Lord of War': array([[0.00430834]]),
#  '8 Mile': array([[0.00327987]]),
#  'The Sixth Sense': array([[0.003437]]),
#  'American Hustle': array([[0.00500392]]),
#  'The Proposal': array([[0.01531909]]),
#  'Back to the Future Part II': array([[0.01840442]]),
#  'Lucy': array([[0.00296002]]),
#  'Fifty Shades of Grey': array([[0.00429998]]),
#  'Lone Survivor': array([[0.00423096]]),
#  'The Conjuring 2': array([[0.00349609]]),
#  'The Social Network': array([[0.0031468]]),
#  'Back to the Future Part III': array([[0.02791824]]),
#  '42': array([[0.00490763]]),
#  'Ray': array([[0.00272916]]),
#  'Sin City': array([[0.0026198]]),
#  'I Love You, Man': array([[0.0230272]]),
#  'JFK': array([[0.00300057]]),
#  'Bridge of Spies': array([[0.00375297]]),
#  'Get Him to the Greek': array([[0.03401541]]),
#  'Unknown': array([[0.00402623]]),
#  'The Prestige': array([[0.00393176]]),
#  'Jersey Boys': array([[0.00531881]]),
#  'Amistad': array([[0.00340958]]),
#  'Music and Lyrics': array([[0.00408885]]),
#  'The Doors': array([[0.03014638]]),
#  'The Other Boleyn Girl': array([[0.00416294]]),
#  'Marie Antoinette': array([[0.00374322]]),
#  'Fantastic Mr. Fox': array([[0.00379906]]),
#  'Disturbia': array([[0.0050027]]),
#  'Grudge Match': array([[0.00412623]]),
#  'The Ugly Truth': array([[0.00416377]]),
#  'The Hurricane': array([[0.0264581]]),
#  'Rock Star': array([[0.00391862]]),
#  'The Thing': array([[0.00340318]]),
#  'Creed': array([[0.00427508]]),
#  'The Town': array([[0.00268997]]),
#  'Burn After Reading': array([[0.00338827]]),
#  'Rush': array([[0.00427866]]),
#  'Twilight': array([[0.01666258]]),
#  "We're the Millers": array([[0.00448489]]),
#  'The Hangover': array([[0.0147347]]),
#  'The Blind Side': array([[0.03539229]]),
#  'Horrible Bosses': array([[0.01991353]]),
#  'The Devil Wears Prada': array([[0.05862477]]),
#  '21': array([[0.00365034]]),
#  'The English Patient': array([[0.00264349]]),
#  'L.A. Confidential': array([[0.00297327]]),
#  'A Nightmare on Elm Street': array([[0.00331633]]),
#  'Radio': array([[0.03337142]]),
#  'Friends with Benefits': array([[0.04681019]]),
#  'Saving Mr. Banks': array([[0.06829008]]),
#  'Malcolm X': array([[0.00246115]]),
#  'The Benchwarmers': array([[0.00398665]]),
#  'Donnie Brasco': array([[0.00337025]]),
#  'Resident Evil': array([[0.005089]]),
#  'In Time': array([[0.00359951]]),
#  'The Pianist': array([[0.0024662]]),
#  'Closer': array([[0.00272623]]),
#  'Concussion': array([[0.00333887]]),
#  'Wimbledon': array([[0.00349032]]),
#  'Walk Hard: The Dewey Cox Story': array([[0.01542801]]),
#  'The Young Victoria': array([[0.0035896]]),
#  'The Maze Runner': array([[0.00328847]]),
#  'The Fountain': array([[0.00359672]]),
#  'The Reader': array([[0.00351653]]),
#  'Elf': array([[0.00362288]]),
#  'Nacho Libre': array([[0.00468637]]),
#  'Bridesmaids': array([[0.002669]]),
#  'This Is the End': array([[0.00340832]]),
#  'Source Code': array([[0.00374561]]),
#  'The Number 23': array([[0.00406867]]),
#  '1941': array([[0.0393351]]),
#  'Apocalypse Now': array([[0.00350485]]),
#  "Mr. Holland's Opus": array([[0.00384416]]),
#  'Flight': array([[0.00268875]]),
#  'The Grand Budapest Hotel': array([[0.00316461]]),
#  'Toy Story': array([[0.0033085]]),
#  'Speed': array([[0.00375642]]),
#  'Remember the Titans': array([[0.01669265]]),
#  'Se7en': array([[0.00323754]]),
#  'District 9': array([[0.03869974]]),
#  'Mystic River': array([[0.00332079]]),
#  'Million Dollar Baby': array([[0.00353376]]),
#  'The Notebook': array([[0.00368346]]),
#  'Legends of the Fall': array([[0.00440169]]),
#  'Up in the Air': array([[0.01786179]]),
#  'Warm Bodies': array([[0.00400118]]),
#  'Looper': array([[0.00324621]]),
#  'Forgetting Sarah Marshall': array([[0.00459596]]),
#  'Midnight in Paris': array([[0.0038791]]),
#  'Blow': array([[0.00369172]]),
#  'P.S. I Love You': array([[0.00407685]]),
#  'Atonement': array([[0.00324017]]),
#  'Corpse Bride': array([[0.00270936]]),
#  'Glory Road': array([[0.00419904]]),
#  'Sicario': array([[0.00274113]]),
#  'Southpaw': array([[0.00558758]]),
#  'Drag Me to Hell': array([[0.00364758]]),
#  'Blue Crush': array([[0.00426846]]),
#  'Stranger Than Fiction': array([[0.00441284]]),
#  '30 Days of Night': array([[0.00402447]]),
#  'The Cabin in the Woods': array([[0.00338294]]),
#  'Carrie': array([[0.02361188]]),
#  'The New World': array([[0.0052372]]),
#  'Glory': array([[0.00369425]]),
#  'Once Upon a Time in America': array([[0.00385777]]),
#  'The Assassination of Jesse James by the Coward Robert Ford': array([[0.00307553]]),
#  'Sausage Party': array([[0.00330968]]),
#  'Pitch Perfect 2': array([[0.04681541]]),
#  'Walk the Line': array([[0.0033575]]),
#  'Aladdin': array([[0.02069407]]),
#  'Straight Outta Compton': array([[0.02165512]]),
#  'Die Hard': array([[0.05027514]]),
#  'The Big Short': array([[0.00323479]]),
#  'Miracle': array([[0.0276955]]),
#  'Dawn of the Dead': array([[0.01305669]]),
#  'Identity': array([[0.00415518]]),
#  'Kick-Ass': array([[0.02242984]]),
#  'Pride & Prejudice': array([[0.00334256]]),
#  'Blade Runner': array([[0.00310756]]),
#  'Knocked Up': array([[0.01542598]]),
#  'Lucky Number Slevin': array([[0.00273236]]),
#  'Dark City': array([[0.00351749]]),
#  'The Duchess': array([[0.00476485]]),
#  'Shakespeare in Love': array([[0.00299219]]),
#  'Pineapple Express': array([[0.04766514]]),
#  'A Bridge Too Far': array([[0.00508883]]),
#  'Final Destination 2': array([[0.00481593]]),
#  'Gran Torino': array([[0.00361866]]),
#  'Taken': array([[0.00422527]]),
#  'The Bodyguard': array([[0.00401983]]),
#  "Schindler's List": array([[0.00363407]]),
#  'Cloverfield': array([[0.01829664]]),
#  'The Untouchables': array([[0.00271406]]),
#  'No Country for Old Men': array([[0.00397115]]),
#  "Bridget Jones's Diary": array([[0.03872482]]),
#  'No Strings Attached': array([[0.03305043]]),
#  'Tombstone': array([[0.00348722]]),
#  'Finding Neverland': array([[0.00234546]]),
#  'Anchorman: The Legend of Ron Burgundy': array([[0.03020567]]),
#  'Scarface': array([[0.00357825]]),
#  'The Last Emperor': array([[0.00252881]]),
#  'There Will Be Blood': array([[0.00316487]]),
#  'Million Dollar Arm': array([[0.0243844]]),
#  "She's the Man": array([[0.01830291]]),
#  'August Rush': array([[0.00202393]]),
#  'Elizabeth': array([[0.00497651]]),
#  'Spice World': array([[0.00407041]]),
#  'The Shawshank Redemption': array([[0.00301282]]),
#  'Kingpin': array([[0.00267435]]),
#  'He Got Game': array([[0.00358447]]),
#  'Dear John': array([[0.00514311]]),
#  'The Greatest Game Ever Played': array([[0.00530033]]),
#  'The Girl Next Door': array([[0.04355076]]),
#  'Legend': array([[0.0047101]]),
#  'Hot Rod': array([[0.02486911]]),
#  'Draft Day': array([[0.02419043]]),
#  'Lords of Dogtown': array([[0.00433262]]),
#  'Warrior': array([[0.0039412]]),
#  'Gettysburg': array([[0.00368748]]),
#  'Stop-Loss': array([[0.00429538]]),
#  "The World's Fastest Indian": array([[0.00349944]]),
#  'Scream 2': array([[0.00541129]]),
#  'Footloose': array([[0.00492515]]),
#  'The Men Who Stare at Goats': array([[0.04269518]]),
#  'Girl, Interrupted': array([[0.00456279]]),
#  'Zombieland': array([[0.01424642]]),
#  'The Waterboy': array([[0.00356617]]),
#  'Final Destination': array([[0.00455461]]),
#  'Pitch Black': array([[0.00413231]]),
#  'Her': array([[0.00392705]]),
#  '1408': array([[0.00324795]]),
#  'The Water Diviner': array([[0.00320781]]),
#  'Ghost': array([[0.00357748]]),
#  "There's Something About Mary": array([[0.00320146]]),
#  'The Rookie': array([[0.00459947]]),
#  'Gandhi': array([[0.00214416]]),
#  'Underworld': array([[0.0037284]]),
#  'Hail, Caesar!': array([[0.06820837]]),
#  'South Park: Bigger, Longer & Uncut': array([[0.01461258]]),
#  'Hardball': array([[0.00606894]]),
#  'Silver Linings Playbook': array([[0.00316387]]),
#  'The Transporter': array([[0.00445536]]),
#  'Never Back Down': array([[0.02213496]]),
#  'Tinker Tailor Soldier Spy': array([[0.00399969]]),
#  'Raiders of the Lost Ark': array([[0.00244941]]),
#  'Home Alone 2: Lost in New York': array([[0.00477172]]),
#  'The Silence of the Lambs': array([[0.00347351]]),
#  "Wayne's World": array([[0.00413194]]),
#  'The Conjuring': array([[0.00302834]]),
#  'School of Rock': array([[0.02634221]]),
#  'The Last Song': array([[0.00497424]]),
#  '12 Years a Slave': array([[0.00311168]]),
#  'Edward Scissorhands': array([[0.003774]]),
#  'Me Before You': array([[0.00325483]]),
#  'Selma': array([[0.0033573]]),
#  'Orphan': array([[0.03739307]]),
#  'Spotlight': array([[0.00282039]]),
#  'Milk': array([[0.0289295]]),
#  'High Fidelity': array([[0.00263538]]),
#  'Eternal Sunshine of the Spotless Mind': array([[0.00331144]]),
#  'Psycho': array([[0.00314916]]),
#  'Into the Wild': array([[0.06313172]]),
#  'From Dusk Till Dawn': array([[0.02174061]]),
#  'Little Boy': array([[0.00530599]]),
#  'Bad Teacher': array([[0.05086933]]),
#  'Scream': array([[0.04034297]]),
#  'The Shining': array([[0.0031423]]),
#  'Back to the Future': array([[0.00214434]]),
#  'The Book Thief': array([[0.00460516]]),
#  'The Mask': array([[0.00368097]]),
#  'Borat: Cultural Learnings of America for Make Benefit Glorious Nation of Kazakhstan': array([[1.]]),
#  'Predator': array([[0.00432603]]),
#  'Amadeus': array([[0.00361907]]),
#  'United 93': array([[0.00402894]]),
#  'Honey': array([[0.00318901]]),
#  'Catch-22': array([[0.00451163]]),
#  'Raging Bull': array([[0.00344784]]),
#  '127 Hours': array([[0.00282436]]),
#  'Steve Jobs': array([[0.00389008]]),
#  'Ed Wood': array([[0.00243406]]),
#  'Superbad': array([[0.05244212]]),
#  'Step Up 2: The Streets': array([[0.00324854]]),
#  'Hotel Rwanda': array([[0.00306732]]),
#  'The Others': array([[0.00410818]]),
#  'Aliens': array([[0.00311763]]),
#  'Halloween': array([[0.04125204]]),
#  'A Night at the Roxbury': array([[0.0040304]]),
#  'The Hills Have Eyes': array([[0.00402899]]),
#  'McFarland, USA': array([[0.06414857]]),
#  'Pitch Perfect': array([[0.02458489]]),
#  'Evil Dead': array([[0.02362406]]),
#  'The Illusionist': array([[0.00350093]]),
#  'Dead Poets Society': array([[0.02190444]]),
#  'Dumb and Dumber': array([[0.00250218]]),
#  'When Harry Met Sally...': array([[0.09150291]]),
#  'The Artist': array([[0.00243569]]),
#  'Moonrise Kingdom': array([[0.0107292]]),
#  'Hot Fuzz': array([[0.00380529]]),
#  'Vicky Cristina Barcelona': array([[0.00439008]]),
#  'Detroit Rock City': array([[0.00398726]]),
#  'Zulu': array([[0.00610676]]),
#  'Home Alone': array([[0.00335835]]),
#  'American Beauty': array([[0.09468732]]),
#  "The King's Speech": array([[0.00368307]]),
#  'The Imitation Game': array([[0.00461356]]),
#  'Mama': array([[0.00491342]]),
#  'The Queen': array([[0.00263612]]),
#  'Beetlejuice': array([[0.00374702]]),
#  'The Woman in Black': array([[0.00351037]]),
#  'The Deer Hunter': array([[0.0036969]]),
#  'The Theory of Everything': array([[0.00373281]]),
#  'Lawrence of Arabia': array([[0.00311005]]),
#  'The Princess Bride': array([[0.00400203]]),
#  'Drive': array([[0.00308156]]),
#  '28 Weeks Later': array([[0.00263375]]),
#  'Match Point': array([[0.00313527]]),
#  'The Hurt Locker': array([[0.00305878]]),
#  'Whip It': array([[0.02165255]]),
#  'The Big Lebowski': array([[0.0023896]]),
#  'Black Snake Moan': array([[0.04035971]]),
#  'In Bruges': array([[0.00289452]]),
#  'The Rocker': array([[0.00398304]]),
#  'Mulholland Drive': array([[0.0031299]]),
#  'Centurion': array([[0.00321473]]),
#  'Groundhog Day': array([[0.00307941]]),
#  'Magic Mike XXL': array([[0.03416044]]),
#  'Romeo + Juliet': array([[0.00296668]]),
#  'Slumdog Millionaire': array([[0.01798899]]),
#  'Pretty Woman': array([[0.05128661]]),
#  'Born on the Fourth of July': array([[0.00341761]]),
#  'Brokeback Mountain': array([[0.05090744]]),
#  'Good Morning, Vietnam': array([[0.00244099]]),
#  'Black Swan': array([[0.0027981]]),
#  'The Godfather: Part II': array([[0.00340345]]),
#  'Save the Last Dance': array([[0.00453635]]),
#  '10 Things I Hate About You': array([[0.02969727]]),
#  'The Butterfly Effect': array([[0.00448445]]),
#  'The Mist': array([[0.00304354]]),
#  'Ex Machina': array([[0.00279441]]),
#  'Being John Malkovich': array([[0.00269066]]),
#  'Room': array([[0.00376174]]),
#  '54': array([[0.00455126]]),
#  'The Perks of Being a Wallflower': array([[0.0158463]]),
#  'In the Land of Blood and Honey': array([[0.00342298]]),
#  'True Romance': array([[0.00342488]]),
#  'The Exorcist': array([[0.00284218]]),
#  'Jaws': array([[0.00282414]]),
#  'American Pie': array([[0.03513401]]),
#  'Step Up': array([[0.02850923]]),
#  'Jackie Brown': array([[0.00427595]]),
#  'Patton': array([[0.00361729]]),
#  'The Fault in Our Stars': array([[0.00348516]]),
#  'About Time': array([[0.0055451]]),
#  'Snatch': array([[0.00327246]]),
#  'Gremlins': array([[0.0028679]]),
#  'Doctor Zhivago': array([[0.00363416]]),
#  'The Fighter': array([[0.01246963]]),
#  'If I Stay': array([[0.00409458]]),
#  'Major League': array([[0.0030036]]),
#  'A Walk to Remember': array([[0.02061482]]),
#  'Barry Lyndon': array([[0.00370614]]),
#  'Woman in Gold': array([[0.00461247]]),
#  'Army of Darkness': array([[0.00288034]]),
#  'Inside Llewyn Davis': array([[0.0037127]]),
#  '2001: A Space Odyssey': array([[0.00398685]]),
#  'E.T. the Extra-Terrestrial': array([[0.00322921]]),
#  'Good Will Hunting': array([[0.00309708]]),
#  'Saw III': array([[0.03774664]]),
#  'Stripes': array([[0.0043768]]),
#  'Bring It On': array([[0.03591141]]),
#  'The Color of Money': array([[0.00410325]]),
#  'The Longest Day': array([[0.00435054]]),
#  'Happy Gilmore': array([[0.00377608]]),
#  "Bill & Ted's Excellent Adventure": array([[0.01675876]]),
#  "Nick and Norah's Infinite Playlist": array([[0.00455595]]),
#  'American History X': array([[0.0360457]]),
#  'The Red Violin': array([[0.00534209]]),
#  'Crash': array([[0.00336929]]),
#  'Peaceful Warrior': array([[0.00636852]]),
#  'Coriolanus': array([[0.00355126]]),
#  'Alien': array([[0.0029335]]),
#  'The Runaways': array([[0.00241131]]),
#  'Velvet Goldmine': array([[0.01806338]]),
#  'Crazy Heart': array([[0.09284681]]),
#  'Pulp Fiction': array([[0.00277673]]),
#  'Nightcrawler': array([[0.00340007]]),
#  'The Sound of Music': array([[0.00300415]]),
#  'Little Miss Sunshine': array([[0.02312397]]),
#  'American Psycho': array([[0.02123409]]),
#  'Easy A': array([[0.04829237]]),
#  'Begin Again': array([[0.00633077]]),
#  'Juno': array([[0.00318709]]),
#  'The Godfather': array([[0.00336283]]),
#  'Flashdance': array([[0.00442584]]),
#  'The Piano': array([[0.00262546]]),
#  'Good Night, and Good Luck.': array([[0.11042704]]),
#  'Capote': array([[0.00379431]]),
#  'The Descent': array([[0.00380135]]),
#  'Incendies': array([[0.00314134]]),
#  'Control': array([[0.00316367]]),
#  'The Terminator': array([[0.00346987]]),
#  'Grease': array([[0.02875662]]),
#  'Platoon': array([[0.00383102]]),
#  'Butch Cassidy and the Sundance Kid': array([[0.00396551]]),
#  'Caddyshack': array([[0.06660027]]),
#  'The Usual Suspects': array([[0.00389476]]),
#  'The Wrestler': array([[0.00317014]]),
#  'The Last King of Scotland': array([[0.00351866]]),
#  'Hedwig and the Angry Inch': array([[0.00275637]]),
#  'Chariots of Fire': array([[0.00402651]]),
#  'Shine': array([[0.00380792]]),
#  'Don Jon': array([[0.06067185]]),
#  'Rang De Basanti': array([[0.00406109]]),
#  'Insidious: Chapter 2': array([[0.00397091]]),
#  'Saw II': array([[0.0056789]]),
#  '10 Cloverfield Lane': array([[0.00397895]]),
#  'Monster': array([[0.06649065]]),
#  'The Elephant Man': array([[0.00354941]]),
#  'Dallas Buyers Club': array([[0.0042679]]),
#  'Memento': array([[0.00332941]]),
#  'Billy Elliot': array([[0.00426368]]),
#  'Shaun of the Dead': array([[0.00249395]]),
#  'Moon': array([[0.00425384]]),
#  'The Machinist': array([[0.00276308]]),
#  'Green Room': array([[0.00250527]]),
#  'Tucker and Dale vs Evil': array([[0.00434054]]),
#  'Hostel': array([[0.00316164]]),
#  'Requiem for a Dream': array([[0.00425779]]),
#  'Donnie Darko': array([[0.0442175]]),
#  "One Flew Over the Cuckoo's Nest": array([[0.00312848]]),
#  'Airlift': array([[0.00422831]]),
#  'Lost in Translation': array([[0.01792886]]),
#  'Annie Hall': array([[0.0032207]]),
#  'The Great Escape': array([[0.00246044]]),
#  'Gone with the Wind': array([[0.03254843]]),
#  'The Witch': array([[0.00478483]]),
#  'Evil Dead II': array([[0.00299505]]),
#  'Whiplash': array([[0.02081013]]),
#  "Rosemary's Baby": array([[0.03186684]]),
#  "It's a Wonderful Life": array([[0.00285201]]),
#  'Trainspotting': array([[0.00210178]]),
#  'The Purge': array([[0.00401792]]),
#  'Sinister': array([[0.00268924]]),
#  'The Bridge on the River Kwai': array([[0.00434246]]),
#  'Judgment at Nuremberg': array([[0.00314732]]),
#  'Hustle & Flow': array([[0.00390478]]),
#  'Some Like It Hot': array([[0.00265091]]),
#  'The Wizard of Oz': array([[0.0033261]]),
#  "Singin' in the Rain": array([[0.00315957]]),
#  'That Thing You Do!': array([[0.00422208]]),
#  'Garden State': array([[0.00293829]]),
#  'Before Sunrise': array([[0.00363412]]),
#  'The Best Years of Our Lives': array([[0.03627972]]),
#  'It Follows': array([[0.02832902]]),
#  'To Kill a Mockingbird': array([[0.00284291]]),
#  'The Hustler': array([[0.00322662]]),
#  'Before Sunset': array([[0.07577445]]),
#  'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb': array([[0.0258654]]),
#  'From Here to Eternity': array([[0.00394269]]),
#  'Insidious': array([[0.02628592]]),
#  'Snow White and the Seven Dwarfs': array([[0.00341878]]),
#  'Lock, Stock and Two Smoking Barrels': array([[0.00286311]]),
#  'Saw': array([[0.00406771]]),
#  'Reservoir Dogs': array([[0.02232332]]),
#  'Casablanca': array([[0.00313808]]),
#  'Rocky': array([[0.00306549]]),
#  'Taxi Driver': array([[0.00337058]]),
#  'Saints and Soldiers': array([[0.0040762]]),
#  'The Blair Witch Project': array([[0.00342723]]),
#  "A Hard Day's Night": array([[0.04116498]]),
#  'Bloody Sunday': array([[0.00424036]]),
#  'Paranormal Activity': array([[0.00469937]]),
#  'Monty Python and the Holy Grail': array([[0.00239838]]),
#  'The Evil Dead': array([[0.00263316]]),
#  '12 Angry Men': array([[0.00325005]]),
#  'Cube': array([[0.00375183]]),
#  'Once': array([[0.00243784]]),
#  'The Birth of a Nation': array([[0.00572927]]),
#  'Pi': array([[0.00395371]])}
